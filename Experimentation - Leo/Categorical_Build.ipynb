# %% [markdown]
# # Categorical Models Buildout
#
# ## Steps
# - Query from yfinance
# - Build out moving average indicators
# - Build out target (binary with a filter to remove 5th percentile)
# - Heatmap to visualize how well indicators separate target --> univariate and bivariate
# - Basic xgboost model with cv
# - Permutation importance
# - Layer in additional complexity to model architecture
# - Evolve indicator list
# - Expand to other categories

# %% [markdown]
# ## Query from yfinance

# %% [markdown]
# ## Build out moving average indicators

# %% [markdown]
# ## Build out target (binary with a filter to remove 5th percentile)

# %% [markdown]
# ## Heatmap to visualize how well indicators separate target --> univariate and bivariate

# %% [markdown]
# ## Basic xgboost model with cv

# %% [markdown]
# ## Permutation importance

# %% [markdown]
# ## Layer in additional complexity to model architecture

# %% [markdown]
# ## Evolve indicator list

# %% [markdown]
# ## Expand to other categories
