# %%
import numpy as np
import pandas as pd
import datetime
import yfinance as yf
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# For importing universal scripts
import sys
import os
# Go up two levels from the subfolder
sys.path.append(os.path.abspath("../.."))
from indicators_returns import final_df #Universal script for indicator set and actuals
import importlib
import indicators_returns
importlib.reload(indicators_returns)
from indicators_returns import final_df

from sklearn.metrics import (fbeta_score, accuracy_score, f1_score, 
                             confusion_matrix, balanced_accuracy_score, recall_score, matthews_corrcoef, precision_score)
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split, StratifiedKFold

# %%
ticker = 'QQQ'
returns = [5, 10, 20, 30, 45, 60, 90]
lb = 20
df = final_df(ticker, returns, lb)
df = df.iloc[:-101].replace([np.inf, -np.inf], 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BB_Mid_raw'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # Import ccsvs from earlier univariate analysis

# %%
cluster_df = pd.read_csv('../Indicator_Correlations/cluster.csv')  # includes 'indicator', 'cluster' columns
high_corr = pd.read_csv('../Indicator_Correlations/highly_correlated_pairs.csv')  # includes 'indicator_1', 'indicator_2'
low_corr = pd.read_csv('../Indicator_Correlations/low_corr_pairs.csv')  # includes 'indicator_1', 'indicator_2'
corr_matrix = pd.read_csv('../Indicator_Correlations/all_cors.csv')  # includes 'indicator_1', 'indicator_2'
ind_dynamics_df = pd.read_csv('../Indicator_Dynamics/indicator_dynamics.csv')  # includes 'r', 'indicator', volatility/zscore/autocorr columns
logistic_results_df = pd.read_csv('../Univariate_Predictive_Power/logistic_results_xgb.csv')  # includes AUC, logloss, etc.
high_level_cat = pd.read_csv('../Finalization/high_level_cat.csv')

# %% [markdown]
# # Bi and Tri Variate Assessment

# %%
# Identify all indicator columns (same logic as before)
indicator_cols = [col for col in df.columns 
                if col not in ['Date', 'Close', 'High', 'Low', 'Volume']
                and not col.startswith('Return')
                and 'slope' not in col.lower()
]

from itertools import combinations
#corr_matrix = corr_matrix.set_index('Unnamed: 0')

def get_low_corr_pairs(corr_matrix, indicator_cols, min_threshold=0.05, max_threshold=0.5):
    low_corr_pairs = []
    indicators = indicator_cols

    for ind1, ind2 in combinations(indicators, 2):
        corr_val = abs(corr_matrix.loc[ind1, ind2])
        if min_threshold <= corr_val < max_threshold:
            low_corr_pairs.append((ind1, ind2))
    
    return low_corr_pairs

# Usage:
low_corr_combos = get_low_corr_pairs(corr_matrix, indicator_cols, min_threshold=0.2, max_threshold=0.4)
print(f"Number of valid low-to-moderate correlation pairs: {len(low_corr_combos)}")
# Out:
# Number of valid low-to-moderate correlation pairs: 12736

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, log_loss, f1_score, accuracy_score
from scipy.stats import ks_2samp
from sklearn.linear_model import LogisticRegression


from xgboost import XGBClassifier
from sklearn.metrics import f1_score, accuracy_score
from scipy.stats import ks_2samp
import numpy as np

def evaluate_pair_recent500(ind1_series, ind2_series, target_series, r, p=500):
    # Combine the two indicators into a feature matrix
    X = np.vstack([ind1_series.values, ind2_series.values]).T
    y = target_series.values

    # Drop any rows with NaNs
    mask = ~np.isnan(X).any(axis=1) & ~np.isnan(y)
    X, y = X[mask], y[mask]

    # Skip if not enough valid data
    if len(np.unique(y)) < 2 or len(y) < 100:
        return None

    # Temporal test/train split
    X_test, y_test = X[:p], y[:p]
    X_train, y_train = X[p:], y[p:]

    # Handle class imbalance
    scale_pos_weight = ((len(y_train) - y_train.sum()) / y_train.sum())

    # Initialize model with early stopping
    model = XGBClassifier(
        objective='binary:logistic',
        eval_metric='logloss',  # Still needed for early stopping
        max_depth=4,
        n_estimators=150,
        learning_rate=0.05,
        subsample=0.85,
        colsample_bytree=1,
        scale_pos_weight=scale_pos_weight,
        early_stopping_rounds=8,
    )

    model.fit(
        X_train, y_train,
        eval_set=[(X_test, y_test)],
        verbose=False
    )

    y_pred_proba = model.predict_proba(X_test)[:, 1]
    y_pred_class = (y_pred_proba >= 0.5).astype(int)

    # Filter for confident predictions
    confident_mask = (y_pred_proba >= 0.55) | (y_pred_proba <= 0.45)
    y_test_conf = y_test[confident_mask]
    y_pred_class_conf = y_pred_class[confident_mask]
    y_pred_proba_conf = y_pred_proba[confident_mask]

    if len(y_test_conf) == 0 or len(np.unique(y_test_conf)) < 2:
        return None  # Not enough confident predictions or not enough class variety

    # Accuracy metrics on confident subset
    pos_mask = y_pred_class_conf == 1
    neg_mask = y_pred_class_conf == 0

    pos_precision = (y_test_conf[pos_mask] == 1).mean() if pos_mask.any() else np.nan
    neg_precision = (y_test_conf[neg_mask] == 0).mean() if neg_mask.any() else np.nan

    total_preds = pos_mask.sum() + neg_mask.sum()
    weighted_precision = (
        (pos_mask.sum() * pos_precision + neg_mask.sum() * neg_precision) / total_preds
        if total_preds > 0 else np.nan
    )

    # KS statistic on confident subset
    ks = ks_2samp(
        y_pred_proba_conf[y_test_conf == 1],
        y_pred_proba_conf[y_test_conf == 0]
    ).statistic

    return {
        'r': r,
        'f1_ts': f1_score(y_test_conf, y_pred_class_conf),
        'accuracy_ts': accuracy_score(y_test_conf, y_pred_class_conf),
        'pos_acc_ts': pos_precision,
        'neg_acc_ts': neg_precision,
        'pos_count_ts': pos_mask.sum(),
        'neg_count_ts': neg_mask.sum(),
        'weighted_precision': weighted_precision,
        'bal_accuracy': np.nanmean([pos_precision, neg_precision]),
        'ks_ts': ks,
        'best_n_estimators': model.best_iteration + 1
    }

results_pair_ts = []

for r in returns:
    print(r)
    df_test = df.copy()
    return_col = f'Return_{r}'
    df_eval = df.iloc[r:].copy()

    for ind1, ind2 in low_corr_combos:
        if ind1 not in df_eval.columns or ind2 not in df_eval.columns:
            continue

        result = evaluate_pair_recent500(df_eval[ind1], df_eval[ind2], df_eval[return_col], r)
        if result:
            result['pair'] = f'{ind1} + {ind2}'
            result['indicator_1'] = ind1
            result['indicator_2'] = ind2
            results_pair_ts.append(result)

logistic_results_pair_ts2 = pd.DataFrame(results_pair_ts)
# Out:
# 5
# /Users/brettchase/Library/Python/3.12/lib/python/site-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/brettchase/Library/Python/3.12/lib/python/site-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/brettchase/Library/Python/3.12/lib/python/site-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   res = hypotest_fun_out(*samples, **kwds)
# 10
# /Users/brettchase/Library/Python/3.12/lib/python/site-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   res = hypotest_fun_out(*samples, **kwds)
# ...

# %% [markdown]
# # Identify most promising pairs for each horizon

# %%
logistic_results_pair_ts2 = pd.DataFrame(results_pair_ts)
logistic_results_pair_ts2['total_count']= logistic_results_pair_ts2['pos_count_ts'] + logistic_results_pair_ts2['neg_count_ts']

df_5 = logistic_results_pair_ts2[logistic_results_pair_ts2['r'] == 5]
df_10 = logistic_results_pair_ts2[logistic_results_pair_ts2['r'] == 10]
df_20 = logistic_results_pair_ts2[logistic_results_pair_ts2['r'] == 20]
df_30 = logistic_results_pair_ts2[logistic_results_pair_ts2['r'] == 30]
df_45 = logistic_results_pair_ts2[logistic_results_pair_ts2['r'] == 45]
df_60 = logistic_results_pair_ts2[logistic_results_pair_ts2['r'] == 60]
df_90 = logistic_results_pair_ts2[logistic_results_pair_ts2['r'] == 90]

df_list = [df_5, df_10, df_20, df_30, df_45, df_60, df_90]

pairs_df = []

for df_perf in df_list:

    # Apply filtering
    filtered_df = df_perf[
        (df_perf['total_count'] >= 100) &
        (df_perf['pos_acc_ts'] >= 0.6) &
        (df_perf['neg_acc_ts'] >= 0.6)
    ]

    # Collect into master list
    print(len(filtered_df))
    pairs_df.append(filtered_df)

# Concatenate all filtered records into a single DataFrame
pairs_df = pd.concat(pairs_df, ignore_index=True)
# Out:
# 61
# 25
# 8
# 18
# 7
# 1
# 0

# %%
def rank_pairs(df_r, actual_pos_weight):
    df_r = df_r.copy()
    df_r['predicted_pos_weight'] = df_r['pos_count_ts'] / df_r['total_count']
    df_r['balance_penalty'] = 1 - abs(df_r['predicted_pos_weight'] - actual_pos_weight)

    df_r['rank_score'] = (
        (df_r['bal_accuracy'] * (df_r['total_count'] / 500)) * 0.6 +
        df_r['weighted_precision'] * 0.25 +
        df_r['ks_ts'] * 0.15
    ) * df_r['balance_penalty']

    df_r = df_r.sort_values(by='rank_score', ascending=False)
    return df_r

pair_master = []

for r, df_r in zip(returns, df_list):
    actual_pos_weight = df[f'Return_{r}'].iloc[500:].sum() / len(df[f'Return_{r}'].iloc[500:]) 
    print(f'{r} | {round(actual_pos_weight,3)}')
    df_r = rank_pairs(df_r, actual_pos_weight)
    ordered_cols = ['r', 'pair', 'rank_score', 'weighted_precision', 'total_count', 'pos_count_ts',
                    'neg_count_ts', 'pos_acc_ts', 'neg_acc_ts', 'ks_ts', 'bal_accuracy', 'f1_ts',
                    'accuracy_ts', 'best_n_estimators', 'indicator_1', 'indicator_2']
    df_r = df_r[(df_r['pos_acc_ts'] >= 0.4) & (df_r['neg_acc_ts'] >= 0.4)
                & (df_r['total_count'] >= 100)][ordered_cols].head(20)
    pair_master.append(df_r)

df_pair_master = pd.concat(pair_master, ignore_index=True)
df_pair_master.to_csv('df_pair_master.csv')
# Out:
# 5 | 0.598
# 10 | 0.628
# 20 | 0.658
# 30 | 0.677
# 45 | 0.709
# 60 | 0.733
# 90 | 0.763

# %% [markdown]
# # Add in close slope metrics and reassess performance

# %%
def evaluate_slope_recent500(X_df, target_series, r, p=500):
    # Drop any rows with NaNs in either features or target
    df_valid = pd.concat([X_df, target_series], axis=1).dropna()

    X = df_valid[X_df.columns].values
    y = df_valid[target_series.name].values

    # Temporal test/train split
    X_test, y_test = X[:p], y[:p]
    X_train, y_train = X[p:], y[p:]

    # Handle class imbalance
    scale_pos_weight = ((len(y_train) - y_train.sum()) / y_train.sum())

    # Initialize model with early stopping
    model = XGBClassifier(
        objective='binary:logistic',
        eval_metric='logloss',  # Still needed for early stopping
        max_depth=5,
        n_estimators=150,
        learning_rate=0.05,
        subsample=0.85,
        colsample_bytree=.6,
        scale_pos_weight=scale_pos_weight,
        early_stopping_rounds=20,
    )

    model.fit(
        X_train, y_train,
        eval_set=[(X_test, y_test)],
        verbose=False
    )

    y_pred_proba = model.predict_proba(X_test)[:, 1]
    y_pred_class = (y_pred_proba >= 0.5).astype(int)

    # Filter for confident predictions
    confident_mask = (y_pred_proba >= 0.55) | (y_pred_proba <= 0.45)
    y_test_conf = y_test[confident_mask]
    y_pred_class_conf = y_pred_class[confident_mask]
    y_pred_proba_conf = y_pred_proba[confident_mask]

    # Accuracy metrics on confident subset
    pos_mask = y_pred_class_conf == 1
    neg_mask = y_pred_class_conf == 0

    pos_precision = (y_test_conf[pos_mask] == 1).mean() if pos_mask.any() else np.nan
    neg_precision = (y_test_conf[neg_mask] == 0).mean() if neg_mask.any() else np.nan

    total_preds = pos_mask.sum() + neg_mask.sum()
    weighted_precision = (
        (pos_mask.sum() * pos_precision + neg_mask.sum() * neg_precision) / total_preds
        if total_preds > 0 else np.nan
    )

    # KS statistic on confident subset
    ks = ks_2samp(
        y_pred_proba_conf[y_test_conf == 1],
        y_pred_proba_conf[y_test_conf == 0]
    ).statistic

    return {
        'r': r,
        'f1_ts': f1_score(y_test_conf, y_pred_class_conf),
        'accuracy_ts': accuracy_score(y_test_conf, y_pred_class_conf),
        'pos_acc_ts': pos_precision,
        'neg_acc_ts': neg_precision,
        'pos_count_ts': pos_mask.sum(),
        'neg_count_ts': neg_mask.sum(),
        'weighted_precision': weighted_precision,
        'bal_accuracy': np.nanmean([pos_precision, neg_precision]),
        'ks_ts': ks,
        'best_n_estimators': model.best_iteration + 1
    }

results_pair_slope = []
slope_cols = [f'Close_slope{w}' for w in [5, 10, 25, 50]]
i = 1

for _, row in df_pair_master.iterrows():
    r = row['r']
    ind1 = row['indicator_1']
    ind2 = row['indicator_2']
    
    return_col = f'Return_{r}'
    df_eval = df.iloc[r:].copy()

    # Check for necessary columns
    if not all(col in df_eval.columns for col in [ind1, ind2, return_col]):
        continue

    # Select feature columns (pair + slope features)
    slope_features = [col for col in slope_cols if col in df_eval.columns]
    feature_cols = [ind1, ind2] + slope_features
    #print(f'{i} - {r} | {feature_cols}')
    i = i + 1
    X_df = df_eval[feature_cols]
    target_series = df_eval[return_col]

    result = evaluate_slope_recent500(X_df, target_series, r)
    if result:
        result['pair'] = f'{ind1} + {ind2}'
        result['indicator_1'] = ind1
        result['indicator_2'] = ind2
        results_pair_slope.append(pd.DataFrame([result]))

df_slope_master = pd.concat(results_pair_slope, ignore_index=True)
df_slope_master['total_count']= df_slope_master['pos_count_ts'] + df_slope_master['neg_count_ts']
# Out:
# /var/folders/k0/mlnk5_mx6ns64dfxsknt0p3m0000gn/T/ipykernel_73749/3192016921.py:57: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   ks = ks_2samp(
# /Users/brettchase/Library/Python/3.12/lib/python/site-packages/sklearn/metrics/_classification.py:1760: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /Users/brettchase/Library/Python/3.12/lib/python/site-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /Users/brettchase/Library/Python/3.12/lib/python/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ...

# %% [markdown]
# # Merge pairs with slope performance

# %%
df_combined = pd.merge(
    df_pair_master,
    df_slope_master,
    on=['r', 'pair', 'indicator_1', 'indicator_2'],
    suffixes=('_p', '_s')
)

df_combined.to_csv('df_combined.csv')

# %% [markdown]
# # Slope Charts

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
import yfinance as yf
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# For importing universal scripts
import sys
import os
# Go up two levels from the subfolder
sys.path.append(os.path.abspath("../.."))
from indicators_returns import final_df #Universal script for indicator set and actuals
import importlib
import indicators_returns
importlib.reload(indicators_returns)
from indicators_returns import final_df

from sklearn.metrics import (fbeta_score, accuracy_score, f1_score, 
                             confusion_matrix, balanced_accuracy_score, recall_score, matthews_corrcoef, precision_score)
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split, StratifiedKFold

ticker = 'QQQ'
returns = [5, 10, 20, 30, 45, 60, 90]
lb = 20
df = final_df(ticker, returns, lb)
df = df.iloc[:-101].replace([np.inf, -np.inf], 0)

high_level_cat = pd.read_csv('../Finalization/high_level_cat.csv') 
cols = high_level_cat['Indicator'][high_level_cat['High Level'] == 'Slope_50'].to_list()
skip = []
#cols = [] # Remove to run
for col in cols:
    try:
        plt.figure(figsize=(12, 6))
        plt.plot(df['Date'], df[col])
        plt.xlabel('Date')
        plt.ylabel(f'{col}')
        plt.title(f'{col} Over Time')
        plt.grid(True)
        plt.tight_layout()
        plt.show()
    except KeyError:
        skip.append(col)
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'High Level'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.iloc[0].to_csv('cols.csv')
