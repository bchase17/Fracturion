# %%
import numpy as np
import pandas as pd
import yfinance as yf
import sys
import os
# Go up two levels from the subfolder
sys.path.append(os.path.abspath(".."))
from indicators_returns import final_df #Universal script for indicator set and actuals
import importlib
import indicators_returns
importlib.reload(indicators_returns)
from indicators_returns import final_df
from sklearn.metrics import matthews_corrcoef, precision_score
from sklearn.model_selection import RandomizedSearchCV, train_test_split, StratifiedKFold, TimeSeriesSplit
from xgboost import XGBClassifier
import pickle
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt

# Get data on this ticker
def get_data(ticker):
    
    df_orig = yf.Ticker(ticker).history(period="max", interval="1d", auto_adjust=True).reset_index()[['Date', 'Close', 'High', 'Low', 'Volume']]
    df_orig['Date'] = pd.to_datetime(df_orig['Date']).dt.strftime('%Y-%m-%d')
    
    return df_orig

def ma_features(df): 
    
    df = df.sort_values(by='Date', ascending=True)

    # =======================
    # Basic SMAs and Ratios
    # =======================
    for window in [5, 10, 25, 50, 100, 200]:
        
        df[f'SMA_{window}'] = df['Close'].rolling(window=window).mean()

        # Current close relativet to n_day high | max 1
        df[f'Close_Rel_Max{window}'] = (df['Close'] / df['High'].rolling(window=window).max()).round(2)
        # Current close relativet to n_day low | min 1
        df[f'Close_Rel_Min{window}'] = (df['Close'] / df['Low'].rolling(window=window).min()).round(2)

        if window in (50, 100, 200):
            df[f'num_days_{window}'] = 0
    
    for window in [50, 100, 200]:
        for i in range(1, len(df)):
            prev = df.loc[i - 1, f'num_days_{window}']
            price = df.loc[i, 'Close']
            sma = df.loc[i, f'SMA_{window}']
            if price > sma:
                df.loc[i, f'num_days_{window}'] = prev + 1 if prev >= 0 else 0
            elif price < sma:
                df.loc[i, f'num_days_{window}'] = prev - 1 if prev <= 0 else 0
            else:
                df.loc[i, f'num_days_{window}'] = 0

        #df[f'num_days_{window}'] = df[f'num_days_{window}'].apply(lambda x: int(5 * round(x / 5)))

    lag_periods = []#[50, 100, 150, 200]

    for lag in lag_periods:
        new_cols = {}
        for col in df.columns:
            if col.startswith('SMA_'):
                new_cols[f'{col}_Lag{lag}'] = (df[col] / df[col].shift(-lag)).round(2)

        df = pd.concat([df, pd.DataFrame(new_cols, index=df.index)], axis=1)
            
    for window in []: #[50, 100, 200]:
        for i in range(1, len(df)):
            prev = df.loc[i - 1, f'num_days_{window}']
            price = df.loc[i, 'Close']
            sma = df.loc[i, f'SMA_{window}']
            if price > sma:
                df.loc[i, f'num_days_{window}'] = prev + 1 if prev >= 0 else 0
            elif price < sma:
                df.loc[i, f'num_days_{window}'] = prev - 1 if prev <= 0 else 0
            else:
                df.loc[i, f'num_days_{window}'] = 0

        #df[f'num_days_{window}'] = df[f'num_days_{window}'].apply(lambda x: int(5 * round(x / 5)))

    # ============================
    # Relative Position Features
    # ============================
    def rows_since_max(x): return len(x) - x.argmax() - 1
    def rows_since_min(x): return len(x) - x.argmin() - 1

    for window in [10, 30, 60, 120, 240]:

        df[f'Rel_Max_{window}'] = (df['High'] / df['High'].rolling(window=window).max()).round(2)
        df[f'Rel_Min_{window}'] = (df['Low'] / df['Low'].rolling(window=window).min()).round(2)
        df[f'Max_{window}_Rows_Since'] = df['High'].rolling(window=window).apply(rows_since_max, raw=True)
        df[f'Min_{window}_Rows_Since'] = df['Low'].rolling(window=window).apply(rows_since_min, raw=True)

    for a, b in [(50, 100), (50, 200), (100, 200), (10, 25), (10, 50), (10, 100), (10, 200), (25, 50), (25, 100), (25, 200),
                (5, 10), (5, 25), (5,50)]:    
        df[f'{a}_SMA_{b}'] = (df[f'SMA_{a}'] / df[f'SMA_{b}']).round(2)

    def round_to_nearest_point05(x):
        return round(x * 20) / 20

    for window in [5, 10, 25, 50, 100, 200]:

        df[f'SMA_{window}'] = (df['Close'] / df[f'SMA_{window}']).round(2)
        #df[f'EMA_{window}'] = (df['Close'] / df[f'EMA_{window}']).round(2)

    return df

def rsi_features(df):

    df = df.sort_values(by='Date', ascending=True)

    # RSI
    def RSI(data, period, diff):
        delta = data['Close'].diff(diff)
        gain = (delta.where(delta > 0, 0)).rolling(window=period).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=period).mean()
        RS = gain / loss
        return (100 - (100 / (1 + RS))).round(0)

    difs = [1, 3, 5]
    for dif in difs:
        df[f'RSI_14_{dif}'] = RSI(df, 14, dif)
        df[f'RSI_14_{dif}'] = RSI(df, 14, dif)
        df[f'RSI_14_{dif}'] = RSI(df, 14, dif)

    return df

def generate_returns(df, returns):

    def add_column_based_on_future_value(df, days):

        df = df.sort_values(by='Date', ascending=True)
        future_return = (df['Close'].shift(-days) - df['Close']) / df['Close']
        df[f'Return%_{days}'] = (future_return * 100).round(1) 
        df[f'Return_{days}'] = (future_return > 0).astype(int)
        
        past_return = (df['Close'] - df['Close'].shift(days)) / df['Close']
        df[f'Past_Return_{days}'] = (past_return > 0).astype(int)

        return df

    df_returns = df.copy()

    for r in returns:
    
        df_returns = add_column_based_on_future_value(df_returns, r)

    return df_returns

# %%
ticker = 'QQQ'
df_orig = get_data(ticker)
df_feats = ma_features(df_orig)
returns = [1, 2, 3, 4, 5, 7, 10, 15, 20, 25, 40, 50]
df_returns = generate_returns(df_orig, returns)
df_merged = pd.merge(df_feats, df_returns[[col for col in df_returns.columns if col.startswith('Return')] + ['Date']], on='Date')

# %% [markdown]
# # Regimes
#
# - Hidden Markov Models
# - Volatility Quintiles

# %%
# 1) HMM
from hmmlearn.hmm import GaussianHMM

df_hmm = df_orig[['Close']].sort_index(ascending=True).copy()
shift = 1
#df_hmm['ref'] = df_hmm['Close'].shift(shift)
#df_hmm['%'] = df_hmm['Close'] / df_hmm['Close'].shift(shift) - 1
df_hmm['logr_5'] = np.log(abs(df_hmm['Close'] / df_hmm['Close'].shift(shift)))

min_obs = 250
max_obs = 250
r = df_hmm.iloc[len(df_hmm)-4000:, 1:]
n_states=3

states = pd.Series(index=r.index, dtype="int64")
model = GaussianHMM(n_components=n_states, covariance_type="diag", n_iter=200)
# expanding walk-forward
for i in range(min_obs, len(r)):
    print(i)
    start = max(0, i - max_obs)
    x = r.iloc[start:i].values.reshape(-1, 1)
    model.fit(x)
    proba = model.predict_proba(x)[-1]
    states.iloc[i] = proba.argmax()
# Out:
# Model is not converging.  Current: 746.164745641361 is not greater than 746.2285894135546. Delta is -0.0638437721935361
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 736.1625575940377 is not greater than 736.1650625459877. Delta is -0.0025049519499589223
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 745.6011964939188 is not greater than 745.6577899683418. Delta is -0.05659347442303897
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.0186566527497 is not greater than 744.071880893033. Delta is -0.05322424028338446
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 743.9698463913751 is not greater than 744.0358634518768. Delta is -0.06601706050173561
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.7065991859031 is not greater than 745.349200410671. Delta is -0.6426012247678727
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 742.1493292889714 is not greater than 742.3397983683493. Delta is -0.19046907937786273
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 741.6620844099045 is not greater than 741.8290878420622. Delta is -0.16700343215768498
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 747.6867798272133 is not greater than 748.6696756757146. Delta is -0.9828958485013572
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.9266052653211 is not greater than 744.9420954827488. Delta is -0.01549021742766854
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 749.1173895494142 is not greater than 749.207159082537. Delta is -0.08976953312287606
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.927609086561 is not greater than 745.0070969123707. Delta is -0.07948782580967872
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 745.9644641936135 is not greater than 746.0241316867941. Delta is -0.059667493180654674
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 746.0148281344761 is not greater than 746.0895124852145. Delta is -0.07468435073838009
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 747.6490136559195 is not greater than 747.8499986546931. Delta is -0.2009849987736061
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.9150436310172 is not greater than 745.2311846236204. Delta is -0.31614099260320927
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 747.4492207252061 is not greater than 747.8339526980623. Delta is -0.38473197285611604
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 746.8244637470644 is not greater than 746.9960005986054. Delta is -0.17153685154096365
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 747.2951670101513 is not greater than 747.3035028143862. Delta is -0.00833580423488911
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 747.3221206762986 is not greater than 747.3434700373109. Delta is -0.02134936101231233
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 747.1246558217285 is not greater than 747.1305715413032. Delta is -0.005915719574659306
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 737.2323770318734 is not greater than 737.2528966767251. Delta is -0.020519644851674457
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 748.4913446546665 is not greater than 749.2283377084116. Delta is -0.7369930537450955
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 748.460948278875 is not greater than 748.4959445116181. Delta is -0.034996232743083056
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 738.5368400661364 is not greater than 738.5408296889472. Delta is -0.003989622810763649
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 747.6583225624147 is not greater than 747.7196003778319. Delta is -0.06127781541715649
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 745.4654643928088 is not greater than 745.5586797478439. Delta is -0.09321535503511313
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 748.1695910197567 is not greater than 748.2435922062389. Delta is -0.07400118648217813
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 746.1455291615351 is not greater than 746.2828415709437. Delta is -0.13731240940853695
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 738.4270431092642 is not greater than 738.4651917885642. Delta is -0.03814867929997945
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 745.8863738749765 is not greater than 745.9799978280669. Delta is -0.09362395309040039
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 756.4637490662353 is not greater than 757.6841073442624. Delta is -1.2203582780271063
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 751.7866057822365 is not greater than 751.8029246386582. Delta is -0.01631885642166253
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 758.8242276284233 is not greater than 759.4204961149552. Delta is -0.5962684865319261
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 754.5934038868324 is not greater than 754.6098629341756. Delta is -0.016459047343118982
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 754.2020288776755 is not greater than 754.2972956890644. Delta is -0.09526681138891036
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 758.748624770976 is not greater than 759.2008223535646. Delta is -0.4521975825886102
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.6173877736816 is not greater than 744.7085986122897. Delta is -0.0912108386081627
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 758.5411280710208 is not greater than 758.8236146962596. Delta is -0.2824866252387892
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 757.9162542030556 is not greater than 757.9224986467227. Delta is -0.0062444436671285075
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.1621578357801 is not greater than 744.178792083767. Delta is -0.016634247986871742
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 745.1944198962582 is not greater than 745.2187073166314. Delta is -0.024287420373184432
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 755.7367581588445 is not greater than 755.9777436889697. Delta is -0.24098553012515822
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 757.6893527056513 is not greater than 757.8218759572655. Delta is -0.1325232516142023
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 755.819593869012 is not greater than 755.8472179278418. Delta is -0.027624058829815112
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 758.8115011757916 is not greater than 758.9164780805789. Delta is -0.10497690478734967
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 758.8699251752603 is not greater than 758.9943704362762. Delta is -0.12444526101592146
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 759.8428813797277 is not greater than 759.9855021175483. Delta is -0.14262073782060725
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# Model is not converging.  Current: 759.1574123351577 is not greater than 759.2668059166665. Delta is -0.10939358150881162
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 759.8440145388306 is not greater than 759.9457411767792. Delta is -0.10172663794855907
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 767.7844282398152 is not greater than 768.9332469650475. Delta is -1.1488187252323314
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 760.3260561874954 is not greater than 760.3307389061671. Delta is -0.004682718671688235
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 759.3651576233422 is not greater than 759.3788982791842. Delta is -0.013740655842070737
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 761.6728656389867 is not greater than 762.6131300954017. Delta is -0.9402644564150933
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 761.1843720313319 is not greater than 761.2890025319009. Delta is -0.10463050056898737
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 761.3800643818722 is not greater than 761.7352557130783. Delta is -0.3551913312061288
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 758.6854553242869 is not greater than 759.3543629597004. Delta is -0.668907635413575
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 750.7930271288844 is not greater than 750.8356850796903. Delta is -0.04265795080584667
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 758.3995728720882 is not greater than 758.8945026626242. Delta is -0.49492979053593444
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 759.0456247825981 is not greater than 759.0493710440526. Delta is -0.0037462614544665485
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 755.4687102586674 is not greater than 756.0982567511646. Delta is -0.6295464924971839
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 757.4868345830553 is not greater than 757.9410502819688. Delta is -0.45421569891357194
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 756.9602526461246 is not greater than 757.0748277694075. Delta is -0.11457512328297526
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 757.5729957485117 is not greater than 757.7578163864887. Delta is -0.18482063797694082
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.4686099750468 is not greater than 744.8498110323928. Delta is -0.38120105734606113
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 753.7785075085889 is not greater than 754.1346600721208. Delta is -0.356152563531964
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 753.4159722957535 is not greater than 753.6499401830897. Delta is -0.23396788733623453
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 754.0864015202648 is not greater than 754.3896172949247. Delta is -0.30321577465997507
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 749.8769871698863 is not greater than 750.1367104378319. Delta is -0.2597232679455601
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 752.3457253868523 is not greater than 752.567130712271. Delta is -0.22140532541868652
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 752.8269571504414 is not greater than 752.9456415509536. Delta is -0.11868440051216567
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 749.7037846380955 is not greater than 749.84450136112. Delta is -0.14071672302452498
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 749.570319322354 is not greater than 749.6000531455273. Delta is -0.029733823173387464
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 750.212299915574 is not greater than 750.7724193610371. Delta is -0.5601194454631013
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 749.9343046131204 is not greater than 750.0011648060076. Delta is -0.06686019288724765
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# ...
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 743.1991763224138 is not greater than 743.2616566384033. Delta is -0.0624803159895464
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# 3949
# 3950
# 3951
# 3952
# 3953
# 3954
# 3955
# 3956
# 3957
# 3958
# 3959
# 3960
# 3961
# 3962
# 3963
# 3964
# 3965
# 3966
# 3967
# 3968
# 3969
# 3970
# 3971
# 3972
# 3973
# 3974
# 3975
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 745.2706723178504 is not greater than 745.3047993366135. Delta is -0.0341270187631153
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 734.8763405394635 is not greater than 734.9449391973798. Delta is -0.06859865791625452
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.4822395686731 is not greater than 744.5976064722272. Delta is -0.11536690355410428
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.9507403961768 is not greater than 744.9835684276552. Delta is -0.03282803147840241
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 745.0680263762158 is not greater than 745.1603978819782. Delta is -0.09237150576234399
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 746.1144712113121 is not greater than 746.1443798595766. Delta is -0.02990864826449524
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 744.7276629739658 is not greater than 744.7486177146737. Delta is -0.02095474070790715
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 742.2677137108371 is not greater than 742.2893783367466. Delta is -0.02166462590946594
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 741.4383925711498 is not greater than 741.4803212093165. Delta is -0.041928638166609744
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 741.8658492628269 is not greater than 741.963578053605. Delta is -0.09772879077809193
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 742.0676034077818 is not greater than 742.1226144106823. Delta is -0.05501100290052818
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 740.7820146849087 is not greater than 741.109266651852. Delta is -0.32725196694320857
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 742.108400921165 is not greater than 742.2011470693471. Delta is -0.09274614818218652
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 739.57813341483 is not greater than 739.9506724074624. Delta is -0.37253899263248513
# Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# Even though the 'means_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'm'
# Even though the 'covars_' attribute is set, it will be overwritten during initialization because 'init_params' contains 'c'
# Model is not converging.  Current: 742.6589816936215 is not greater than 742.72105958223. Delta is -0.0620778886085418
# 3976
# 3977
# 3978
# 3979
# 3980
# 3981
# 3982
# 3983
# 3984
# 3985
# 3986
# 3987
# 3988
# 3989
# 3990
# 3991
# 3992
# 3993
# 3994
# 3995
# 3996
# 3997
# 3998
# 3999

# %%
# 2) Volatility regime
df_rv = df_orig[['Close']].sort_index(ascending=True).copy()
shift = 3
df_rv['logr_5'] = np.log(abs(df_rv['Close'] / df_rv['Close'].shift(shift)))

r = df_rv['logr_5']
rv = r.rolling(14).std()
vol_rank = rv.rolling(252).apply(lambda x: x.rank(pct=True).iloc[-1], raw=False)
vol_regime_3_14_252 = pd.cut(vol_rank, bins=[-1, 0.25, 0.5, 0.75, 1.01], labels=[0, 1, 2, 3])

# %% [markdown]
# # Challenger - Incumbent Logic

# %%
def perm_importance(all_perm_dfs):

    # Combine all permutation importance DataFrames
    current_perm_df = pd.concat(all_perm_dfs, ignore_index=True)

    # Apply the retention logic per group
    def apply_retention_logic(group):
        group = group.copy()
        group["drop_flag"] = group["importance_mean"] <= 0.01

        total = len(group)
        retained = (~group["drop_flag"]).sum()
        min_retained = int(np.ceil(total * 0.45))

        if retained < min_retained:
            top_feats = group.sort_values(by="importance_mean", ascending=False).head(min_retained)["feature"]
            group["drop_flag"] = ~group["feature"].isin(top_feats)

        return group

    # Apply group-wise adjustment by model_name, arch, horizon
    current_perm_df = current_perm_df.apply(apply_retention_logic)
    
    return current_perm_df

def print_metrics(metrics):
        for thresh, metric_values in metrics.items():
            i = 1
            #print(f"{thresh}: {metric_values}")
  
def optimize_splits_new(df_indicators, df_predict, thresh, opt, test_size, e, name, return_metrics=False):
    
    def train_no_eval(model, param_grid, X_train, y_train, X_test, y_test, opt, thresh, iter, name):

        model.set_params(n_jobs=1)
        random_search = RandomizedSearchCV(
            estimator=model,
            param_distributions=param_grid,
            scoring=opt,
            cv=TimeSeriesSplit(n_splits=8),
            n_jobs=-1,
            n_iter=iter,
            random_state=42
        )
        
        #X_test = X_train.iloc[len(X_train) - 300:]
        #y_test = y_train.iloc[len(y_train) - 300:]
        random_search.fit(X_train, y_train, verbose=False)
        best_model = random_search.best_estimator_
        y_prob = best_model.predict_proba(X_test)
        postot = y_test.sum()
        negtot = len(y_test) - y_test.sum()

        metrics = {}
        for t in thresh:
            y_pred_thresh = (y_prob[:, 1] > t).astype(int)
            y_pred_thresh[y_prob[:, 0] > t] = 0
            filtered_indices = (y_prob[:, 1] > t) | (y_prob[:, 0] > t)
            actpos = int(y_test.sum())        # actual positives
            actneg = int(len(y_test) - actpos)  # actual negatives

            if filtered_indices.sum() > 0:
                y_test_valid = y_test[filtered_indices]
                y_pred_valid = y_pred_thresh[filtered_indices]
                posprec = round(precision_score(y_test_valid, y_pred_valid, pos_label=1, zero_division=0), 2)
                negprec = round(precision_score(y_test_valid, y_pred_valid, pos_label=0, zero_division=0), 2)
                predpos = sum(y_pred_valid == 1)
                predneg = sum(y_pred_valid == 0)
                posrec = round(posprec * predpos / postot, 2) if postot else 0
                negrec = round(negprec * predneg / negtot, 2) if negtot else 0
                pos_denom = (2*posrec)+(1*posprec)
                neg_denom = (2*negrec)+(1*negprec)
                posfb = round((3*posprec*posrec)/pos_denom, 2) if pos_denom else 0
                negfb = round((3*negprec*negrec)/neg_denom, 2) if neg_denom else 0
                metrics[t] = {
                    "Name": name,
                    "PAC": actpos,
                    "PPC": predpos,
                    "NAC": actneg,
                    "NPC": predneg,
                    "PP": posprec,
                    "PR": posrec,
                    "NP": negprec,
                    "NR": negrec,
                    "PosFb": posfb,
                    "NegFb": negfb,
                    "Retained": round(((predpos + predneg) / len(y_test)),2)
                }
                metrics[t] = {k: np.nan_to_num(v, nan=0.0) for k, v in metrics[t].items()}
            
        return metrics, best_model
    
    def train_with_eval(model, param_grid, X_train, y_train, X_tune, y_tune, X_test, y_test, opt, thresh, iter, name):

        model.set_params(n_jobs=1)
        random_search = RandomizedSearchCV(
            estimator=model,
            param_distributions=param_grid,
            scoring=opt,
            cv=4,
            n_jobs=-1,
            n_iter=iter,
            random_state=42
        )
        
        random_search.fit(X_train, y_train, eval_set=[(X_tune, y_tune)], verbose=False)
        best_model = random_search.best_estimator_
        y_prob = best_model.predict_proba(X_test)
        postot = y_test.sum()
        negtot = len(y_test) - y_test.sum()

        metrics = {}
        for t in thresh:
            y_pred_thresh = (y_prob[:, 1] > t).astype(int)
            y_pred_thresh[y_prob[:, 0] > t] = 0
            filtered_indices = (y_prob[:, 1] > t) | (y_prob[:, 0] > t)
            actpos = int(y_test.sum())        # actual positives
            actneg = int(len(y_test) - actpos)  # actual negatives

            if filtered_indices.sum() > 0:
                y_test_valid = y_test[filtered_indices]
                y_pred_valid = y_pred_thresh[filtered_indices]
                posprec = round(precision_score(y_test_valid, y_pred_valid, pos_label=1, zero_division=0), 2)
                negprec = round(precision_score(y_test_valid, y_pred_valid, pos_label=0, zero_division=0), 2)
                predpos = sum(y_pred_valid == 1)
                predneg = sum(y_pred_valid == 0)
                posrec = round(posprec * predpos / postot, 2) if postot else 0
                negrec = round(negprec * predneg / negtot, 2) if negtot else 0
                pos_denom = (2*posrec)+(1*posprec)
                neg_denom = (2*negrec)+(1*negprec)
                posfb = round((3*posprec*posrec)/pos_denom, 2) if pos_denom else 0
                negfb = round((3*negprec*negrec)/neg_denom, 2) if neg_denom else 0
                metrics[t] = {
                    "Name": name,
                    "PAC": actpos,
                    "PPC": predpos,
                    "NAC": actneg,
                    "NPC": predneg,
                    "PP": posprec,
                    "PR": posrec,
                    "NP": negprec,
                    "NR": negrec,
                    "PosFb": posfb,
                    "NegFb": negfb,
                    "PredsRetained": round(((predpos + predneg) / len(y_test)),2)
                }
                metrics[t] = {k: np.nan_to_num(v, nan=0.0) for k, v in metrics[t].items()}
            
        return metrics, best_model

    iter = 50
    
    # Deep
    if e == 'Y': # use eval set

        tune_size = 200 + test_size

        X_test = df_indicators.iloc[:test_size].copy()
        y_test = df_predict.iloc[:test_size].copy()

        X_tune = df_indicators.iloc[test_size:tune_size+test_size].copy()
        y_tune = df_predict.iloc[test_size:tune_size+test_size].copy()

        X_train = df_indicators.iloc[tune_size+test_size:].sort_index(ascending=True).copy()
        y_train = df_predict.iloc[tune_size+test_size:].sort_index(ascending=True).copy()

        xgboost_hyperparameters = {
            'max_depth': [3, 6, 9],
            'learning_rate': [0.01, 0.05],    # Lower rates
            'min_child_weight': [6, 10],   # More conservative splits
            'subsample': [0.7, 0.8, 0.9],     
            'colsample_bytree': [0.75, 0.85], 
            'colsample_bylevel': [0.7, 0.8],
            'colsample_bynode': [0.7, 0.8],    
            'gamma': [0.3, 0.5],         
            'alpha': [0.5, 1.0], 
            'lambda': [10, 15],            
            'n_estimators': [200, 400, 600], 
            'early_stopping_rounds': [10]
            }
        
        xg_metrics, best_xg_model = train_with_eval(XGBClassifier(random_state=42), xgboost_hyperparameters, X_train, y_train, 
                                                    X_tune, y_tune, X_test, y_test, opt, thresh, iter, name)
    
    else: # no eval set

        X_test = df_indicators.iloc[:test_size].copy()
        y_test = df_predict.iloc[:test_size].copy()
        
        X_train = df_indicators.iloc[test_size:].sort_index(ascending=True).copy()
        y_train = df_predict.iloc[test_size:].sort_index(ascending=True).copy()

        xgboost_hyperparameters = {
            'max_depth': [3, 6, 9],
            'learning_rate': [0.01, 0.05],    # Lower rates
            'min_child_weight': [10],   # More conservative splits
            'subsample': [0.7, 0.8, 0.9],     
            'colsample_bytree': [0.75, 0.85], 
            'colsample_bylevel': [0.7, 0.8],
            'colsample_bynode': [0.7, 0.8],    
            'gamma': [0.3, 0.5],         
            'alpha': [0.5, 1.0], 
            'lambda': [10, 15],            
            'n_estimators': [200, 400], 
            }
        
        xg_metrics, best_xg_model = train_no_eval(XGBClassifier(random_state=42), xgboost_hyperparameters, X_train, y_train, 
                                                  X_test, y_test, opt, thresh, iter, name)
    
    print_metrics(xg_metrics)

    if return_metrics:
        return best_xg_model, xg_metrics
    else:
        #print_metrics(xg_metrics)
        return best_xg_model, best_score

def optimize_rs(df_indicators, df_predict, thresh, opt, test_size, name, return_metrics=False):
    
    def train_and_evaluate(model, param_grid, X_train, y_train, X_tune, y_tune, X_test, y_test, opt, thresh, iter, name):

        model.set_params(n_jobs=1)
        random_search = RandomizedSearchCV(
            estimator=model,
            param_distributions=param_grid,
            scoring=opt,
            cv=StratifiedKFold(n_splits=4, shuffle=True, random_state=42),
            n_jobs=-1,
            n_iter=iter,
            random_state=42
        )
        
        random_search.fit(X_train, y_train, eval_set=[(X_tune, y_tune)], verbose=False)
        best_model = random_search.best_estimator_
        #best_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False)
        y_prob = best_model.predict_proba(X_test)
        postot = y_test.sum()
        negtot = len(y_test) - y_test.sum()

        metrics = {}
        for t in thresh:
            y_pred_thresh = (y_prob[:, 1] > t).astype(int)
            y_pred_thresh[y_prob[:, 0] > t] = 0
            filtered_indices = (y_prob[:, 1] > t) | (y_prob[:, 0] > t)
            actpos = int(y_test.sum())        # actual positives
            actneg = int(len(y_test) - actpos)  # actual negatives

            if filtered_indices.sum() > 0:
                y_test_valid = y_test[filtered_indices]
                y_pred_valid = y_pred_thresh[filtered_indices]
                posprec = round(precision_score(y_test_valid, y_pred_valid, pos_label=1, zero_division=0), 2)
                negprec = round(precision_score(y_test_valid, y_pred_valid, pos_label=0, zero_division=0), 2)
                predpos = sum(y_pred_valid == 1)
                predneg = sum(y_pred_valid == 0)
                posrec = round(posprec * predpos / postot, 2) if postot else 0
                negrec = round(negprec * predneg / negtot, 2) if negtot else 0
                pos_denom = (2*posrec)+(1*posprec)
                neg_denom = (2*negrec)+(1*negprec)
                posfb = round((3*posprec*posrec)/pos_denom, 2) if pos_denom else 0
                negfb = round((3*negprec*negrec)/neg_denom, 2) if neg_denom else 0
                metrics[t] = {
                    "Name": name,
                    "PAC": actpos,
                    "PPC": predpos,
                    "NAC": actneg,
                    "NPC": predneg,
                    "PP": posprec,
                    "PR": posrec,
                    "NP": negprec,
                    "NR": negrec,
                    "PosFb": posfb,
                    "NegFb": negfb,
                    "Retained": round(((predpos + predneg) / len(y_test)),2)
                }
                metrics[t] = {k: np.nan_to_num(v, nan=0.0) for k, v in metrics[t].items()}
            
        return metrics, best_model

    X_test = df_indicators.iloc[:test_size].copy()
    y_test = df_predict.iloc[:test_size].copy()
    
    df_indicators = df_indicators.iloc[test_size:].sort_index(ascending=True).copy()
    df_predict = df_predict.iloc[test_size:].sort_index(ascending=True).copy()
    X_train, X_tune, y_train, y_tune = train_test_split(df_indicators, df_predict, test_size=0.3, random_state=42, shuffle=True)

    counts = y_train.value_counts()
    negf = counts.get(0, 0)
    posf = counts.get(1, 1)  # prevent division by zero
    scale_pos_weight = negf / posf

    xgboost_hyperparameters = {
        #'scale_pos_weight': [scale_pos_weight],
        'max_depth': [3, 6, 9],
        'learning_rate': [0.01, 0.05],    # Lower rates
        'min_child_weight': [6, 10],   # More conservative splits
        'subsample': [0.7, 0.8, 0.9],     
        'colsample_bytree': [0.75, 0.85], 
        'colsample_bylevel': [0.7, 0.8],
        'colsample_bynode': [0.7, 0.8],    
        'gamma': [0.3, 0.5],         
        'alpha': [0.5, 1.0], 
        'lambda': [10, 15],            
        'n_estimators': [200, 400, 600], 
        'early_stopping_rounds': [10]
        }

    iter = 50

    # Train and evaluate models
    xg_metrics, best_xg_model = train_and_evaluate(XGBClassifier(random_state=42), xgboost_hyperparameters, X_train, y_train, X_tune, y_tune, 
                                                               X_test, y_test, opt, thresh, iter, name)
    print_metrics(xg_metrics)

    if return_metrics:
        return best_xg_model, xg_metrics
    else:
        #print_metrics(xg_metrics)
        return best_xg_model, best_score

def add_run(metrics, metrics_df):

    # convert to DataFrame and include threshold as a column
    df_run = pd.DataFrame.from_dict(metrics, orient='index').reset_index().rename(columns={'index': 'Threshold'})
    df_run['Start_Date'] = df_ph['Date'].iloc[test_size]
    df_run['End_Date'] = df_ph['Date'].iloc[0]
    df_run['LB'] = lb

    # then append to a cumulative DataFrame
    try:
        metrics_df = pd.concat([metrics_df, df_run], ignore_index=True)
    except NameError:
        metrics_df = df_run.copy()

    # PosFb: if PAC==0 and PPC==0, set to 1, else keep current
    metrics_df['PosFb'] = np.where((metrics_df['PAC'] == 0) & (metrics_df['PPC'] == 0), 1, metrics_df['PosFb'])

    # NegFb: if NAC==0 and NPC==0, set to 1, else keep current
    metrics_df['NegFb'] = np.where((metrics_df['NAC'] == 0) & (metrics_df['NPC'] == 0), 1, metrics_df['NegFb'])

    return metrics_df

def visualize_performance(metrics_df):
    
    metrics_df['Actual_Distribution'] = round(metrics_df['PAC']/ (metrics_df['PAC'] + metrics_df['NAC']), 2)
    cols = ['PosFb', 'NegFb']

    for col in cols:

        # Assume your DataFrame is called df
        # Convert Start_Date to datetime
        df_vis = metrics_df[metrics_df['Name'].isin(['Incumbent', 'Challenger'])].copy()
        df_vis['Start_Date'] = pd.to_datetime(df_vis['Start_Date'])

        # One line per unique Name
        fig, ax1 = plt.subplots(figsize=(12,4))

        for name, group in df_vis.groupby('Name'):
            ax1.plot(group['Start_Date'], group[col], marker='o', label=name)

        ax1.set_xlabel('Start Date')
        ax1.set_ylabel(col)
        ax1.legend(title='Name', bbox_to_anchor=(1.05,1), loc='upper left')

        # Add Actual_Distribution on secondary y-axis
        ax2 = ax1.twinx()
        actual = df_vis.groupby('Start_Date')['Actual_Distribution'].first()
        ax2.plot(actual.index, actual.values, color='black', linestyle='--', linewidth=2, label='Actual Distribution')
        ax2.set_ylabel('Actual Distribution')

        # Combine legends
        lines, labels = ax1.get_legend_handles_labels()
        lines2, labels2 = ax2.get_legend_handles_labels()
        ax1.legend(lines + lines2, labels + labels2, bbox_to_anchor=(1.15,1), loc='upper left')

        plt.title(f'{col} by Start Date (lines per Name) with Actual Distribution')
        plt.tight_layout()
        plt.show()

ticker = 'QQQ'
thresh = [.55] # minimum confidence by model for predictions to be included
results = [] # for storing performance of single run
returns = [1] # list of time horizons to test
test_size = 5 # used for size of test set if using eval set with optimize_splits_new
lbs = [9] # lookback years for training data
eval = ['N'] # Can be Y or N, Y means use an eval set with optimize_splits_new
metrics_df = pd.DataFrame() # initialize df for storing performance of multiple runs
all_perm_dfs = [] # stores results of permutation importance for each run
perm_size = 300 # size of permutation importance 
offset_size = test_size # if doing multiple time series, this value determines the step size
runs = 30 # number of runs to do

#df_orig = get_data(ticker) # extract pricing data
df_feats = ma_features(df_orig) # moving average features
df_returns = generate_returns(df_orig, returns) # generate target variable
# merge returns and features table into one df
df_merged = pd.merge(df_feats, df_returns[[col for col in df_returns.columns if col.startswith('Return')] + ['Date']], on='Date') 

for r in returns:

    for i in range(runs): # number of runs to do

        offset = max(i * offset_size, 0) # step size for each run
        
        for lb in lbs: 

            for e in eval:

                df = df_merged.sort_values(by='Date', ascending=False).copy() # sort in descending order so newest records are at top
                cols = [col for col in df.iloc[:, 5:].columns if not col.startswith('Return')] # features only, 5: trims out Date, Close, High, Low, Volume
                record_length = 245 * lb # number of records to pull, 245 is about 1 year
                df_ph = df.iloc[offset:offset+record_length].copy()
                df_ph = df_ph.iloc[r:].copy()
                return_col = f"Return_{r}"
                return_perc_col = f"Return%_{r}"

                rets = df_ph[return_perc_col].copy()
                # Split into negative and positive returns
                neg = rets[rets < 0]
                pos = rets[rets > 0]
                # Calculate dynamic thresholds
                neg_cutoff = neg.nlargest(int(len(neg) * 0.05)).min()  # least negative of top 10% in magnitude
                pos_cutoff = pos.nsmallest(int(len(pos) * 0.05)).max()  # smallest positive of top 10% in magnitude
                
                filtered = df_ph[(df_ph[f'Return%_{r}'] < neg_cutoff) | (df_ph[f'Return%_{r}'] > pos_cutoff)].copy()
                counts = filtered[return_col].value_counts()
                negf = counts.get(0, 0)
                posf = counts.get(1, 1)  # prevent division by zero
                #print(f'{posf} | {negf}')
                scale_pos_weight = negf / posf

                # Choose evaluation metric
                opt = 'matthews_corrcoef'
                prod_cols = cols

                used_cols = prod_cols + [return_col]
                df_model = filtered[used_cols].dropna()
                
                df_indicators = df_model[prod_cols]
                df_indicators = df_indicators.replace([np.inf, -np.inf], 0)
                df_predict = df_model[return_col]
                
                print(f'Run {i} of {runs} | LB: {lb} | {filtered['Date'].iloc[test_size]} - {filtered['Date'].iloc[0]}')
                """
                best_xg_model, metrics = optimize_splits_new(df_indicators, df_predict, thresh, opt, 
                                                             test_size, e, name=f'Temp_Orig-{lb}', return_metrics=True)
                metrics_df = add_run(metrics, metrics_df)
                """
                df_indicators2 = df_indicators[rev_cols].copy()
                best_xg_model, metrics = optimize_splits_new(df_indicators2, df_predict, thresh, opt, 
                                                             test_size, e, name=f'Incumbent', return_metrics=True)
                metrics_df = add_run(metrics, metrics_df)
                
                """
                opt = 'balanced_accuracy'
                best_xg_model, metrics = optimize_splits_new(df_indicators2, df_predict, thresh, opt, 
                                                             test_size, e, name=f'Incumbent', return_metrics=True)
                metrics_df = add_run(metrics, metrics_df)
                
                best_xg_model, metrics = optimize_rs(df_indicators, df_predict, thresh, opt, 
                                                     test_size, name=f'RS_Orig-{lb}', return_metrics=True)
                metrics_df = add_run(metrics, metrics_df)
                """
                df_indicators3 = df_indicators[rs_cols].copy()
                best_xg_model, metrics = optimize_rs(df_indicators3, df_predict, thresh, opt, 
                                                     test_size, name=f'Challenger', return_metrics=True)
                metrics_df = add_run(metrics, metrics_df)    
                
                """
                X_test = df_indicators.iloc[:perm_size].copy()
                y_test = df_predict.iloc[:perm_size].copy()
                
                # Run permutation importance
                perm = permutation_importance(best_xg_model, X_test, y_test, n_repeats=100, random_state=None, n_jobs=-1)

                # Organize into a DataFrame
                perm_df = pd.DataFrame({
                    'feature': df_indicators.columns,
                    'importance_mean': perm.importances_mean,
                    'importance_std': perm.importances_std,
                    'eval': e,
                    'horizon': r,
                    'split': 'Temporal',
                    'Start': df_ph['Date'].iloc[test_size],
                    'End': df_ph['Date'].iloc[0]
                })

                #all_perm_dfs.append(perm_df)
                #current_perm_df = perm_importance(perm_df)
                
                """

visualize_performance(metrics_df)
# Out:
# Run 0 of 30 | LB: 9 | 2025-10-23 - 2025-10-30
# Run 1 of 30 | LB: 9 | 2025-10-15 - 2025-10-23
# Run 2 of 30 | LB: 9 | 2025-10-09 - 2025-10-16
# Run 3 of 30 | LB: 9 | 2025-10-01 - 2025-10-09
# Run 4 of 30 | LB: 9 | 2025-09-25 - 2025-10-02
# Run 5 of 30 | LB: 9 | 2025-09-18 - 2025-09-25
# Run 6 of 30 | LB: 9 | 2025-09-10 - 2025-09-18
# Run 7 of 30 | LB: 9 | 2025-09-02 - 2025-09-11
# Run 8 of 30 | LB: 9 | 2025-08-26 - 2025-09-03
# Run 9 of 30 | LB: 9 | 2025-08-20 - 2025-08-27
# Run 10 of 30 | LB: 9 | 2025-08-08 - 2025-08-20
# Run 11 of 30 | LB: 9 | 2025-08-04 - 2025-08-11
# Run 12 of 30 | LB: 9 | 2025-07-30 - 2025-08-06
# Run 13 of 30 | LB: 9 | 2025-07-22 - 2025-07-30
# Run 14 of 30 | LB: 9 | 2025-07-11 - 2025-07-23
# Run 15 of 30 | LB: 9 | 2025-07-02 - 2025-07-16
# Run 16 of 30 | LB: 9 | 2025-06-27 - 2025-07-08
# Run 17 of 30 | LB: 9 | 2025-06-24 - 2025-07-01
# Run 18 of 30 | LB: 9 | 2025-06-13 - 2025-06-24
# Run 19 of 30 | LB: 9 | 2025-06-09 - 2025-06-16
# Run 20 of 30 | LB: 9 | 2025-05-30 - 2025-06-09
# Run 21 of 30 | LB: 9 | 2025-05-23 - 2025-06-02
# Run 22 of 30 | LB: 9 | 2025-05-15 - 2025-05-23
# Run 23 of 30 | LB: 9 | 2025-05-06 - 2025-05-15
# Run 24 of 30 | LB: 9 | 2025-05-01 - 2025-05-09
# Run 25 of 30 | LB: 9 | 2025-04-23 - 2025-05-02
# Run 26 of 30 | LB: 9 | 2025-04-15 - 2025-04-24
# Run 27 of 30 | LB: 9 | 2025-04-08 - 2025-04-17
# Run 28 of 30 | LB: 9 | 2025-04-03 - 2025-04-10
# Run 29 of 30 | LB: 9 | 2025-03-26 - 2025-04-03

# %%
import matplotlib.pyplot as plt
import pandas as pd

df_vis = metrics_df[metrics_df['Name'].isin(['Temp_Trim-MCC-9', 'Temp_Trim-LL-9'])].copy()
df_vis['Start_Date'] = pd.to_datetime(df_vis['Start_Date'])

# actual distribution per Start_Date
actual = df_vis.groupby('Start_Date')['Actual_Distribution'].first()

color_map = {
    'Temp_Trim-MCC-9': 'tab:blue',
    'Temp_Trim-LL-9': 'tab:orange'
}

fig, ax1 = plt.subplots(figsize=(12,5))

# PosFb (solid)
for name, group in df_vis.groupby('Name'):
    ax1.plot(
        group['Start_Date'], group['PosFb'],
        marker='o', linestyle='-',
        color=color_map[name],
        label=f'{name} PosFb'
    )

# NegFb (dashed)
for name, group in df_vis.groupby('Name'):
    ax1.plot(
        group['Start_Date'], group['NegFb'],
        marker='s', linestyle='--',
        color=color_map[name],
        label=f'{name} NegFb'
    )

# Actual distribution (black solid)
ax1.plot(
    actual.index, actual.values,
    color='black', linestyle='-', linewidth=2, alpha=0.7,
    label='Actual Distribution'
)

ax1.set_xlabel('Start Date')
ax1.set_ylabel('Value')
ax1.set_ylim(-0.05, 1.05)

ax1.legend(title='Metrics', bbox_to_anchor=(1.05,1), loc='upper left')
plt.title('PosFb & NegFb with Actual Distribution (single axis)')
plt.tight_layout()
plt.show()

# %%
top = perm_df.sort_values(by='importance_mean', ascending=False)
rs_cols = top['feature'].iloc[:10].to_list()
rs_cols
# Out:
# ['num_days_200',
#  'num_days_50',
#  'Min_240_Rows_Since',
#  'Min_60_Rows_Since',
#  'Close_Rel_Min200',
#  '25_SMA_100',
#  'Min_10_Rows_Since',
#  'Close_Rel_Min10',
#  'SMA_5',
#  'Min_120_Rows_Since']

# %%
current_perm_df = perm_df.copy()

# Apply the retention logic per group
def apply_retention_logic(group):
    group = group.copy()
    group["drop_flag"] = group["importance_mean"] <= 0.01

    total = len(group)
    retained = (~group["drop_flag"]).sum()
    min_retained = int(np.ceil(total * 0.45))

    if retained < min_retained:
        top_feats = group.sort_values(by="importance_mean", ascending=False).head(min_retained)["feature"]
        group["drop_flag"] = ~group["feature"].isin(top_feats)

    return group

# Apply group-wise adjustment by model_name, arch, horizon
final_perm_df = current_perm_df.apply(apply_retention_logic)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/brettchase/Documents/Fracturion/Ensemble_Aggregation_Allocation_Logic/Categorical.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/Users/brettchase/Documents/Fracturion/Ensemble_Aggregation_Allocation_Logic/Categorical.ipynb#Y314sZmlsZQ%3D%3D?line=15'>16</a>     return group
#      <a href='vscode-notebook-cell:/Users/brettchase/Documents/Fracturion/Ensemble_Aggregation_Allocation_Logic/Categorical.ipynb#Y314sZmlsZQ%3D%3D?line=17'>18</a> # Apply group-wise adjustment by model_name, arch, horizon
# ---> <a href='vscode-notebook-cell:/Users/brettchase/Documents/Fracturion/Ensemble_Aggregation_Allocation_Logic/Categorical.ipynb#Y314sZmlsZQ%3D%3D?line=18'>19</a> final_perm_df = current_perm_df.apply(apply_retention_logic)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# /Users/brettchase/Documents/Fracturion/Ensemble_Aggregation_Allocation_Logic/Categorical.ipynb Cell 10 line 6
#       <a href='vscode-notebook-cell:/Users/brettchase/Documents/Fracturion/Ensemble_Aggregation_Allocation_Logic/Categorical.ipynb#Y314sZmlsZQ%3D%3D?line=3'>4</a> def apply_retention_logic(group):
#       <a href='vscode-notebook-cell:/Users/brettchase/Documents/Fracturion/Ensemble_Aggregation_Allocation_Logic/Categorical.ipynb#Y314sZmlsZQ%3D%3D?line=4'>5</a>     group = group.copy()
# ----> <a href='vscode-notebook-cell:/Users/brettchase/Documents/Fracturion/Ensemble_Aggregation_Allocation_Logic/Categorical.ipynb#Y314sZmlsZQ%3D%3D?line=5'>6</a>     group["drop_flag"] = group["importance_mean"] <= 0.01
#       <a href='vscode-notebook-cell:/Users/brettchase/Documents/Fracturion/Ensemble_Aggregation_Allocation_Logic/Categorical.ipynb#Y314sZmlsZQ%3D%3D?line=7'>8</a>     total = len(group)
#       <a href='vscode-notebook-cell:/Users/brettchase/Documents/Fracturion/Ensemble_Aggregation_Allocation_Logic/Categorical.ipynb#Y314sZmlsZQ%3D%3D?line=8'>9</a>     retained = (~group["drop_flag"]).sum()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'importance_mean'

# %% [markdown]
# # Variable Visualizations

# %%
from itertools import combinations
from matplotlib.colors import TwoSlopeNorm
import seaborn as sns

def plot_univariate_feature_indicator_weight(df, feature, return_col, bins=5):
    """
    Plots a univariate heatmap: feature bin (x) vs year (y), cell = mean return.

    Parameters:
        df (pd.DataFrame): Must include 'Date', feature, and return_col
        feature (str): The feature to bin along the x-axis
        return_col (str): Target column
        bins (int): Number of quantile bins for the feature
    """
    
    df = df[['Date', feature, return_col]].dropna()
    current_value = df[feature].iloc[-1]
    df['year'] = pd.to_datetime(df['Date']).dt.year
    #df['feature_bin'] = df[feature].astype(int)
    df['feature_bin'] = pd.qcut(df[feature], q=bins, duplicates="drop")
    #df['feature_bin'] = pd.cut(df[feature], bins=bins, include_lowest=True)


    grouped = df.groupby(['year', 'feature_bin'], observed=True)
    mean_values = grouped[return_col].mean().unstack()
    count_values = grouped.size().unstack()

    annotations = mean_values.astype("object")
    for r in mean_values.index:
        for c in mean_values.columns:
            val = mean_values.loc[r, c]
            cnt = count_values.loc[r, c]
            if pd.notna(val) and pd.notna(cnt):
                annotations.loc[r, c] = f"{val:.2f}\n(n={int(cnt)})"
            else:
                annotations.loc[r, c] = ""

    plt.figure(figsize=(9, 6))
    norm = TwoSlopeNorm(vmin=0, vcenter=0.5, vmax=1)
    sns.heatmap(
        mean_values.astype(float),
        annot=annotations,
        fmt="",
        cmap="RdYlGn",
        norm=norm,
        cbar_kws={"label": f"Mean {return_col}"}
    )
    plt.title(f"{feature} vs Year | Mean {return_col} | cv: {current_value}")
    plt.xlabel("Feature Bin")
    plt.ylabel("Year")
    plt.tight_layout()
    plt.show()

ret_cols = [col for col in df_merged.columns if col.startswith('Return_') or col in ['Date', 'Close']]
cols = ['Max_5', 'Min_5', 'Max_10', 'Min_10', 'Max_20', 'Min_20', 'Max_50', 
        'Min_50', 'Max_100', 'Min_100', 'Max_200', 'Min_200']#indicators.to_list()
df_visualize = df_merged[ret_cols + cols].sort_index(ascending=False).iloc[:1500].round(2).copy()

returns = [5]
for r in returns:

    #df = add_column_based_on_future_value(df, r, binary)
    return_col = f"Return_{r}"
    df_cor = df_visualize.iloc[r:].copy()
    bins = [4]
    #method = 'mean_return'
    #df['SMA_50-SMA_100'] = df['QQQ_SMA_50'] - df['QQQ_SMA_100']

    for bin in bins:

        # Loop over all unique feature pairs
        for feature in cols:
            df_clean = df_cor.dropna().copy()
            plot_univariate_feature_indicator_weight(df_clean, feature, return_col, bins=bin)

# %%
def plot_bivariate_regimes(df, feature_x, feature_y, return_col, bins=5):
    """
    Plots a bivariate heatmap: feature_x (x-axis) vs feature_y (y-axis),
    with each cell showing the mean of return_col.

    Parameters:
        df (pd.DataFrame): Must include feature_x, feature_y, and return_col
        feature_x (str): First feature (x-axis)
        feature_y (str): Second feature (y-axis)
        return_col (str): Target column for averaging
        bins (int): Number of quantile bins for each feature
    """

    # Clean data
    df = df[[feature_x, feature_y, return_col]].dropna()
    cv1 = df[feature_x].iloc[-1]
    cv2 = df[feature_y].iloc[-1]

    # Bin both features into quantiles
    df['x_bin'] = df[feature_x].astype(int)
    #df['x_bin'] = pd.qcut(df[feature_x], q=1, duplicates='drop')
    df['y_bin'] = pd.qcut(df[feature_y], q=bins, duplicates='drop')

    # Group by both binned features
    grouped = df.groupby(['y_bin', 'x_bin'], observed=False)
    mean_values = grouped[return_col].mean().unstack()
    count_values = grouped.size().unstack()

    # Annotate with mean + sample size
    annotations = mean_values.astype("object")
    for r in mean_values.index:
        for c in mean_values.columns:
            val = mean_values.loc[r, c]
            cnt = count_values.loc[r, c]
            if pd.notna(val) and pd.notna(cnt):
                annotations.loc[r, c] = f"{val:.2f}\n(n={int(cnt)})"
            else:
                annotations.loc[r, c] = ""

    # Plot
    plt.figure(figsize=(6, 5))
    norm = TwoSlopeNorm(vmin=0, vcenter=0.5, vmax=1)
    sns.heatmap(
        mean_values.astype(float),
        annot=annotations,
        fmt="",
        cmap="RdYlGn",
        norm=norm,
        cbar_kws={"label": f"Mean {return_col}"}
    )

    plt.title(f"{feature_x} vs {feature_y} | Mean {return_col} | x/y: {cv1}-{cv2}")
    plt.xlabel(f"{feature_x} (binned)")
    plt.ylabel(f"{feature_y} (binned)")
    plt.tight_layout()
    plt.show()

indicators = df_feats.iloc[:, 37:38].columns
states = states.dropna()

regs = [vol_regime_3_14_252]
names = ['vol_regime_3_14_252']

returns = [1, 2, 3, 4, 5, 7, 10, 15, 20, 25, 40, 50]

for r in returns:

    for reg, name in zip(regs, names):

        df_regime = df_feats.merge(reg.rename('state'), left_index=True, right_index=True, how='inner')
        df_merged = pd.merge(df_regime, df_returns[[col for col in df_returns.columns if col.startswith('Return')] + ['Date']], on='Date')

        ret_cols = [col for col in df_merged.columns if col.startswith('Return_') or col in ['Date', 'Close']]
        cols = indicators.to_list()
        regime = ['state']
        df_visualize = df_merged[ret_cols + cols + regime].sort_index(ascending=False).iloc[r:1000].round(2).copy()
        binary = True

        #df = add_column_based_on_future_value(df, r, binary)
        return_col = f"Return_{r}"
        bins = [1]

        for bin in bins:

            # Loop over all unique feature pairs
            for feature in cols:
                try:
                    print(f"Plotting {feature} | {name}")
                    df_clean = df_visualize.copy()
                    plot_bivariate_regimes(df_clean, 'state', feature, return_col, bins=bin)
                except Exception as e:
                    print(f"Skipped {feature} due to error: {e}")
# Out:
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
# Plotting 10_SMA_25 | vol_regime_3_14_252
