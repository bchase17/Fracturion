# %%
import numpy as np
import pandas as pd
import datetime
import yfinance as yf
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# For importing universal scripts
import sys
import os
# Go up two levels from the subfolder
sys.path.append(os.path.abspath(".."))
from indicators_returns import final_df #Universal script for indicator set and actuals
import importlib
import indicators_returns
importlib.reload(indicators_returns)
from indicators_returns import final_df
import gc
from sklearn.metrics import (fbeta_score, accuracy_score, f1_score, 
                             confusion_matrix, balanced_accuracy_score, recall_score, matthews_corrcoef, precision_score)
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split, StratifiedKFold
from xgboost import XGBClassifier
import math
import pickle
from sklearn.inspection import permutation_importance
from sklearn.model_selection import TimeSeriesSplit, ParameterSampler, StratifiedKFold

tags = pd.read_csv('../Indicator_Selection_Pipeline/Finalization/tags_cons.csv') 

def extract(ticker, returns, cat_cols_all, windows=[10, 25]):

    import os
    # point this at an existing directory in your project
    os.chdir('/Users/brettchase/Documents/Fracturion/Feature_Set_Construction_Testing')
    
    df = final_df(ticker, returns)
    df = df.iloc[:-101].replace([np.inf, -np.inf], 0)#

    df = df.sort_index(ascending=True)
    # Exponential Moving Average
    ema_cols = {
        f"{col}_EMA{w}": df[col].ewm(span=w, adjust=False).mean()
        for w in windows
        for col in cat_cols_all
    }
    # 3) merge them back into one dict
    new_cols = {**ema_cols}

    # 4) concatenate onto your original df
    df = pd.concat([df, pd.DataFrame(new_cols, index=df.index)], axis=1)    
    df = df.sort_index(ascending=False)
    
    return df

# %% [markdown]
# # Start with must include columns (slope)

# %%
# -----------------------------
# Fetch and prepare data
# -----------------------------
def get_price_data(ticker='QQQ'):
    tickerData = yf.Ticker(ticker)
    df = tickerData.history(period="max", interval="1d", auto_adjust=True)
    df.dropna(inplace=True)
    df['Return'] = df['Close'].pct_change()
    df['LogRet'] = np.log(df['Close']).diff()
    return df


# -----------------------------
# Normalization helper
# -----------------------------
def rolling_zscore(series, window=252):
    mean = series.rolling(window).mean()
    std = series.rolling(window).std()
    return (series - mean) / std

# -----------------------------
# Trend indicators
# -----------------------------
def add_trend_features(df):
    for span in [20, 50, 200]:
        df[f'ma_{span}'] = df['Close'].rolling(span).mean()
        df[f'ma_ratio_{span}'] = df[f'ma_{span}'] / df['Close']
        df[f'ma_slope_{span}'] = (df[f'ma_{span}'].diff(5) / df['Close']).fillna(0)
    df['ma_ratio_20_50'] = df['ma_20'] / df['ma_50']
    df['ma_ratio_50_200'] = df['ma_50'] / df['ma_200']
    df['trend_breakout'] = (df['Close'] / df['Close'].rolling(100).max()) - 1
    df['ema_20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['ema_slope_20'] = (df['ema_20'].diff(5) / df['Close']).fillna(0)
    df['trend_z'] = rolling_zscore(df['Close'].pct_change(10), 252)
    return df

# -----------------------------
# Momentum indicators
# -----------------------------
def add_momentum_features(df):
    df['roc_10'] = df['Close'].pct_change(10)
    df['roc_20'] = df['Close'].pct_change(20)
    df['momentum_z_10'] = rolling_zscore(df['roc_10'], 252)
    df['momentum_z_20'] = rolling_zscore(df['roc_20'], 252)
    df['momentum_accel'] = df['roc_10'] - df['roc_10'].shift(10)
    df['log_ret_5'] = df['LogRet'].rolling(5).sum()
    df['log_ret_20'] = df['LogRet'].rolling(20).sum()
    df['rsi_14'] = 100 - (100 / (1 + (df['Return'].rolling(14).apply(
        lambda x: (x[x>0].mean() / abs(x[x<0].mean())) if abs(x[x<0].mean())>0 else 0
    ))))
    df['rsi_z'] = rolling_zscore(df['rsi_14'], 252)
    df['stoch_k'] = (df['Close'] - df['Low'].rolling(14).min()) / (df['High'].rolling(14).max() - df['Low'].rolling(14).min())
    df['stoch_d'] = df['stoch_k'].rolling(3).mean()
    df['stoch_z'] = rolling_zscore(df['stoch_k'], 252)
    return df

# -----------------------------
# Volume indicators
# -----------------------------
def add_volume_features(df):
    df['vol_ma_20'] = df['Volume'].rolling(20).mean()
    df['vol_ratio_5_20'] = df['Volume'].rolling(5).mean() / df['vol_ma_20']
    df['obv'] = (np.sign(df['Return']) * df['Volume']).fillna(0).cumsum()
    df['obv_norm'] = df['obv'] / df['obv'].rolling(252).mean()
    df['obv_z'] = rolling_zscore(df['obv'], 252)
    df['obv_slope'] = (df['obv'].diff(5) / df['obv'].rolling(60).mean())
    df['vwap'] = (df['Close'] * df['Volume']).cumsum() / df['Volume'].cumsum()
    df['price_vwap_diff'] = (df['Close'] - df['vwap']) / df['vwap']
    df['acc_dist'] = ((df['Close'] - df['Low']) - (df['High'] - df['Close'])) / (df['High'] - df['Low']) * df['Volume']
    df['acc_dist_cum'] = df['acc_dist'].cumsum()
    df['acc_dist_z'] = rolling_zscore(df['acc_dist_cum'], 252)
    return df

# -----------------------------
# Volatility indicators
# -----------------------------
def add_volatility_features(df):
    df['true_range'] = np.maximum(df['High'] - df['Low'],
                          np.maximum(abs(df['High'] - df['Close'].shift(1)),
                                     abs(df['Low'] - df['Close'].shift(1))))
    df['atr_14'] = df['true_range'].rolling(14).mean()
    df['atr_norm'] = df['atr_14'] / df['Close']
    df['vol_20'] = df['Return'].rolling(20).std()
    df['vol_60'] = df['Return'].rolling(60).std()
    df['vol_ratio_20_60'] = df['vol_20'] / df['vol_60']
    df['vol_z'] = rolling_zscore(df['vol_20'], 252)
    df['range_pct'] = (df['High'] - df['Low']) / df['Close']
    df['downside_vol'] = df['Return'].apply(lambda x: x if x < 0 else 0).rolling(20).std()
    df['downside_vol_norm'] = df['downside_vol'] / df['vol_20']
    df['vol_jump'] = (df['vol_20'] - df['vol_20'].shift(20)) / df['vol_20'].shift(20)
    return df

# -----------------------------
# Combine
# -----------------------------
def build_feature_set(ticker='QQQ', start='2010-01-01'):
    df = get_price_data(ticker, start)
    df = add_trend_features(df)
    df = add_momentum_features(df)
    df = add_volume_features(df)
    df = add_volatility_features(df)
    df.dropna(inplace=True)
    return df

if __name__ == "__main__":
    features_df = build_feature_set('QQQ', '2010-01-01')

features_df.sort_index(ascending=False)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-10-20 00:00:00-04:00  607.140015  612.799988  607.070007  611.539978
# 2025-10-17 00:00:00-04:00  597.950012  605.510010  596.369995  603.929993
# 2025-10-16 00:00:00-04:00  605.109985  608.309998  595.500000  599.989990
# 2025-10-15 00:00:00-04:00  604.010010  606.700012  595.929993  602.219971
# 2025-10-14 00:00:00-04:00  595.309998  602.690002  590.130005  598.000000
# ...                               ...         ...         ...         ...
# 2000-04-10 00:00:00-04:00   91.019865   91.072722   83.937018   84.677017
# 2000-04-07 00:00:00-04:00   88.059874   90.808441   86.791304   90.174156
# 2000-04-06 00:00:00-04:00   86.579879   87.848448   84.359882   86.685593
# 2000-04-05 00:00:00-04:00   82.457021   87.901298   81.399879   84.677017
# 2000-04-04 00:00:00-04:00   87.637033   87.901319   74.687050   86.209892
#
#                              Volume  Dividends  Stock Splits  Capital Gains  \
# Date
# 2025-10-20 00:00:00-04:00  45652200        0.0           0.0            0.0
# 2025-10-17 00:00:00-04:00  72024900        0.0           0.0            0.0
# 2025-10-16 00:00:00-04:00  70982000        0.0           0.0            0.0
# 2025-10-15 00:00:00-04:00  62805500        0.0           0.0            0.0
# 2025-10-14 00:00:00-04:00  69203200        0.0           0.0            0.0
# ...                             ...        ...           ...            ...
# 2000-04-10 00:00:00-04:00  26988200        0.0           0.0            0.0
# 2000-04-07 00:00:00-04:00  20645500        0.0           0.0            0.0
# 2000-04-06 00:00:00-04:00  30499900        0.0           0.0            0.0
# 2000-04-05 00:00:00-04:00  37631500        0.0           0.0            0.0
# 2000-04-04 00:00:00-04:00  66213000        0.0           0.0            0.0
#
#                              Return    LogRet  ...    atr_14    vol_20  \
# Date                                           ...
# 2025-10-20 00:00:00-04:00  0.012601  0.012522  ...  9.541425  0.011114
# 2025-10-17 00:00:00-04:00  0.006567  0.006545  ...  9.237143  0.010839
# 2025-10-16 00:00:00-04:00 -0.003703 -0.003710  ...  9.018572  0.010845
# 2025-10-15 00:00:00-04:00  0.007057  0.007032  ...  8.477857  0.010957
# 2025-10-14 00:00:00-04:00 -0.006661 -0.006683  ...  8.251426  0.010887
# ...                             ...       ...  ...       ...       ...
# 2000-04-10 00:00:00-04:00 -0.060961 -0.062899  ...  5.581140  0.034588
# 2000-04-07 00:00:00-04:00  0.040244  0.039455  ...  5.577365  0.032423
# 2000-04-06 00:00:00-04:00  0.023720  0.023443  ...  5.600018  0.030780
# 2000-04-05 00:00:00-04:00 -0.017781 -0.017941  ...  5.539610  0.031351
# 2000-04-04 00:00:00-04:00 -0.009715 -0.009762  ...  5.573589  0.031340
#
#                              vol_60  vol_ratio_20_60      hv_z  range_pct  \
# Date
# 2025-10-20 00:00:00-04:00  0.008958         1.240764 -0.193825   0.009370
# 2025-10-17 00:00:00-04:00  0.008836         1.226636 -0.227868   0.015134
# 2025-10-16 00:00:00-04:00  0.008809         1.231143 -0.226360   0.021350
# 2025-10-15 00:00:00-04:00  0.008797         1.245581 -0.210942   0.017884
# 2025-10-14 00:00:00-04:00  0.008802         1.236939 -0.218717   0.021003
# ...                             ...              ...       ...        ...
# 2000-04-10 00:00:00-04:00  0.029927         1.155755  1.435124   0.084270
# 2000-04-07 00:00:00-04:00  0.029697         1.091808  1.173206   0.044549
# 2000-04-06 00:00:00-04:00  0.029496         1.043536  0.973067   0.040244
# 2000-04-05 00:00:00-04:00  0.030107         1.041342  1.051733   0.076779
# 2000-04-04 00:00:00-04:00  0.030180         1.038462  1.057114   0.153280
#
#                            vol_jump  vol_slope  vol_correlation  downside_vol
# Date
# 2025-10-20 00:00:00-04:00  0.005490   0.000357         0.384311      0.007741
# 2025-10-17 00:00:00-04:00  0.004560   0.001002         0.365723      0.007741
# 2025-10-16 00:00:00-04:00  0.004399   0.005469         0.366484      0.007741
# 2025-10-15 00:00:00-04:00  0.004434   0.005594         0.385516      0.007780
# 2025-10-14 00:00:00-04:00  0.003546   0.005923         0.449869      0.007748
# ...                             ...        ...              ...           ...
# 2000-04-10 00:00:00-04:00  0.009506   0.003168         0.376434      0.021267
# 2000-04-07 00:00:00-04:00  0.007532   0.003860         0.386113      0.018793
# 2000-04-06 00:00:00-04:00  0.005319  -0.000171         0.405773      0.018627
# 2000-04-05 00:00:00-04:00  0.004923   0.000480         0.491626      0.018627
# 2000-04-04 00:00:00-04:00  0.003618   0.002154         0.491355      0.018952
#
# [6425 rows x 51 columns]

# %%
def print_metrics(metrics):
        for thresh, metric_values in metrics.items():
            print(f"  Threshold {thresh}: {metric_values}")
  
def optimize_splits_new(df_indicators, df_predict, thresh, opt, arch, test_size, withold, return_metrics=False):
    
    def train_and_evaluate(model, param_grid, X_train, y_train, X_test, y_test, opt, thresh, iter):

        def run_cv(cv_split, iter):

            model.set_params(n_jobs=1)
            random_search = RandomizedSearchCV(
                estimator=model,
                param_distributions=param_grid,
                scoring=opt,
                cv=cv_split,
                n_jobs=-1,
                n_iter=iter,
                random_state=42
            )
            
            random_search.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False)
            best_model = random_search.best_estimator_
            y_prob = best_model.predict_proba(X_test)
            postot = y_test.sum()
            negtot = len(y_test) - y_test.sum()

            metrics = {}
            for t in thresh:
                y_pred_thresh = (y_prob[:, 1] > t).astype(int)
                y_pred_thresh[y_prob[:, 0] > t] = 0
                filtered_indices = (y_prob[:, 1] > t) | (y_prob[:, 0] > t)

                if filtered_indices.sum() > 0:
                    y_test_valid = y_test[filtered_indices]
                    y_pred_valid = y_pred_thresh[filtered_indices]
                    posprec = round(precision_score(y_test_valid, y_pred_valid, pos_label=1, zero_division=0), 2)
                    negprec = round(precision_score(y_test_valid, y_pred_valid, pos_label=0, zero_division=0), 2)
                    poscnt = sum(y_pred_valid == 1)
                    negcnt = sum(y_pred_valid == 0)
                    posrec = round(posprec * poscnt / postot, 2)
                    negrec = round(negprec * negcnt / negtot, 2)
                    metrics[t] = {
                    "Len": len(y_test),
                    "PC": poscnt,
                    "NC": negcnt,
                    "PP": posprec,
                    "PR": posrec,
                    "NP": negprec,
                    "NR": negrec,
                    "PosFb": round((3*posprec*posrec)/((2*posrec)+(1*posprec)),3),
                    "NegFb": round((3*negprec*negrec)/((2*negrec)+(1*negprec)),3),
                    }
                    metrics[t] = {k: np.nan_to_num(v, nan=0.0) for k, v in metrics[t].items()}
                
            return metrics, best_model

        # Try all split values and pick best
        best_result = None
        best_score = -float("inf")

        split_values = [3, 4, 5]

        for splits in split_values:

            cv_split = TimeSeriesSplit(n_splits=splits)

            metrics, model = run_cv(cv_split, iter)

            # scoring method: average of PosFb and NegFb at first threshold
            t = list(metrics.keys())[0]
            avg_score = (metrics[t]["PosFb"] + metrics[t]["NegFb"]) / 2

            if avg_score > best_score:
                best_score = avg_score
                best_result = (metrics, model, splits)

        print(f"Best CV split: {best_result[2]} (score={best_score.round(2)})")
        
        return best_result[0], best_result[1], best_score

    X_test = df_indicators.iloc[:test_size].copy()
    y_test = df_predict.iloc[:test_size].copy()
    
    if withold == 'N':
        test_size = 0
    df_indicators = df_indicators.iloc[test_size:].sort_index(ascending=True).copy()
    df_predict = df_predict.iloc[test_size:].sort_index(ascending=True).copy()

    X_train = df_indicators.copy()
    y_train = df_predict.copy()

    counts = y_train.value_counts()
    negf = counts.get(0, 0)
    posf = counts.get(1, 1)  # prevent division by zero
    scale_pos_weight = negf / posf

    # Deep
    xgboost_hyperparameters = {
        'max_depth': [6, 9, 12],          # Still fairly deep
        'learning_rate': [0.01, 0.05],    # Lower rates
        'min_child_weight': [4, 7, 9, 12],   # More conservative splits
        'subsample': [0.7, 0.8, 0.9],     
        'colsample_bytree': [0.75, 0.85], 
        'colsample_bylevel': [0.7, 0.8, 0.9],
        'colsample_bynode': [0.7, 0.8, 0.9],    
        'gamma': [0.1, 0.3, 0.5],         
        'alpha': [0.1, 0.5, 1.0], 
        'lambda': [5, 10, 15],            
        'n_estimators': [800], 
        'early_stopping_rounds': [10]
        }

    iter = 50

    # Train and evaluate models
    xg_metrics, best_xg_model, best_score = train_and_evaluate(XGBClassifier(random_state=42), xgboost_hyperparameters, X_train, y_train, X_test, y_test, opt, thresh, iter)
    #record_validation_metrics(xg_metrics, arch='shallow', horizon=r, model_name=name)
    #savearch(best_xg_model, r, name, arch)
    metrics = list(xg_metrics.values())[0]
    pscore = metrics.get('PosFb', 0)
    nscore = metrics.get('NegFb', 0)
    
    print_metrics(xg_metrics)

    if return_metrics:
        return xg_metrics, best_xg_model
    else:
        #print_metrics(xg_metrics)
        return best_xg_model, best_score

def optimize_rs(df_indicators, df_predict, thresh, opt, arch, test_size, withold, return_metrics=False):
    
    def train_and_evaluate(model, param_grid, X_train, y_train, X_tune, y_tune, X_test, y_test, opt, thresh, iter):

        def run_cv(cv_split, iter):

            model.set_params(n_jobs=1)
            random_search = RandomizedSearchCV(
                estimator=model,
                param_distributions=param_grid,
                scoring=opt,
                cv=cv_split,
                n_jobs=-1,
                n_iter=iter,
                random_state=42
            )
            
            random_search.fit(X_train, y_train, eval_set=[(X_tune, y_tune)], verbose=False)
            best_model = random_search.best_estimator_
            best_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False)
            y_prob = best_model.predict_proba(X_test)
            postot = y_test.sum()
            negtot = len(y_test) - y_test.sum()

            metrics = {}
            for t in thresh:
                y_pred_thresh = (y_prob[:, 1] > t).astype(int)
                y_pred_thresh[y_prob[:, 0] > t] = 0
                filtered_indices = (y_prob[:, 1] > t) | (y_prob[:, 0] > t)

                if filtered_indices.sum() > 0:
                    y_test_valid = y_test[filtered_indices]
                    y_pred_valid = y_pred_thresh[filtered_indices]
                    posprec = round(precision_score(y_test_valid, y_pred_valid, pos_label=1, zero_division=0), 2)
                    negprec = round(precision_score(y_test_valid, y_pred_valid, pos_label=0, zero_division=0), 2)
                    poscnt = sum(y_pred_valid == 1)
                    negcnt = sum(y_pred_valid == 0)
                    posrec = round(posprec * poscnt / postot, 2)
                    negrec = round(negprec * negcnt / negtot, 2)
                    metrics[t] = {
                    "Len": len(y_test),
                    "PC": poscnt,
                    "NC": negcnt,
                    "PP": posprec,
                    "PR": posrec,
                    "NP": negprec,
                    "NR": negrec,
                    "PosFb": round((3*posprec*posrec)/((2*posrec)+(1*posprec)),3),
                    "NegFb": round((3*negprec*negrec)/((2*negrec)+(1*negprec)),3),
                    }
                    metrics[t] = {k: np.nan_to_num(v, nan=0.0) for k, v in metrics[t].items()}
                
            return metrics, best_model

        # Try all split values and pick best
        best_result = None
        best_score = -float("inf")

        split_values = [3, 4, 5]

        for splits in split_values:

            cv_split = StratifiedKFold(n_splits=splits, shuffle=True, random_state=42)

            metrics, model = run_cv(cv_split, iter)

            # scoring method: average of PosFb and NegFb at first threshold
            t = list(metrics.keys())[0]
            avg_score = (metrics[t]["PosFb"] + metrics[t]["NegFb"]) / 2

            if avg_score > best_score:
                best_score = avg_score
                best_result = (metrics, model, splits)

        print(f"Best CV split: {best_result[2]} (score={best_score.round(2)})")
        
        return best_result[0], best_result[1], best_score

    X_test = df_indicators.iloc[:test_size].copy()
    y_test = df_predict.iloc[:test_size].copy()
    
    if withold == 'N':
        test_size = 0
    df_indicators = df_indicators.iloc[test_size:].sort_index(ascending=True).copy()
    df_predict = df_predict.iloc[test_size:].sort_index(ascending=True).copy()
    X_train, X_tune, y_train, y_tune = train_test_split(df_indicators, df_predict, test_size=0.3, random_state=42, shuffle=True)

    counts = y_train.value_counts()
    negf = counts.get(0, 0)
    posf = counts.get(1, 1)  # prevent division by zero
    scale_pos_weight = negf / posf

    def mcc_eval(y_pred, dtrain):
        # 1️⃣ True labels (the actual 0/1 target values)
        y_true = dtrain.get_label()
        
        # 2️⃣ Predicted probabilities (convert to binary)
        #    For binary classification, you usually threshold at 0.5
        y_pred_binary = np.rint(y_pred)  # rounds to 0 or 1
        
        # 3️⃣ Compute MCC between true and predicted labels
        mcc = matthews_corrcoef(y_true, y_pred_binary)
        
        # 4️⃣ Return (name, value, higher_is_better flag)
        return 'MCC', mcc, True

    # Deep
    xgboost_hyperparameters = {
        'max_depth': [6, 9, 12],          # Still fairly deep
        'learning_rate': [0.01, 0.05],    # Lower rates
        'min_child_weight': [4, 7, 9, 12],   # More conservative splits
        'subsample': [0.7, 0.8, 0.9],     
        'colsample_bytree': [0.75, 0.85], 
        'colsample_bylevel': [0.7, 0.8, 0.9],
        'colsample_bynode': [0.7, 0.8, 0.9],    
        'gamma': [0.1, 0.3, 0.5],         
        'alpha': [0.1, 0.5, 1.0],         
        'lambda': [5, 10, 15],            
        'n_estimators': [800], 
        'early_stopping_rounds': [10],
        #'eval_metric': ['error']
        }

    iter = 50

    # Train and evaluate models
    xg_metrics, best_xg_model, best_score = train_and_evaluate(XGBClassifier(random_state=42), xgboost_hyperparameters, X_train, y_train, X_tune, y_tune, 
                                                               X_test, y_test, opt, thresh, iter)
    #record_validation_metrics(xg_metrics, arch='shallow', horizon=r, model_name=name)
    #savearch(best_xg_model, r, name, arch)
    metrics = list(xg_metrics.values())[0]
    pscore = metrics.get('PosFb', 0)
    nscore = metrics.get('NegFb', 0)
    
    print_metrics(xg_metrics)

    if return_metrics:
        return xg_metrics, best_xg_model
    else:
        #print_metrics(xg_metrics)
        return best_xg_model, best_score

def save(best_model, days, model, ticker, arch):
    
    directory = f'../Models/Ensemble_{ticker}'  # Saves to the current working directory
    os.makedirs(directory, exist_ok=True)
    
    with open(os.path.join(directory, str(model)+'_xgboost_'+str(days)+str(arch)+'new.pkl'), 'wb') as file_object:
        pickle.dump(best_model, file_object)

    print('Models Saved for '+(ticker)+'_'+str(model)+' '+str(days)+'_'+' Returns')

def savers(best_model, days, model, ticker, arch, ext):
    
    directory = f'../Models/Ensemble_{ticker}'  # Saves to the current working directory
    os.makedirs(directory, exist_ok=True)
    
    with open(os.path.join(directory, str(model)+'_xgboost_'+str(days)+str(arch)+str(ext)+'.pkl'), 'wb') as file_object:
        pickle.dump(best_model, file_object)

    print('Models Saved for '+(ticker)+'_'+str(model)+' '+str(days)+' Returns')

def add_cyclic_seasonality(
    df: pd.DataFrame,
    date_col: str = 'Date',
    add_weekly: bool = True,
    add_month: bool = True,
    add_quarter: bool = True,
    add_year: bool = True,
    add_day_of_year: bool = False,
    mode: str = 'calendar',          # 'trading', 'calendar', or 'both'
    prefix: str = 'cyc_'
) -> pd.DataFrame:
    """
    Add cyclic (sin/cos) seasonality features.

    Parameters
    ----------
    df : pd.DataFrame
        Input dataframe containing a date column.
    date_col : str
        Name of the datetime column.
    add_weekly, add_month, add_quarter, add_year, add_day_of_year : bool
        Toggles for which seasonal cycles to create.
    mode : {'trading','calendar','both'}
        - 'trading': position = trading-day index / trading-days-in-period (resets at dataset slice start)
        - 'calendar': position = calendar progress within period (day-based; retains true mid-period phase)
        - 'both': create both sets (with suffixes _trade and _cal)
    prefix : str
        Prefix for created feature names.

    Returns
    -------
    pd.DataFrame
        Copy of df with new seasonality features appended (original row order preserved).
    """
    if date_col not in df.columns:
        raise ValueError(f"'{date_col}' not found in DataFrame.")
    if mode not in {'trading', 'calendar', 'both'}:
        raise ValueError("mode must be 'trading', 'calendar', or 'both'.")

    out = df.copy()
    out[date_col] = pd.to_datetime(out[date_col])

    # Preserve original order / index
    original_index = out.index
    work = out.sort_values(date_col).reset_index(drop=False)
    idx_col = work.columns[0]

    # Precompute basic date parts
    work['_year']    = work[date_col].dt.year
    work['_month']   = work[date_col].dt.month
    work['_quarter'] = work[date_col].dt.quarter
    work['_weekday'] = work[date_col].dt.weekday
    work['_doy']     = work[date_col].dt.dayofyear
    work['_is_leap'] = work[date_col].dt.is_leap_year

    # ---------- WEEKLY (trading week: Mon-Fri) ----------
    if add_weekly:
        week_pos = work['_weekday'] / 5.0  # Monday=0.0, Friday≈0.8 (if only Mon-Fri present)
        work[f'{prefix}week_sin'] = np.sin(2 * np.pi * week_pos)
        work[f'{prefix}week_cos'] = np.cos(2 * np.pi * week_pos)

    # Helper to safely divide
    def _safe_div(num, den):
        return np.where(den == 0, 0.0, num / np.where(den == 0, 1, den))

    # ---------- MONTH ----------
    if add_month:
        if mode in {'trading', 'both'}:
            grp_m = [work['_year'], work['_month']]
            idx_m = work.groupby(grp_m).cumcount()
            cnt_m = work.groupby(grp_m)[date_col].transform('count')
            pos_m_trade = _safe_div(idx_m, cnt_m)
            work[f'{prefix}month_trade_sin'] = np.sin(2 * np.pi * pos_m_trade)
            work[f'{prefix}month_trade_cos'] = np.cos(2 * np.pi * pos_m_trade)

        if mode in {'calendar', 'both'}:
            dom = work[date_col].dt.day           # 1..days_in_month
            dim = work[date_col].dt.days_in_month
            pos_m_cal = _safe_div(dom - 1, dim - 1)
            work[f'{prefix}month_sin'] = np.sin(2 * np.pi * pos_m_cal)
            work[f'{prefix}month_cos'] = np.cos(2 * np.pi * pos_m_cal)

    # ---------- QUARTER ----------
    if add_quarter:
        if mode in {'trading', 'both'}:
            grp_q = [work['_year'], work['_quarter']]
            idx_q = work.groupby(grp_q).cumcount()
            cnt_q = work.groupby(grp_q)[date_col].transform('count')
            pos_q_trade = _safe_div(idx_q, cnt_q)
            work[f'{prefix}quarter_trade_sin'] = np.sin(2 * np.pi * pos_q_trade)
            work[f'{prefix}quarter_trade_cos'] = np.cos(2 * np.pi * pos_q_trade)

        if mode in {'calendar', 'both'}:
            q = work['_quarter']
            y = work['_year']
            quarter_start = pd.to_datetime({'year': y, 'month': (q - 1) * 3 + 1, 'day': 1})
            quarter_end = quarter_start + pd.offsets.QuarterEnd(0)
            day_in_q = (work[date_col] - quarter_start).dt.days
            days_q = (quarter_end - quarter_start).dt.days
            pos_q_cal = _safe_div(day_in_q, days_q)
            work[f'{prefix}quarter_sin'] = np.sin(2 * np.pi * pos_q_cal)
            work[f'{prefix}quarter_cos'] = np.cos(2 * np.pi * pos_q_cal)

    # ---------- YEAR ----------
    if add_year:
        if mode in {'trading', 'both'}:
            grp_y = work['_year']
            idx_y = work.groupby(grp_y).cumcount()
            cnt_y = work.groupby(grp_y)[date_col].transform('count')
            pos_y_trade = _safe_div(idx_y, cnt_y)
            work[f'{prefix}year_trade_sin'] = np.sin(2 * np.pi * pos_y_trade)
            work[f'{prefix}year_trade_cos'] = np.cos(2 * np.pi * pos_y_trade)

        if mode in {'calendar', 'both'}:
            doy = work['_doy']
            year_len = np.where(work['_is_leap'], 366, 365)
            pos_y_cal = _safe_div(doy - 1, year_len - 1)
            work[f'{prefix}year_sin'] = np.sin(2 * np.pi * pos_y_cal)
            work[f'{prefix}year_cos'] = np.cos(2 * np.pi * pos_y_cal)

    # ---------- DAY OF YEAR (explicit) ----------
    if add_day_of_year:
        year_len = np.where(work['_is_leap'], 366, 365)
        work[f'{prefix}doy_sin'] = np.sin(2 * np.pi * work['_doy'] / year_len)
        work[f'{prefix}doy_cos'] = np.cos(2 * np.pi * work['_doy'] / year_len)

    # Drop temp columns
    temp_cols = [c for c in work.columns if c.startswith('_')]
    work = work.drop(columns=temp_cols)

    # Identify newly created features
    new_cols = [c for c in work.columns if c not in out.columns and c != idx_col]

    # Map back to original order
    work = work.set_index(idx_col)
    out[new_cols] = work.loc[original_index, new_cols]

    return out

def perm_importance(all_perm_dfs, ext):

    # Combine all permutation importance DataFrames
    current_perm_df = pd.concat(all_perm_dfs, ignore_index=True)

    # Apply the retention logic per group
    def apply_retention_logic(group):
        group = group.copy()
        group["drop_flag"] = group["importance_mean"] <= 0.01

        total = len(group)
        retained = (~group["drop_flag"]).sum()
        min_retained = int(np.ceil(total * 0.45))

        if retained < min_retained:
            top_feats = group.sort_values(by="importance_mean", ascending=False).head(min_retained)["feature"]
            group["drop_flag"] = ~group["feature"].isin(top_feats)

        return group

    # Apply group-wise adjustment by model_name, arch, horizon
    current_perm_df = current_perm_df.groupby(
        ["model_name", "arch", "horizon"], group_keys=False
    ).apply(apply_retention_logic)

    # Build feature map from retained features
    curr_feature_map = (
        current_perm_df[~current_perm_df["drop_flag"]]
        .groupby(["model_name", "arch", "horizon"])["feature"]
        .apply(list)
        .to_dict()
    )

    # Save
    with open(f"curr_feature_map_v{ext}.pkl", "wb") as f:
        pickle.dump(curr_feature_map, f)

    print('Saved curr_feature_map')

weekly = ['cyc_week_sin', 'cyc_week_cos']
monthly = ['cyc_month_sin', 'cyc_month_cos']
quarterly = ['cyc_quarter_sin', 'cyc_quarter_cos']
yearly = ['cyc_year_sin', 'cyc_year_cos']
all_seasons = ['cyc_week_sin', 'cyc_week_cos', 'cyc_month_sin', 'cyc_month_cos', 'cyc_quarter_sin', 'cyc_quarter_cos',
               'cyc_year_sin', 'cyc_year_cos']
slopes = ['Close_slope10', 'Close_slope25', 'Close_slope50']

selected_combos = {
    "h_5": {
        'duration_slow+trend_ratio_slow+momentum_fast_EMA10': duration_slow+trend_ratio_slow+momentum_fast_EMA10,
        'lag_fast+trend_slow+momentum_moderate': lag_fast+trend_slow+momentum_moderate,
        'duration_slow+trend_ratio_slow+momentum_moderate': duration_slow+trend_ratio_slow+momentum_moderate,
        #'duration_slow+trend_ratio_slow+momentum_fast': duration_slow+trend_ratio_slow+momentum_fast,
        'trend_ratio_moderate+momentum_moderate+momentum_fast_EMA10': trend_ratio_moderate+momentum_moderate+momentum_fast_EMA10,
    },
    "h_10": {
        'duration_moderate+duration_fast+trend_ratio_slow': duration_moderate+duration_fast+trend_ratio_slow,
        'duration_slow+duration_fast+trend_fast': duration_slow+duration_fast+trend_fast,
        #'duration_moderate+trend_slow+trend_ratio_fast': duration_moderate+trend_slow+trend_ratio_fast,
        'duration_slow+trend_ratio_slow+trend_ratio_moderate': duration_slow+trend_ratio_slow+trend_ratio_moderate,
        'trend_slow+trend_fast+trend_ratio_fast': trend_slow+trend_fast+trend_ratio_fast,
    },
    "h_15": {
        'duration_moderate+duration_fast+trend_slow': duration_moderate+duration_fast+trend_slow,
        'trend_ratio_slow+momentum_moderate+momentum_fast_EMA10': trend_ratio_slow+momentum_moderate+momentum_fast_EMA10,
        'trend_slow+trend_ratio_slow+trend_ratio_fast': trend_slow+trend_ratio_slow+trend_ratio_fast,
        'duration_slow+duration_fast+trend_ratio_moderate': duration_slow+duration_fast+trend_ratio_moderate,
        'trend_fast+trend_ratio_moderate+volatility_fast': trend_fast+trend_ratio_moderate+volatility_fast,
    },
    "h_20": {
        'lag_fast+trend_slow+volatility_moderate': lag_fast+trend_slow+volatility_moderate,
        'lag_fast+trend_slow+trend_moderate': lag_fast+trend_slow+trend_moderate,
        'duration_moderate+trend_ratio_slow+momentum_moderate': duration_moderate+trend_ratio_slow+momentum_moderate,
        'duration_slow+duration_moderate+trend_ratio_slow': duration_slow+duration_moderate+trend_ratio_slow,
        'duration_slow+trend_moderate+trend_ratio_moderate': duration_slow+trend_moderate+trend_ratio_moderate,
    },
    "h_25": {
        'lag_fast+duration_moderate+volatility_fast_EMA10': lag_fast+duration_moderate+volatility_fast_EMA10,
        'lag_fast+trend_slow+volatility_moderate': lag_fast+trend_slow+volatility_moderate,
        'duration_slow+duration_moderate+trend_ratio_slow': duration_slow+duration_moderate+trend_ratio_slow,
        'duration_slow+trend_moderate+trend_ratio_moderate': duration_slow+trend_moderate+trend_ratio_moderate,
        'duration_fast+trend_moderate+trend_ratio_slow': duration_fast+trend_moderate+trend_ratio_slow,
    },
    "h_35": {
        'lag_fast+trend_fast+trend_ratio_moderate': lag_fast+trend_fast+trend_ratio_moderate,
        'lag_fast+volatility_fast+momentum_slow': lag_fast+volatility_fast+momentum_slow,
        'lag_fast+trend_ratio_fast+momentum_slow': lag_fast+trend_ratio_fast+momentum_slow,
        #'duration_slow+trend_ratio_slow+trend_ratio_moderate': duration_slow+trend_ratio_slow+trend_ratio_moderate,
        'duration_slow+trend_slow+trend_ratio_slow': duration_slow+trend_slow+trend_ratio_slow,
    },
    "h_45": {
        'lag_fast+trend_moderate+trend_ratio_slow': lag_fast+trend_moderate+trend_ratio_slow,
        'lag_fast+trend_ratio_slow+volatility_moderate': lag_fast+trend_ratio_slow+volatility_moderate,
        'duration_slow+duration_moderate+trend_fast': duration_slow+duration_moderate+trend_fast,
        'duration_slow+duration_moderate+volatility_moderate': duration_slow+duration_moderate+volatility_moderate,
        'momentum_moderate+momentum_fast_EMA10+all_seasons': momentum_moderate+momentum_fast_EMA10+all_seasons,
    },
    "h_50": {
        'lag_fast+win_rates': lag_fast + win_rates
    }
}

def get_model_set(horizon):
    if horizon in [5]:
        key = "h_5"
    elif horizon in [10]:
        key = "h_10"
    elif horizon in [15]:
        key = "h_15"
    elif horizon in [20]:
        key = "h_20" 
    elif horizon in [25]:
        key = "h_25"
    elif horizon in [35]:
        key = "h_35"
    elif horizon in [45]:
        key = "h_45"
    else:
        raise ValueError(f"Unsupported horizon: {horizon}")
    
    return selected_combos[key]

"""
def get_model_set(horizon):
    if horizon in [5]:
        key = "h_50"
    elif horizon in [10]:
        key = "h_50"
    elif horizon in [15]:
        key = "h_50"
    elif horizon in [20]:
        key = "h_50" 
    elif horizon in [25]:
        key = "h_50"
    elif horizon in [35]:
        key = "h_50"
    elif horizon in [45]:
        key = "h_50"
    else:
        raise ValueError(f"Unsupported horizon: {horizon}")
    
    return selected_combos[key]
"""
# Out:
# '\ndef get_model_set(horizon):\n    if horizon in [5]:\n        key = "h_50"\n    elif horizon in [10]:\n        key = "h_50"\n    elif horizon in [15]:\n        key = "h_50"\n    elif horizon in [20]:\n        key = "h_50" \n    elif horizon in [25]:\n        key = "h_50"\n    elif horizon in [35]:\n        key = "h_50"\n    elif horizon in [45]:\n        key = "h_50"\n    else:\n        raise ValueError(f"Unsupported horizon: {horizon}")\n    \n    return selected_combos[key]\n'

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
np.seterr(invalid='ignore', divide='ignore')
ticker = 'QQQ'
thresh = [.5, .55]
results = []
returns = [5, 10, 15, 20, 25, 35, 45]
arch = 'deep'
withold = 'Y'
test_size = 160
test_sizes = [220, 170, 120]
run_perm = "N"
save_models = 'Y'
offset = 0
lbs = [8, 10]
ext = '10-17'

for test_size in test_sizes:

    ext = test_size

    if run_perm != "Y":
        with open(f"curr_feature_map_v{ext}.pkl", "rb") as f:
                feature_map = pickle.load(f)
    else: all_perm_dfs = []
        
    for r in returns:

        selected_models = get_model_set(r)
            
        for name, cols in selected_models.items():

            best_score = -float("inf")
            best_model = None
            best_lb = None

            periods = [5, 10, 15, 20, 25, 35, 45]
            df = extract(ticker, periods, raw_all, windows=[10,25])
            df = add_cyclic_seasonality(df, date_col='Date', add_weekly=True, add_month=True,
                                        add_quarter=True, add_year=True, add_day_of_year=False,
                                        mode='calendar',    # or 'trading' or 'both'
                                        prefix='cyc_')    
                
            for lb in lbs:

                record_length = 245 * lb
                df_ph = df.iloc[offset:offset+record_length].copy()
                df_ph = df_ph.iloc[r:].copy()
                return_col = f"Return_{r}"
                return_perc_col = f"Return%_{r}"
                model_key = f"QQQ_{r}"

                rets = df_ph[return_perc_col].copy()
                # Split into negative and positive returns
                neg = rets[rets < 0]
                pos = rets[rets > 0]
                # Calculate dynamic thresholds
                neg_cutoff = neg.nlargest(int(len(neg) * 0.05)).min()  # least negative of top 10% in magnitude
                pos_cutoff = pos.nsmallest(int(len(pos) * 0.05)).max()  # smallest positive of top 10% in magnitude
                
                filtered = df_ph[(df_ph[f'Return%_{r}'] < neg_cutoff) | (df_ph[f'Return%_{r}'] > pos_cutoff)].copy()
                counts = filtered[return_col].value_counts()
                negf = counts.get(0, 0)
                posf = counts.get(1, 1)  # prevent division by zero
                #print(f'{posf} | {negf}')
                scale_pos_weight = negf / posf

                # Choose evaluation metric
                opt = 'matthews_corrcoef'

                # Combine features with return column, drop missing
                original_cols = list(dict.fromkeys(cols))
                pi_cols = feature_map.get((name, arch, r), original_cols)
                #print(f"{len(original_cols)} | {len(pi_cols)}")

                if run_perm == 'Y':
                    prod_cols = original_cols
                else: prod_cols = pi_cols

                used_cols = prod_cols + [return_col]
                df_model = filtered[used_cols].dropna()
                
                df_indicators = df_model[prod_cols]
                df_indicators = df_indicators.replace([np.inf, -np.inf], 0)
                df_predict = df_model[return_col]
                
                print(f"Results for {lb}lb | {len(df_ph)}records | {name} | Test: {df_ph['Date'].iloc[0].strftime('%Y-%m-%d')}-{df_ph['Date'].iloc[test_size].strftime('%Y-%m-%d')} | {ticker}_{r}")
                best_xg_model, score = optimize_splits_new(df_indicators, df_predict, thresh, opt, arch, test_size, withold, return_metrics=False)
                #best_xg_model, score = optimize_rs(df_indicators, df_predict, thresh, opt, arch, test_size, withold, return_metrics=False)

                if score > best_score:

                    best_score = score
                    best_model = best_xg_model
                    best_lb = lb
            
            if best_model is not None:

                print(f"Best model: lb={best_lb}, score={round(best_score,3)}")
                
                if save_models == 'Y': 
                    savers(best_model, r, name, ticker, arch, ext)
                
                if run_perm == 'Y':

                    perm_size = test_size
                    X_test = df_indicators.iloc[:perm_size].copy()
                    y_test = df_predict.iloc[:perm_size].copy()
                    
                    # Run permutation importance
                    perm = permutation_importance(best_model, X_test, y_test, n_repeats=100, random_state=None, n_jobs=-1)

                    # Organize into a DataFrame
                    perm_df = pd.DataFrame({
                        'feature': df_indicators.columns,
                        'importance_mean': perm.importances_mean,
                        'importance_std': perm.importances_std,
                        'arch': arch,
                        'horizon': r,
                        'model_name': name
                    })

                    all_perm_dfs.append(perm_df)

                    print(f"Permutation Importance — {name} | QQQ_{r}")
                
                print('---------------------------')

    if run_perm == 'Y': perm_importance(all_perm_dfs, ext)
# Out:
# Results for 8lb | 1955records | duration_slow+trend_ratio_slow+momentum_fast_EMA10 | Test: 2025-10-10-2024-11-21 | QQQ_5
# Best CV split: 3 (score=0.6)
#   Threshold 0.5: {'Len': 220, 'PC': 191, 'NC': 29, 'PP': 0.68, 'PR': 0.94, 'NP': 0.72, 'NR': 0.25, 'PosFb': 0.749, 'NegFb': 0.443}
#   Threshold 0.55: {'Len': 220, 'PC': 181, 'NC': 13, 'PP': 0.7, 'PR': 0.92, 'NP': 0.85, 'NR': 0.13, 'PosFb': 0.761, 'NegFb': 0.299}
# Results for 10lb | 2445records | duration_slow+trend_ratio_slow+momentum_fast_EMA10 | Test: 2025-10-10-2024-11-21 | QQQ_5
# Best CV split: 3 (score=0.62)
#   Threshold 0.5: {'Len': 220, 'PC': 183, 'NC': 37, 'PP': 0.69, 'PR': 0.91, 'NP': 0.68, 'NR': 0.31, 'PosFb': 0.75, 'NegFb': 0.486}
#   Threshold 0.55: {'Len': 220, 'PC': 160, 'NC': 27, 'PP': 0.71, 'PR': 0.82, 'NP': 0.67, 'NR': 0.22, 'PosFb': 0.743, 'NegFb': 0.398}
# Best model: lb=10, score=0.618
# Models Saved for QQQ_duration_slow+trend_ratio_slow+momentum_fast_EMA10 5 Returns
# ---------------------------
# Results for 8lb | 1955records | lag_fast+trend_slow+momentum_moderate | Test: 2025-10-10-2024-11-21 | QQQ_5
# Best CV split: 5 (score=0.57)
#   Threshold 0.5: {'Len': 220, 'PC': 200, 'NC': 20, 'PP': 0.67, 'PR': 0.97, 'NP': 0.8, 'NR': 0.2, 'PosFb': 0.747, 'NegFb': 0.4}
#   Threshold 0.55: {'Len': 220, 'PC': 189, 'NC': 11, 'PP': 0.69, 'PR': 0.94, 'NP': 1.0, 'NR': 0.13, 'PosFb': 0.757, 'NegFb': 0.31}
# Results for 10lb | 2445records | lag_fast+trend_slow+momentum_moderate | Test: 2025-10-10-2024-11-21 | QQQ_5
# Best CV split: 3 (score=0.57)
#   Threshold 0.5: {'Len': 220, 'PC': 190, 'NC': 30, 'PP': 0.67, 'PR': 0.92, 'NP': 0.63, 'NR': 0.23, 'PosFb': 0.737, 'NegFb': 0.399}
#   Threshold 0.55: {'Len': 220, 'PC': 174, 'NC': 12, 'PP': 0.67, 'PR': 0.84, 'NP': 0.83, 'NR': 0.12, 'PosFb': 0.718, 'NegFb': 0.279}
# Best model: lb=8, score=0.574
# Models Saved for QQQ_lag_fast+trend_slow+momentum_moderate 5 Returns
# ---------------------------
# Results for 8lb | 1955records | duration_slow+trend_ratio_slow+momentum_moderate | Test: 2025-10-10-2024-11-21 | QQQ_5
# Best CV split: 5 (score=0.58)
#   Threshold 0.5: {'Len': 220, 'PC': 195, 'NC': 25, 'PP': 0.67, 'PR': 0.95, 'NP': 0.72, 'NR': 0.22, 'PosFb': 0.743, 'NegFb': 0.41}
#   Threshold 0.55: {'Len': 220, 'PC': 177, 'NC': 10, 'PP': 0.7, 'PR': 0.9, 'NP': 0.9, 'NR': 0.11, 'PosFb': 0.756, 'NegFb': 0.265}
# Results for 10lb | 2445records | duration_slow+trend_ratio_slow+momentum_moderate | Test: 2025-10-10-2024-11-21 | QQQ_5
# Best CV split: 4 (score=0.59)
#   Threshold 0.5: {'Len': 220, 'PC': 186, 'NC': 34, 'PP': 0.68, 'PR': 0.92, 'NP': 0.65, 'NR': 0.27, 'PosFb': 0.745, 'NegFb': 0.442}
#   Threshold 0.55: {'Len': 220, 'PC': 170, 'NC': 20, 'PP': 0.69, 'PR': 0.85, 'NP': 0.7, 'NR': 0.17, 'PosFb': 0.736, 'NegFb': 0.343}
# Best model: lb=10, score=0.594
# Models Saved for QQQ_duration_slow+trend_ratio_slow+momentum_moderate 5 Returns
# ---------------------------
# Results for 8lb | 1955records | trend_ratio_moderate+momentum_moderate+momentum_fast_EMA10 | Test: 2025-10-10-2024-11-21 | QQQ_5
# Best CV split: 3 (score=0.57)
#   Threshold 0.5: {'Len': 220, 'PC': 201, 'NC': 19, 'PP': 0.67, 'PR': 0.98, 'NP': 0.84, 'NR': 0.19, 'PosFb': 0.749, 'NegFb': 0.392}
#   Threshold 0.55: {'Len': 220, 'PC': 186, 'NC': 8, 'PP': 0.66, 'PR': 0.89, 'NP': 1.0, 'NR': 0.1, 'PosFb': 0.722, 'NegFb': 0.25}
# Results for 10lb | 2445records | trend_ratio_moderate+momentum_moderate+momentum_fast_EMA10 | Test: 2025-10-10-2024-11-21 | QQQ_5
# Best CV split: 3 (score=0.55)
#   Threshold 0.5: {'Len': 220, 'PC': 195, 'NC': 25, 'PP': 0.66, 'PR': 0.93, 'NP': 0.64, 'NR': 0.2, 'PosFb': 0.731, 'NegFb': 0.369}
#   Threshold 0.55: {'Len': 220, 'PC': 172, 'NC': 13, 'PP': 0.67, 'PR': 0.84, 'NP': 0.92, 'NR': 0.15, 'PosFb': 0.718, 'NegFb': 0.339}
# Best model: lb=8, score=0.57
# Models Saved for QQQ_trend_ratio_moderate+momentum_moderate+momentum_fast_EMA10 5 Returns
# ---------------------------
# Results for 8lb | 1950records | duration_moderate+duration_fast+trend_ratio_slow | Test: 2025-10-03-2024-11-14 | QQQ_10
# Best CV split: 3 (score=0.38)
#   Threshold 0.5: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.67, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.753, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.67, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.753, 'NegFb': 0.0}
# Results for 10lb | 2440records | duration_moderate+duration_fast+trend_ratio_slow | Test: 2025-10-03-2024-11-14 | QQQ_10
# Best CV split: 3 (score=0.42)
#   Threshold 0.5: {'Len': 220, 'PC': 202, 'NC': 18, 'PP': 0.67, 'PR': 0.9, 'NP': 0.22, 'NR': 0.06, 'PosFb': 0.732, 'NegFb': 0.116}
#   Threshold 0.55: {'Len': 220, 'PC': 197, 'NC': 6, 'PP': 0.68, 'PR': 0.89, 'NP': 0.33, 'NR': 0.03, 'PosFb': 0.738, 'NegFb': 0.076}
# Best model: lb=10, score=0.424
# Models Saved for QQQ_duration_moderate+duration_fast+trend_ratio_slow 10 Returns
# ---------------------------
# Results for 8lb | 1950records | duration_slow+duration_fast+trend_fast | Test: 2025-10-03-2024-11-14 | QQQ_10
# Best CV split: 5 (score=0.76)
#   Threshold 0.5: {'Len': 220, 'PC': 141, 'NC': 79, 'PP': 0.85, 'PR': 0.82, 'NP': 0.66, 'NR': 0.71, 'PosFb': 0.84, 'NegFb': 0.676}
#   Threshold 0.55: {'Len': 220, 'PC': 125, 'NC': 67, 'PP': 0.86, 'PR': 0.73, 'NP': 0.69, 'NR': 0.63, 'PosFb': 0.812, 'NegFb': 0.669}
# Results for 10lb | 2440records | duration_slow+duration_fast+trend_fast | Test: 2025-10-03-2024-11-14 | QQQ_10
# Best CV split: 5 (score=0.8)
#   Threshold 0.5: {'Len': 220, 'PC': 158, 'NC': 62, 'PP': 0.85, 'PR': 0.9, 'NP': 0.76, 'NR': 0.67, 'PosFb': 0.866, 'NegFb': 0.727}
#   Threshold 0.55: {'Len': 220, 'PC': 149, 'NC': 56, 'PP': 0.86, 'PR': 0.85, 'NP': 0.8, 'NR': 0.64, 'PosFb': 0.857, 'NegFb': 0.738}
# Best model: lb=10, score=0.796
# Models Saved for QQQ_duration_slow+duration_fast+trend_fast 10 Returns
# ---------------------------
# Results for 8lb | 1950records | duration_slow+trend_ratio_slow+trend_ratio_moderate | Test: 2025-10-03-2024-11-14 | QQQ_10
# Best CV split: 5 (score=0.67)
#   Threshold 0.5: {'Len': 220, 'PC': 192, 'NC': 28, 'PP': 0.74, 'PR': 0.97, 'NP': 0.82, 'NR': 0.31, 'PosFb': 0.804, 'NegFb': 0.53}
#   Threshold 0.55: {'Len': 220, 'PC': 175, 'NC': 0, 'PP': 0.78, 'PR': 0.93, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.824, 'NegFb': 0.0}
# Results for 10lb | 2440records | duration_slow+trend_ratio_slow+trend_ratio_moderate | Test: 2025-10-03-2024-11-14 | QQQ_10
# Best CV split: 3 (score=0.66)
#   Threshold 0.5: {'Len': 220, 'PC': 162, 'NC': 58, 'PP': 0.77, 'PR': 0.83, 'NP': 0.57, 'NR': 0.47, 'PosFb': 0.789, 'NegFb': 0.532}
#   Threshold 0.55: {'Len': 220, 'PC': 143, 'NC': 40, 'PP': 0.77, 'PR': 0.73, 'NP': 0.72, 'NR': 0.41, 'PosFb': 0.756, 'NegFb': 0.575}
# Best model: lb=8, score=0.667
# Models Saved for QQQ_duration_slow+trend_ratio_slow+trend_ratio_moderate 10 Returns
# ---------------------------
# Results for 8lb | 1950records | trend_slow+trend_fast+trend_ratio_fast | Test: 2025-10-03-2024-11-14 | QQQ_10
# Best CV split: 4 (score=0.6)
#   Threshold 0.5: {'Len': 220, 'PC': 206, 'NC': 14, 'PP': 0.71, 'PR': 0.99, 'NP': 1.0, 'NR': 0.19, 'PosFb': 0.784, 'NegFb': 0.413}
#   Threshold 0.55: {'Len': 220, 'PC': 199, 'NC': 11, 'PP': 0.71, 'PR': 0.96, 'NP': 1.0, 'NR': 0.15, 'PosFb': 0.777, 'NegFb': 0.346}
# Results for 10lb | 2440records | trend_slow+trend_fast+trend_ratio_fast | Test: 2025-10-03-2024-11-14 | QQQ_10
# Best CV split: 4 (score=0.67)
#   Threshold 0.5: {'Len': 220, 'PC': 190, 'NC': 30, 'PP': 0.75, 'PR': 0.95, 'NP': 0.77, 'NR': 0.33, 'PosFb': 0.807, 'NegFb': 0.533}
#   Threshold 0.55: {'Len': 220, 'PC': 182, 'NC': 23, 'PP': 0.76, 'PR': 0.92, 'NP': 0.87, 'NR': 0.29, 'PosFb': 0.807, 'NegFb': 0.522}
# Best model: lb=10, score=0.67
# Models Saved for QQQ_trend_slow+trend_fast+trend_ratio_fast 10 Returns
# ---------------------------
# Results for 8lb | 1945records | duration_moderate+duration_fast+trend_slow | Test: 2025-09-26-2024-11-07 | QQQ_15
# Best CV split: 4 (score=0.64)
#   Threshold 0.5: {'Len': 220, 'PC': 186, 'NC': 34, 'PP': 0.77, 'PR': 0.91, 'NP': 0.59, 'NR': 0.32, 'PosFb': 0.812, 'NegFb': 0.46}
#   Threshold 0.55: {'Len': 220, 'PC': 175, 'NC': 30, 'PP': 0.76, 'PR': 0.84, 'NP': 0.6, 'NR': 0.29, 'PosFb': 0.785, 'NegFb': 0.442}
# Results for 10lb | 2435records | duration_moderate+duration_fast+trend_slow | Test: 2025-09-26-2024-11-07 | QQQ_15
# Best CV split: 4 (score=0.66)
#   Threshold 0.5: {'Len': 220, 'PC': 199, 'NC': 21, 'PP': 0.77, 'PR': 0.97, 'NP': 0.81, 'NR': 0.27, 'PosFb': 0.827, 'NegFb': 0.486}
#   Threshold 0.55: {'Len': 220, 'PC': 193, 'NC': 12, 'PP': 0.78, 'PR': 0.95, 'NP': 0.92, 'NR': 0.18, 'PosFb': 0.829, 'NegFb': 0.388}
# Best model: lb=10, score=0.656
# Models Saved for QQQ_duration_moderate+duration_fast+trend_slow 15 Returns
# ---------------------------
# Results for 8lb | 1945records | trend_ratio_slow+momentum_moderate+momentum_fast_EMA10 | Test: 2025-09-26-2024-11-07 | QQQ_15
# Best CV split: 5 (score=0.76)
#   Threshold 0.5: {'Len': 220, 'PC': 183, 'NC': 37, 'PP': 0.83, 'PR': 0.96, 'NP': 0.81, 'NR': 0.48, 'PosFb': 0.869, 'NegFb': 0.659}
#   Threshold 0.55: {'Len': 220, 'PC': 171, 'NC': 26, 'PP': 0.82, 'PR': 0.89, 'NP': 0.85, 'NR': 0.36, 'PosFb': 0.842, 'NegFb': 0.585}
# Results for 10lb | 2435records | trend_ratio_slow+momentum_moderate+momentum_fast_EMA10 | Test: 2025-09-26-2024-11-07 | QQQ_15
# Best CV split: 5 (score=0.72)
#   Threshold 0.5: {'Len': 220, 'PC': 182, 'NC': 38, 'PP': 0.81, 'PR': 0.93, 'NP': 0.71, 'NR': 0.44, 'PosFb': 0.846, 'NegFb': 0.589}
#   Threshold 0.55: {'Len': 220, 'PC': 172, 'NC': 26, 'PP': 0.81, 'PR': 0.88, 'NP': 0.85, 'NR': 0.36, 'PosFb': 0.832, 'NegFb': 0.585}
# Best model: lb=8, score=0.764
# Models Saved for QQQ_trend_ratio_slow+momentum_moderate+momentum_fast_EMA10 15 Returns
# ---------------------------
# Results for 8lb | 1945records | trend_slow+trend_ratio_slow+trend_ratio_fast | Test: 2025-09-26-2024-11-07 | QQQ_15
# Best CV split: 5 (score=0.82)
#   Threshold 0.5: {'Len': 220, 'PC': 176, 'NC': 44, 'PP': 0.86, 'PR': 0.96, 'NP': 0.84, 'NR': 0.6, 'PosFb': 0.891, 'NegFb': 0.741}
#   Threshold 0.55: {'Len': 220, 'PC': 170, 'NC': 41, 'PP': 0.85, 'PR': 0.91, 'NP': 0.85, 'NR': 0.56, 'PosFb': 0.869, 'NegFb': 0.725}
# Results for 10lb | 2435records | trend_slow+trend_ratio_slow+trend_ratio_fast | Test: 2025-09-26-2024-11-07 | QQQ_15
# Best CV split: 5 (score=0.77)
#   Threshold 0.5: {'Len': 220, 'PC': 188, 'NC': 32, 'PP': 0.82, 'PR': 0.98, 'NP': 0.88, 'NR': 0.45, 'PosFb': 0.867, 'NegFb': 0.667}
#   Threshold 0.55: {'Len': 220, 'PC': 179, 'NC': 25, 'PP': 0.81, 'PR': 0.92, 'NP': 0.96, 'NR': 0.39, 'PosFb': 0.844, 'NegFb': 0.646}
# Best model: lb=8, score=0.816
# Models Saved for QQQ_trend_slow+trend_ratio_slow+trend_ratio_fast 15 Returns
# ---------------------------
# Results for 8lb | 1945records | duration_slow+duration_fast+trend_ratio_moderate | Test: 2025-09-26-2024-11-07 | QQQ_15
# Best CV split: 4 (score=0.77)
#   Threshold 0.5: {'Len': 220, 'PC': 153, 'NC': 67, 'PP': 0.88, 'PR': 0.85, 'NP': 0.66, 'NR': 0.71, 'PosFb': 0.87, 'NegFb': 0.676}
#   Threshold 0.55: {'Len': 220, 'PC': 145, 'NC': 61, 'PP': 0.9, 'PR': 0.83, 'NP': 0.69, 'NR': 0.68, 'PosFb': 0.875, 'NegFb': 0.687}
# Results for 10lb | 2435records | duration_slow+duration_fast+trend_ratio_moderate | Test: 2025-09-26-2024-11-07 | QQQ_15
# Best CV split: 4 (score=0.8)
#   Threshold 0.5: {'Len': 220, 'PC': 166, 'NC': 54, 'PP': 0.87, 'PR': 0.91, 'NP': 0.76, 'NR': 0.66, 'PosFb': 0.883, 'NegFb': 0.723}
#   Threshold 0.55: {'Len': 220, 'PC': 159, 'NC': 45, 'PP': 0.89, 'PR': 0.9, 'NP': 0.73, 'NR': 0.53, 'PosFb': 0.893, 'NegFb': 0.648}
# Best model: lb=10, score=0.803
# Models Saved for QQQ_duration_slow+duration_fast+trend_ratio_moderate 15 Returns
# ---------------------------
# Results for 8lb | 1945records | trend_fast+trend_ratio_moderate+volatility_fast | Test: 2025-09-26-2024-11-07 | QQQ_15
# Best CV split: 3 (score=0.6)
#   Threshold 0.5: {'Len': 220, 'PC': 200, 'NC': 20, 'PP': 0.76, 'PR': 0.96, 'NP': 0.65, 'NR': 0.21, 'PosFb': 0.817, 'NegFb': 0.383}
#   Threshold 0.55: {'Len': 220, 'PC': 171, 'NC': 14, 'PP': 0.78, 'PR': 0.84, 'NP': 0.86, 'NR': 0.19, 'PosFb': 0.799, 'NegFb': 0.395}
# Results for 10lb | 2435records | trend_fast+trend_ratio_moderate+volatility_fast | Test: 2025-09-26-2024-11-07 | QQQ_15
# Best CV split: 4 (score=0.67)
#   Threshold 0.5: {'Len': 220, 'PC': 171, 'NC': 49, 'PP': 0.8, 'PR': 0.87, 'NP': 0.57, 'NR': 0.45, 'PosFb': 0.822, 'NegFb': 0.523}
#   Threshold 0.55: {'Len': 220, 'PC': 155, 'NC': 39, 'PP': 0.83, 'PR': 0.81, 'NP': 0.54, 'NR': 0.34, 'PosFb': 0.823, 'NegFb': 0.451}
# Best model: lb=10, score=0.672
# Models Saved for QQQ_trend_fast+trend_ratio_moderate+volatility_fast 15 Returns
# ---------------------------
# Results for 8lb | 1940records | lag_fast+trend_slow+volatility_moderate | Test: 2025-09-19-2024-10-31 | QQQ_20
# Best CV split: 4 (score=0.8)
#   Threshold 0.5: {'Len': 220, 'PC': 170, 'NC': 50, 'PP': 0.88, 'PR': 0.92, 'NP': 0.74, 'NR': 0.64, 'PosFb': 0.893, 'NegFb': 0.703}
#   Threshold 0.55: {'Len': 220, 'PC': 161, 'NC': 42, 'PP': 0.88, 'PR': 0.87, 'NP': 0.86, 'NR': 0.62, 'PosFb': 0.877, 'NegFb': 0.762}
# Results for 10lb | 2430records | lag_fast+trend_slow+volatility_moderate | Test: 2025-09-19-2024-10-31 | QQQ_20
# Best CV split: 5 (score=0.78)
#   Threshold 0.5: {'Len': 220, 'PC': 187, 'NC': 33, 'PP': 0.84, 'PR': 0.97, 'NP': 0.85, 'NR': 0.48, 'PosFb': 0.879, 'NegFb': 0.676}
#   Threshold 0.55: {'Len': 220, 'PC': 177, 'NC': 30, 'PP': 0.85, 'PR': 0.93, 'NP': 0.9, 'NR': 0.47, 'PosFb': 0.875, 'NegFb': 0.69}
# Best model: lb=8, score=0.798
# Models Saved for QQQ_lag_fast+trend_slow+volatility_moderate 20 Returns
# ---------------------------
# Results for 8lb | 1940records | lag_fast+trend_slow+trend_moderate | Test: 2025-09-19-2024-10-31 | QQQ_20
# Best CV split: 4 (score=0.8)
#   Threshold 0.5: {'Len': 220, 'PC': 144, 'NC': 76, 'PP': 0.94, 'PR': 0.84, 'NP': 0.64, 'NR': 0.84, 'PosFb': 0.904, 'NegFb': 0.695}
#   Threshold 0.55: {'Len': 220, 'PC': 134, 'NC': 57, 'PP': 0.97, 'PR': 0.8, 'NP': 0.72, 'NR': 0.71, 'PosFb': 0.906, 'NegFb': 0.717}
# Results for 10lb | 2430records | lag_fast+trend_slow+trend_moderate | Test: 2025-09-19-2024-10-31 | QQQ_20
# Best CV split: 5 (score=0.84)
#   Threshold 0.5: {'Len': 220, 'PC': 146, 'NC': 74, 'PP': 0.96, 'PR': 0.87, 'NP': 0.7, 'NR': 0.89, 'PosFb': 0.928, 'NegFb': 0.754}
#   Threshold 0.55: {'Len': 220, 'PC': 137, 'NC': 58, 'PP': 0.96, 'PR': 0.81, 'NP': 0.79, 'NR': 0.79, 'PosFb': 0.904, 'NegFb': 0.79}
# Best model: lb=10, score=0.841
# Models Saved for QQQ_lag_fast+trend_slow+trend_moderate 20 Returns
# ---------------------------
# Results for 8lb | 1940records | duration_moderate+trend_ratio_slow+momentum_moderate | Test: 2025-09-19-2024-10-31 | QQQ_20
# Best CV split: 5 (score=0.77)
#   Threshold 0.5: {'Len': 220, 'PC': 167, 'NC': 53, 'PP': 0.87, 'PR': 0.9, 'NP': 0.68, 'NR': 0.62, 'PosFb': 0.88, 'NegFb': 0.659}
#   Threshold 0.55: {'Len': 220, 'PC': 164, 'NC': 49, 'PP': 0.87, 'PR': 0.88, 'NP': 0.71, 'NR': 0.6, 'PosFb': 0.873, 'NegFb': 0.669}
# Results for 10lb | 2430records | duration_moderate+trend_ratio_slow+momentum_moderate | Test: 2025-09-19-2024-10-31 | QQQ_20
# Best CV split: 4 (score=0.8)
#   Threshold 0.5: {'Len': 220, 'PC': 177, 'NC': 43, 'PP': 0.86, 'PR': 0.94, 'NP': 0.79, 'NR': 0.59, 'PosFb': 0.885, 'NegFb': 0.71}
#   Threshold 0.55: {'Len': 220, 'PC': 169, 'NC': 37, 'PP': 0.87, 'PR': 0.91, 'NP': 0.81, 'NR': 0.52, 'PosFb': 0.883, 'NegFb': 0.683}
# Best model: lb=10, score=0.798
# Models Saved for QQQ_duration_moderate+trend_ratio_slow+momentum_moderate 20 Returns
# ---------------------------
# Results for 8lb | 1940records | duration_slow+duration_moderate+trend_ratio_slow | Test: 2025-09-19-2024-10-31 | QQQ_20
# Best CV split: 3 (score=0.83)
#   Threshold 0.5: {'Len': 220, 'PC': 156, 'NC': 64, 'PP': 0.92, 'PR': 0.89, 'NP': 0.72, 'NR': 0.79, 'PosFb': 0.91, 'NegFb': 0.742}
#   Threshold 0.55: {'Len': 220, 'PC': 149, 'NC': 49, 'PP': 0.94, 'PR': 0.86, 'NP': 0.84, 'NR': 0.71, 'PosFb': 0.912, 'NegFb': 0.792}
# Results for 10lb | 2430records | duration_slow+duration_moderate+trend_ratio_slow | Test: 2025-09-19-2024-10-31 | QQQ_20
# Best CV split: 3 (score=0.76)
#   Threshold 0.5: {'Len': 220, 'PC': 147, 'NC': 73, 'PP': 0.9, 'PR': 0.82, 'NP': 0.6, 'NR': 0.76, 'PosFb': 0.872, 'NegFb': 0.645}
#   Threshold 0.55: {'Len': 220, 'PC': 141, 'NC': 71, 'PP': 0.94, 'PR': 0.82, 'NP': 0.61, 'NR': 0.75, 'PosFb': 0.896, 'NegFb': 0.65}
# Best model: lb=8, score=0.826
# Models Saved for QQQ_duration_slow+duration_moderate+trend_ratio_slow 20 Returns
# ---------------------------
# Results for 8lb | 1940records | duration_slow+trend_moderate+trend_ratio_moderate | Test: 2025-09-19-2024-10-31 | QQQ_20
# Best CV split: 4 (score=0.82)
#   Threshold 0.5: {'Len': 220, 'PC': 141, 'NC': 79, 'PP': 0.96, 'PR': 0.84, 'NP': 0.66, 'NR': 0.9, 'PosFb': 0.916, 'NegFb': 0.724}
#   Threshold 0.55: {'Len': 220, 'PC': 125, 'NC': 62, 'PP': 0.95, 'PR': 0.73, 'NP': 0.81, 'NR': 0.87, 'PosFb': 0.863, 'NegFb': 0.829}
# Results for 10lb | 2430records | duration_slow+trend_moderate+trend_ratio_moderate | Test: 2025-09-19-2024-10-31 | QQQ_20
# Best CV split: 3 (score=0.85)
#   Threshold 0.5: {'Len': 220, 'PC': 154, 'NC': 66, 'PP': 0.94, 'PR': 0.89, 'NP': 0.74, 'NR': 0.84, 'PosFb': 0.923, 'NegFb': 0.771}
#   Threshold 0.55: {'Len': 220, 'PC': 145, 'NC': 60, 'PP': 0.94, 'PR': 0.84, 'NP': 0.77, 'NR': 0.8, 'PosFb': 0.904, 'NegFb': 0.78}
# Best model: lb=10, score=0.847
# Models Saved for QQQ_duration_slow+trend_moderate+trend_ratio_moderate 20 Returns
# ---------------------------
# Results for 8lb | 1935records | lag_fast+duration_moderate+volatility_fast_EMA10 | Test: 2025-09-12-2024-10-24 | QQQ_25
# Best CV split: 5 (score=0.79)
#   Threshold 0.5: {'Len': 220, 'PC': 168, 'NC': 52, 'PP': 0.88, 'PR': 0.91, 'NP': 0.71, 'NR': 0.65, 'PosFb': 0.89, 'NegFb': 0.689}
#   Threshold 0.55: {'Len': 220, 'PC': 160, 'NC': 48, 'PP': 0.89, 'PR': 0.87, 'NP': 0.71, 'NR': 0.6, 'PosFb': 0.883, 'NegFb': 0.669}
# Results for 10lb | 2425records | lag_fast+duration_moderate+volatility_fast_EMA10 | Test: 2025-09-12-2024-10-24 | QQQ_25
# Best CV split: 5 (score=0.84)
#   Threshold 0.5: {'Len': 220, 'PC': 170, 'NC': 50, 'PP': 0.9, 'PR': 0.94, 'NP': 0.8, 'NR': 0.7, 'PosFb': 0.913, 'NegFb': 0.764}
#   Threshold 0.55: {'Len': 220, 'PC': 155, 'NC': 44, 'PP': 0.92, 'PR': 0.87, 'NP': 0.8, 'NR': 0.62, 'PosFb': 0.903, 'NegFb': 0.729}
# Best model: lb=10, score=0.838
# Models Saved for QQQ_lag_fast+duration_moderate+volatility_fast_EMA10 25 Returns
# ---------------------------
# Results for 8lb | 1935records | lag_fast+trend_slow+volatility_moderate | Test: 2025-09-12-2024-10-24 | QQQ_25
# Best CV split: 3 (score=0.8)
#   Threshold 0.5: {'Len': 220, 'PC': 158, 'NC': 62, 'PP': 0.91, 'PR': 0.88, 'NP': 0.68, 'NR': 0.74, 'PosFb': 0.9, 'NegFb': 0.699}
#   Threshold 0.55: {'Len': 220, 'PC': 148, 'NC': 43, 'PP': 0.93, 'PR': 0.84, 'NP': 0.74, 'NR': 0.56, 'PosFb': 0.898, 'NegFb': 0.668}
# Results for 10lb | 2425records | lag_fast+trend_slow+volatility_moderate | Test: 2025-09-12-2024-10-24 | QQQ_25
# Best CV split: 3 (score=0.75)
#   Threshold 0.5: {'Len': 220, 'PC': 175, 'NC': 45, 'PP': 0.85, 'PR': 0.91, 'NP': 0.69, 'NR': 0.54, 'PosFb': 0.869, 'NegFb': 0.632}
#   Threshold 0.55: {'Len': 220, 'PC': 156, 'NC': 26, 'PP': 0.86, 'PR': 0.82, 'NP': 0.81, 'NR': 0.37, 'PosFb': 0.846, 'NegFb': 0.58}
# Best model: lb=8, score=0.8
# Models Saved for QQQ_lag_fast+trend_slow+volatility_moderate 25 Returns
# ---------------------------
# Results for 8lb | 1935records | duration_slow+duration_moderate+trend_ratio_slow | Test: 2025-09-12-2024-10-24 | QQQ_25
# Best CV split: 5 (score=0.82)
#   Threshold 0.5: {'Len': 220, 'PC': 157, 'NC': 63, 'PP': 0.92, 'PR': 0.89, 'NP': 0.7, 'NR': 0.77, 'PosFb': 0.91, 'NegFb': 0.722}
#   Threshold 0.55: {'Len': 220, 'PC': 152, 'NC': 55, 'PP': 0.93, 'PR': 0.87, 'NP': 0.76, 'NR': 0.73, 'PosFb': 0.909, 'NegFb': 0.75}
# Results for 10lb | 2425records | duration_slow+duration_moderate+trend_ratio_slow | Test: 2025-09-12-2024-10-24 | QQQ_25
# Best CV split: 5 (score=0.82)
#   Threshold 0.5: {'Len': 220, 'PC': 157, 'NC': 63, 'PP': 0.92, 'PR': 0.89, 'NP': 0.71, 'NR': 0.78, 'PosFb': 0.91, 'NegFb': 0.732}
#   Threshold 0.55: {'Len': 220, 'PC': 147, 'NC': 60, 'PP': 0.95, 'PR': 0.86, 'NP': 0.75, 'NR': 0.79, 'PosFb': 0.918, 'NegFb': 0.763}
# Best model: lb=10, score=0.821
# Models Saved for QQQ_duration_slow+duration_moderate+trend_ratio_slow 25 Returns
# ---------------------------
# Results for 8lb | 1935records | duration_slow+trend_moderate+trend_ratio_moderate | Test: 2025-09-12-2024-10-24 | QQQ_25
# Best CV split: 3 (score=0.89)
#   Threshold 0.5: {'Len': 220, 'PC': 156, 'NC': 64, 'PP': 0.96, 'PR': 0.92, 'NP': 0.8, 'NR': 0.9, 'PosFb': 0.946, 'NegFb': 0.831}
#   Threshold 0.55: {'Len': 220, 'PC': 147, 'NC': 53, 'PP': 0.96, 'PR': 0.87, 'NP': 0.85, 'NR': 0.79, 'PosFb': 0.928, 'NegFb': 0.829}
# Results for 10lb | 2425records | duration_slow+trend_moderate+trend_ratio_moderate | Test: 2025-09-12-2024-10-24 | QQQ_25
# Best CV split: 4 (score=0.87)
#   Threshold 0.5: {'Len': 220, 'PC': 154, 'NC': 66, 'PP': 0.96, 'PR': 0.91, 'NP': 0.77, 'NR': 0.89, 'PosFb': 0.943, 'NegFb': 0.806}
#   Threshold 0.55: {'Len': 220, 'PC': 146, 'NC': 58, 'PP': 0.96, 'PR': 0.86, 'NP': 0.83, 'NR': 0.84, 'PosFb': 0.924, 'NegFb': 0.833}
# Best model: lb=8, score=0.888
# Models Saved for QQQ_duration_slow+trend_moderate+trend_ratio_moderate 25 Returns
# ---------------------------
# Results for 8lb | 1935records | duration_fast+trend_moderate+trend_ratio_slow | Test: 2025-09-12-2024-10-24 | QQQ_25
# Best CV split: 5 (score=0.64)
#   Threshold 0.5: {'Len': 220, 'PC': 199, 'NC': 21, 'PP': 0.79, 'PR': 0.96, 'NP': 0.71, 'NR': 0.26, 'PosFb': 0.84, 'NegFb': 0.45}
#   Threshold 0.55: {'Len': 220, 'PC': 184, 'NC': 12, 'PP': 0.79, 'PR': 0.89, 'NP': 0.92, 'NR': 0.19, 'PosFb': 0.821, 'NegFb': 0.403}
# Results for 10lb | 2425records | duration_fast+trend_moderate+trend_ratio_slow | Test: 2025-09-12-2024-10-24 | QQQ_25
# Best CV split: 4 (score=0.63)
#   Threshold 0.5: {'Len': 220, 'PC': 200, 'NC': 20, 'PP': 0.78, 'PR': 0.96, 'NP': 0.7, 'NR': 0.25, 'PosFb': 0.832, 'NegFb': 0.437}
#   Threshold 0.55: {'Len': 220, 'PC': 190, 'NC': 15, 'PP': 0.78, 'PR': 0.91, 'NP': 0.73, 'NR': 0.19, 'PosFb': 0.819, 'NegFb': 0.375}
# Best model: lb=8, score=0.645
# Models Saved for QQQ_duration_fast+trend_moderate+trend_ratio_slow 25 Returns
# ---------------------------
# Results for 8lb | 1925records | lag_fast+trend_fast+trend_ratio_moderate | Test: 2025-08-28-2024-10-10 | QQQ_35
# Best CV split: 5 (score=0.65)
#   Threshold 0.5: {'Len': 220, 'PC': 189, 'NC': 31, 'PP': 0.83, 'PR': 0.91, 'NP': 0.52, 'NR': 0.34, 'PosFb': 0.855, 'NegFb': 0.442}
#   Threshold 0.55: {'Len': 220, 'PC': 170, 'NC': 8, 'PP': 0.82, 'PR': 0.81, 'NP': 1.0, 'NR': 0.17, 'PosFb': 0.817, 'NegFb': 0.381}
# Results for 10lb | 2415records | lag_fast+trend_fast+trend_ratio_moderate | Test: 2025-08-28-2024-10-10 | QQQ_35
# Best CV split: 4 (score=0.5)
#   Threshold 0.5: {'Len': 220, 'PC': 209, 'NC': 11, 'PP': 0.79, 'PR': 0.96, 'NP': 0.36, 'NR': 0.08, 'PosFb': 0.84, 'NegFb': 0.166}
#   Threshold 0.55: {'Len': 220, 'PC': 202, 'NC': 3, 'PP': 0.79, 'PR': 0.93, 'NP': 0.67, 'NR': 0.04, 'PosFb': 0.832, 'NegFb': 0.107}
# Best model: lb=8, score=0.648
# Models Saved for QQQ_lag_fast+trend_fast+trend_ratio_moderate 35 Returns
# ---------------------------
# Results for 8lb | 1925records | lag_fast+volatility_fast+momentum_slow | Test: 2025-08-28-2024-10-10 | QQQ_35
# Best CV split: 3 (score=0.7)
#   Threshold 0.5: {'Len': 220, 'PC': 200, 'NC': 20, 'PP': 0.84, 'PR': 0.98, 'NP': 0.75, 'NR': 0.31, 'PosFb': 0.882, 'NegFb': 0.509}
#   Threshold 0.55: {'Len': 220, 'PC': 188, 'NC': 11, 'PP': 0.84, 'PR': 0.92, 'NP': 1.0, 'NR': 0.23, 'PosFb': 0.865, 'NegFb': 0.473}
# Results for 10lb | 2415records | lag_fast+volatility_fast+momentum_slow | Test: 2025-08-28-2024-10-10 | QQQ_35
# Best CV split: 3 (score=0.59)
#   Threshold 0.5: {'Len': 220, 'PC': 206, 'NC': 14, 'PP': 0.81, 'PR': 0.97, 'NP': 0.57, 'NR': 0.17, 'PosFb': 0.857, 'NegFb': 0.319}
#   Threshold 0.55: {'Len': 220, 'PC': 200, 'NC': 1, 'PP': 0.82, 'PR': 0.95, 'NP': 1.0, 'NR': 0.02, 'PosFb': 0.859, 'NegFb': 0.058}
# Best model: lb=8, score=0.696
# Models Saved for QQQ_lag_fast+volatility_fast+momentum_slow 35 Returns
# ---------------------------
# Results for 8lb | 1925records | lag_fast+trend_ratio_fast+momentum_slow | Test: 2025-08-28-2024-10-10 | QQQ_35
# Best CV split: 5 (score=0.84)
#   Threshold 0.5: {'Len': 220, 'PC': 160, 'NC': 60, 'PP': 0.96, 'PR': 0.89, 'NP': 0.7, 'NR': 0.88, 'PosFb': 0.935, 'NegFb': 0.751}
#   Threshold 0.55: {'Len': 220, 'PC': 160, 'NC': 58, 'PP': 0.96, 'PR': 0.89, 'NP': 0.71, 'NR': 0.86, 'PosFb': 0.935, 'NegFb': 0.754}
# Results for 10lb | 2415records | lag_fast+trend_ratio_fast+momentum_slow | Test: 2025-08-28-2024-10-10 | QQQ_35
# Best CV split: 4 (score=0.71)
#   Threshold 0.5: {'Len': 220, 'PC': 186, 'NC': 34, 'PP': 0.85, 'PR': 0.92, 'NP': 0.62, 'NR': 0.44, 'PosFb': 0.872, 'NegFb': 0.546}
#   Threshold 0.55: {'Len': 220, 'PC': 177, 'NC': 28, 'PP': 0.86, 'PR': 0.88, 'NP': 0.57, 'NR': 0.33, 'PosFb': 0.867, 'NegFb': 0.459}
# Best model: lb=8, score=0.843
# Models Saved for QQQ_lag_fast+trend_ratio_fast+momentum_slow 35 Returns
# ---------------------------
# Results for 8lb | 1925records | duration_slow+trend_slow+trend_ratio_slow | Test: 2025-08-28-2024-10-10 | QQQ_35
# Best CV split: 3 (score=0.81)
#   Threshold 0.5: {'Len': 220, 'PC': 158, 'NC': 62, 'PP': 0.95, 'PR': 0.87, 'NP': 0.65, 'NR': 0.84, 'PosFb': 0.922, 'NegFb': 0.703}
#   Threshold 0.55: {'Len': 220, 'PC': 147, 'NC': 56, 'PP': 0.96, 'PR': 0.82, 'NP': 0.68, 'NR': 0.79, 'PosFb': 0.908, 'NegFb': 0.713}
# Results for 10lb | 2415records | duration_slow+trend_slow+trend_ratio_slow | Test: 2025-08-28-2024-10-10 | QQQ_35
# Best CV split: 3 (score=0.77)
#   Threshold 0.5: {'Len': 220, 'PC': 153, 'NC': 67, 'PP': 0.94, 'PR': 0.84, 'NP': 0.58, 'NR': 0.81, 'PosFb': 0.904, 'NegFb': 0.641}
#   Threshold 0.55: {'Len': 220, 'PC': 139, 'NC': 55, 'PP': 0.95, 'PR': 0.77, 'NP': 0.67, 'NR': 0.77, 'PosFb': 0.881, 'NegFb': 0.7}
# Best model: lb=8, score=0.812
# Models Saved for QQQ_duration_slow+trend_slow+trend_ratio_slow 35 Returns
# ---------------------------
# Results for 8lb | 1915records | lag_fast+trend_moderate+trend_ratio_slow | Test: 2025-08-14-2024-09-26 | QQQ_45
# Best CV split: 4 (score=0.9)
#   Threshold 0.5: {'Len': 220, 'PC': 173, 'NC': 47, 'PP': 0.94, 'PR': 0.97, 'NP': 0.89, 'NR': 0.79, 'PosFb': 0.95, 'NegFb': 0.854}
#   Threshold 0.55: {'Len': 220, 'PC': 148, 'NC': 32, 'PP': 0.95, 'PR': 0.84, 'NP': 0.91, 'NR': 0.55, 'PosFb': 0.91, 'NegFb': 0.747}
# Results for 10lb | 2405records | lag_fast+trend_moderate+trend_ratio_slow | Test: 2025-08-14-2024-09-26 | QQQ_45
# Best CV split: 3 (score=0.41)
#   Threshold 0.5: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.76, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.826, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.76, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.826, 'NegFb': 0.0}
# Best model: lb=8, score=0.902
# Models Saved for QQQ_lag_fast+trend_moderate+trend_ratio_slow 45 Returns
# ---------------------------
# Results for 8lb | 1915records | lag_fast+trend_ratio_slow+volatility_moderate | Test: 2025-08-14-2024-09-26 | QQQ_45
# Best CV split: 4 (score=0.78)
#   Threshold 0.5: {'Len': 220, 'PC': 158, 'NC': 62, 'PP': 0.91, 'PR': 0.86, 'NP': 0.63, 'NR': 0.74, 'PosFb': 0.893, 'NegFb': 0.663}
#   Threshold 0.55: {'Len': 220, 'PC': 134, 'NC': 50, 'PP': 0.93, 'PR': 0.75, 'NP': 0.62, 'NR': 0.58, 'PosFb': 0.861, 'NegFb': 0.606}
# Results for 10lb | 2405records | lag_fast+trend_ratio_slow+volatility_moderate | Test: 2025-08-14-2024-09-26 | QQQ_45
# Best CV split: 3 (score=0.55)
#   Threshold 0.5: {'Len': 220, 'PC': 176, 'NC': 44, 'PP': 0.78, 'PR': 0.82, 'NP': 0.32, 'NR': 0.27, 'PosFb': 0.793, 'NegFb': 0.301}
#   Threshold 0.55: {'Len': 220, 'PC': 166, 'NC': 33, 'PP': 0.83, 'PR': 0.83, 'NP': 0.09, 'NR': 0.06, 'PosFb': 0.83, 'NegFb': 0.077}
# Best model: lb=8, score=0.778
# Models Saved for QQQ_lag_fast+trend_ratio_slow+volatility_moderate 45 Returns
# ---------------------------
# Results for 8lb | 1915records | duration_slow+duration_moderate+trend_fast | Test: 2025-08-14-2024-09-26 | QQQ_45
# Best CV split: 3 (score=0.41)
#   Threshold 0.5: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.76, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.826, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 220, 'PC': 196, 'NC': 0, 'PP': 0.8, 'PR': 0.94, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.842, 'NegFb': 0.0}
# Results for 10lb | 2405records | duration_slow+duration_moderate+trend_fast | Test: 2025-08-14-2024-09-26 | QQQ_45
# Best CV split: 3 (score=0.41)
#   Threshold 0.5: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.76, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.826, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.76, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.826, 'NegFb': 0.0}
# Best model: lb=8, score=0.413
# Models Saved for QQQ_duration_slow+duration_moderate+trend_fast 45 Returns
# ---------------------------
# Results for 8lb | 1915records | duration_slow+duration_moderate+volatility_moderate | Test: 2025-08-14-2024-09-26 | QQQ_45
# Best CV split: 4 (score=0.5)
#   Threshold 0.5: {'Len': 220, 'PC': 207, 'NC': 13, 'PP': 0.77, 'PR': 0.95, 'NP': 0.38, 'NR': 0.09, 'PosFb': 0.822, 'NegFb': 0.183}
#   Threshold 0.55: {'Len': 220, 'PC': 200, 'NC': 2, 'PP': 0.78, 'PR': 0.93, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.824, 'NegFb': 0.0}
# Results for 10lb | 2405records | duration_slow+duration_moderate+volatility_moderate | Test: 2025-08-14-2024-09-26 | QQQ_45
# Best CV split: 3 (score=0.41)
#   Threshold 0.5: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.76, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.826, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.76, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.826, 'NegFb': 0.0}
# Best model: lb=8, score=0.502
# Models Saved for QQQ_duration_slow+duration_moderate+volatility_moderate 45 Returns
# ---------------------------
# Results for 8lb | 1915records | momentum_moderate+momentum_fast_EMA10+all_seasons | Test: 2025-08-14-2024-09-26 | QQQ_45
# Best CV split: 4 (score=0.56)
#   Threshold 0.5: {'Len': 220, 'PC': 214, 'NC': 6, 'PP': 0.78, 'PR': 1.0, 'NP': 1.0, 'NR': 0.11, 'PosFb': 0.842, 'NegFb': 0.27}
#   Threshold 0.55: {'Len': 220, 'PC': 204, 'NC': 1, 'PP': 0.79, 'PR': 0.97, 'NP': 1.0, 'NR': 0.02, 'PosFb': 0.842, 'NegFb': 0.058}
# Results for 10lb | 2405records | momentum_moderate+momentum_fast_EMA10+all_seasons | Test: 2025-08-14-2024-09-26 | QQQ_45
# Best CV split: 3 (score=0.41)
#   Threshold 0.5: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.76, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.826, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 220, 'PC': 220, 'NC': 0, 'PP': 0.76, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.826, 'NegFb': 0.0}
# Best model: lb=8, score=0.556
# Models Saved for QQQ_momentum_moderate+momentum_fast_EMA10+all_seasons 45 Returns
# ---------------------------
# Results for 8lb | 1955records | duration_slow+trend_ratio_slow+momentum_fast_EMA10 | Test: 2025-10-10-2025-02-06 | QQQ_5
# Best CV split: 5 (score=0.66)
#   Threshold 0.5: {'Len': 170, 'PC': 133, 'NC': 37, 'PP': 0.74, 'PR': 0.89, 'NP': 0.65, 'NR': 0.41, 'PosFb': 0.784, 'NegFb': 0.544}
#   Threshold 0.55: {'Len': 170, 'PC': 113, 'NC': 16, 'PP': 0.74, 'PR': 0.75, 'NP': 0.75, 'NR': 0.2, 'PosFb': 0.743, 'NegFb': 0.391}
# Results for 10lb | 2445records | duration_slow+trend_ratio_slow+momentum_fast_EMA10 | Test: 2025-10-10-2025-02-06 | QQQ_5
# Best CV split: 3 (score=0.59)
#   Threshold 0.5: {'Len': 170, 'PC': 153, 'NC': 17, 'PP': 0.7, 'PR': 0.96, 'NP': 0.76, 'NR': 0.22, 'PosFb': 0.769, 'NegFb': 0.418}
#   Threshold 0.55: {'Len': 170, 'PC': 127, 'NC': 4, 'PP': 0.71, 'PR': 0.81, 'NP': 1.0, 'NR': 0.07, 'PosFb': 0.74, 'NegFb': 0.184}
# Best model: lb=8, score=0.664
# Models Saved for QQQ_duration_slow+trend_ratio_slow+momentum_fast_EMA10 5 Returns
# ---------------------------
# Results for 8lb | 1955records | lag_fast+trend_slow+momentum_moderate | Test: 2025-10-10-2025-02-06 | QQQ_5
# Best CV split: 3 (score=0.61)
#   Threshold 0.5: {'Len': 170, 'PC': 146, 'NC': 24, 'PP': 0.71, 'PR': 0.93, 'NP': 0.67, 'NR': 0.27, 'PosFb': 0.771, 'NegFb': 0.449}
#   Threshold 0.55: {'Len': 170, 'PC': 134, 'NC': 12, 'PP': 0.75, 'PR': 0.91, 'NP': 0.67, 'NR': 0.14, 'PosFb': 0.797, 'NegFb': 0.296}
# Results for 10lb | 2445records | lag_fast+trend_slow+momentum_moderate | Test: 2025-10-10-2025-02-06 | QQQ_5
# Best CV split: 4 (score=0.61)
#   Threshold 0.5: {'Len': 170, 'PC': 155, 'NC': 15, 'PP': 0.7, 'PR': 0.98, 'NP': 0.87, 'NR': 0.22, 'PosFb': 0.774, 'NegFb': 0.438}
#   Threshold 0.55: {'Len': 170, 'PC': 142, 'NC': 9, 'PP': 0.72, 'PR': 0.92, 'NP': 0.89, 'NR': 0.14, 'PosFb': 0.776, 'NegFb': 0.319}
# Best model: lb=8, score=0.61
# Models Saved for QQQ_lag_fast+trend_slow+momentum_moderate 5 Returns
# ---------------------------
# Results for 8lb | 1955records | duration_slow+trend_ratio_slow+momentum_moderate | Test: 2025-10-10-2025-02-06 | QQQ_5
# Best CV split: 4 (score=0.7)
#   Threshold 0.5: {'Len': 170, 'PC': 144, 'NC': 26, 'PP': 0.74, 'PR': 0.96, 'NP': 0.85, 'NR': 0.37, 'PosFb': 0.801, 'NegFb': 0.593}
#   Threshold 0.55: {'Len': 170, 'PC': 125, 'NC': 15, 'PP': 0.74, 'PR': 0.83, 'NP': 0.93, 'NR': 0.24, 'PosFb': 0.768, 'NegFb': 0.475}
# Results for 10lb | 2445records | duration_slow+trend_ratio_slow+momentum_moderate | Test: 2025-10-10-2025-02-06 | QQQ_5
# Best CV split: 5 (score=0.68)
#   Threshold 0.5: {'Len': 170, 'PC': 150, 'NC': 20, 'PP': 0.73, 'PR': 0.99, 'NP': 0.9, 'NR': 0.31, 'PosFb': 0.8, 'NegFb': 0.551}
#   Threshold 0.55: {'Len': 170, 'PC': 136, 'NC': 11, 'PP': 0.73, 'PR': 0.89, 'NP': 1.0, 'NR': 0.19, 'PosFb': 0.777, 'NegFb': 0.413}
# Best model: lb=8, score=0.697
# Models Saved for QQQ_duration_slow+trend_ratio_slow+momentum_moderate 5 Returns
# ---------------------------
# Results for 8lb | 1955records | trend_ratio_moderate+momentum_moderate+momentum_fast_EMA10 | Test: 2025-10-10-2025-02-06 | QQQ_5
# Best CV split: 5 (score=0.69)
#   Threshold 0.5: {'Len': 170, 'PC': 135, 'NC': 35, 'PP': 0.75, 'PR': 0.91, 'NP': 0.71, 'NR': 0.42, 'PosFb': 0.797, 'NegFb': 0.577}
#   Threshold 0.55: {'Len': 170, 'PC': 113, 'NC': 24, 'PP': 0.78, 'PR': 0.79, 'NP': 0.75, 'NR': 0.31, 'PosFb': 0.783, 'NegFb': 0.509}
# Results for 10lb | 2445records | trend_ratio_moderate+momentum_moderate+momentum_fast_EMA10 | Test: 2025-10-10-2025-02-06 | QQQ_5
# Best CV split: 3 (score=0.59)
#   Threshold 0.5: {'Len': 170, 'PC': 153, 'NC': 17, 'PP': 0.7, 'PR': 0.96, 'NP': 0.76, 'NR': 0.22, 'PosFb': 0.769, 'NegFb': 0.418}
#   Threshold 0.55: {'Len': 170, 'PC': 131, 'NC': 8, 'PP': 0.73, 'PR': 0.86, 'NP': 1.0, 'NR': 0.14, 'PosFb': 0.769, 'NegFb': 0.328}
# Best model: lb=8, score=0.687
# Models Saved for QQQ_trend_ratio_moderate+momentum_moderate+momentum_fast_EMA10 5 Returns
# ---------------------------
# Results for 8lb | 1950records | duration_moderate+duration_fast+trend_ratio_slow | Test: 2025-10-03-2025-01-30 | QQQ_10
# Best CV split: 3 (score=0.39)
#   Threshold 0.5: {'Len': 170, 'PC': 170, 'NC': 0, 'PP': 0.7, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.778, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 170, 'PC': 170, 'NC': 0, 'PP': 0.7, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.778, 'NegFb': 0.0}
# Results for 10lb | 2440records | duration_moderate+duration_fast+trend_ratio_slow | Test: 2025-10-03-2025-01-30 | QQQ_10
# Best CV split: 4 (score=0.42)
#   Threshold 0.5: {'Len': 170, 'PC': 154, 'NC': 16, 'PP': 0.68, 'PR': 0.89, 'NP': 0.19, 'NR': 0.06, 'PosFb': 0.738, 'NegFb': 0.11}
#   Threshold 0.55: {'Len': 170, 'PC': 146, 'NC': 9, 'PP': 0.71, 'PR': 0.88, 'NP': 0.33, 'NR': 0.06, 'PosFb': 0.759, 'NegFb': 0.132}
# Best model: lb=10, score=0.424
# Models Saved for QQQ_duration_moderate+duration_fast+trend_ratio_slow 10 Returns
# ---------------------------
# Results for 8lb | 1950records | duration_slow+duration_fast+trend_fast | Test: 2025-10-03-2025-01-30 | QQQ_10
# Best CV split: 3 (score=0.8)
#   Threshold 0.5: {'Len': 170, 'PC': 112, 'NC': 58, 'PP': 0.9, 'PR': 0.85, 'NP': 0.69, 'NR': 0.78, 'PosFb': 0.883, 'NegFb': 0.718}
#   Threshold 0.55: {'Len': 170, 'PC': 105, 'NC': 48, 'PP': 0.92, 'PR': 0.81, 'NP': 0.73, 'NR': 0.69, 'PosFb': 0.88, 'NegFb': 0.716}
# Results for 10lb | 2440records | duration_slow+duration_fast+trend_fast | Test: 2025-10-03-2025-01-30 | QQQ_10
# Best CV split: 3 (score=0.81)
#   Threshold 0.5: {'Len': 170, 'PC': 130, 'NC': 40, 'PP': 0.85, 'PR': 0.94, 'NP': 0.82, 'NR': 0.63, 'PosFb': 0.878, 'NegFb': 0.745}
#   Threshold 0.55: {'Len': 170, 'PC': 114, 'NC': 35, 'PP': 0.9, 'PR': 0.87, 'NP': 0.86, 'NR': 0.58, 'PosFb': 0.89, 'NegFb': 0.741}
# Best model: lb=10, score=0.812
# Models Saved for QQQ_duration_slow+duration_fast+trend_fast 10 Returns
# ---------------------------
# Results for 8lb | 1950records | duration_slow+trend_ratio_slow+trend_ratio_moderate | Test: 2025-10-03-2025-01-30 | QQQ_10
# Best CV split: 5 (score=0.76)
#   Threshold 0.5: {'Len': 170, 'PC': 135, 'NC': 35, 'PP': 0.82, 'PR': 0.93, 'NP': 0.77, 'NR': 0.53, 'PosFb': 0.854, 'NegFb': 0.669}
#   Threshold 0.55: {'Len': 170, 'PC': 124, 'NC': 33, 'PP': 0.87, 'PR': 0.91, 'NP': 0.76, 'NR': 0.49, 'PosFb': 0.883, 'NegFb': 0.642}
# Results for 10lb | 2440records | duration_slow+trend_ratio_slow+trend_ratio_moderate | Test: 2025-10-03-2025-01-30 | QQQ_10
# Best CV split: 5 (score=0.78)
#   Threshold 0.5: {'Len': 170, 'PC': 129, 'NC': 41, 'PP': 0.84, 'PR': 0.92, 'NP': 0.76, 'NR': 0.6, 'PosFb': 0.865, 'NegFb': 0.698}
#   Threshold 0.55: {'Len': 170, 'PC': 120, 'NC': 21, 'PP': 0.84, 'PR': 0.85, 'NP': 0.9, 'NR': 0.36, 'PosFb': 0.843, 'NegFb': 0.6}
# Best model: lb=10, score=0.782
# Models Saved for QQQ_duration_slow+trend_ratio_slow+trend_ratio_moderate 10 Returns
# ---------------------------
# Results for 8lb | 1950records | trend_slow+trend_fast+trend_ratio_fast | Test: 2025-10-03-2025-01-30 | QQQ_10
# Best CV split: 3 (score=0.68)
#   Threshold 0.5: {'Len': 170, 'PC': 151, 'NC': 19, 'PP': 0.77, 'PR': 0.98, 'NP': 0.84, 'NR': 0.31, 'PosFb': 0.829, 'NegFb': 0.535}
#   Threshold 0.55: {'Len': 170, 'PC': 149, 'NC': 19, 'PP': 0.77, 'PR': 0.96, 'NP': 0.84, 'NR': 0.31, 'PosFb': 0.824, 'NegFb': 0.535}
# Results for 10lb | 2440records | trend_slow+trend_fast+trend_ratio_fast | Test: 2025-10-03-2025-01-30 | QQQ_10
# Best CV split: 3 (score=0.62)
#   Threshold 0.5: {'Len': 170, 'PC': 152, 'NC': 18, 'PP': 0.74, 'PR': 0.95, 'NP': 0.72, 'NR': 0.25, 'PosFb': 0.799, 'NegFb': 0.443}
#   Threshold 0.55: {'Len': 170, 'PC': 144, 'NC': 14, 'PP': 0.78, 'PR': 0.95, 'NP': 0.71, 'NR': 0.19, 'PosFb': 0.829, 'NegFb': 0.371}
# Best model: lb=8, score=0.682
# Models Saved for QQQ_trend_slow+trend_fast+trend_ratio_fast 10 Returns
# ---------------------------
# Results for 8lb | 1945records | duration_moderate+duration_fast+trend_slow | Test: 2025-09-26-2025-01-23 | QQQ_15
# Best CV split: 5 (score=0.66)
#   Threshold 0.5: {'Len': 170, 'PC': 138, 'NC': 32, 'PP': 0.79, 'PR': 0.89, 'NP': 0.59, 'NR': 0.39, 'PosFb': 0.821, 'NegFb': 0.504}
#   Threshold 0.55: {'Len': 170, 'PC': 136, 'NC': 32, 'PP': 0.8, 'PR': 0.89, 'NP': 0.59, 'NR': 0.39, 'PosFb': 0.828, 'NegFb': 0.504}
# Results for 10lb | 2435records | duration_moderate+duration_fast+trend_slow | Test: 2025-09-26-2025-01-23 | QQQ_15
# Best CV split: 4 (score=0.75)
#   Threshold 0.5: {'Len': 170, 'PC': 141, 'NC': 29, 'PP': 0.82, 'PR': 0.95, 'NP': 0.79, 'NR': 0.48, 'PosFb': 0.859, 'NegFb': 0.65}
#   Threshold 0.55: {'Len': 170, 'PC': 140, 'NC': 23, 'PP': 0.83, 'PR': 0.95, 'NP': 0.83, 'NR': 0.4, 'PosFb': 0.866, 'NegFb': 0.611}
# Best model: lb=10, score=0.754
# Models Saved for QQQ_duration_moderate+duration_fast+trend_slow 15 Returns
# ---------------------------
# Results for 8lb | 1945records | trend_ratio_slow+momentum_moderate+momentum_fast_EMA10 | Test: 2025-09-26-2025-01-23 | QQQ_15
# Best CV split: 4 (score=0.68)
#   Threshold 0.5: {'Len': 170, 'PC': 138, 'NC': 32, 'PP': 0.8, 'PR': 0.9, 'NP': 0.62, 'NR': 0.41, 'PosFb': 0.831, 'NegFb': 0.53}
#   Threshold 0.55: {'Len': 170, 'PC': 117, 'NC': 23, 'PP': 0.85, 'PR': 0.82, 'NP': 0.65, 'NR': 0.31, 'PosFb': 0.84, 'NegFb': 0.476}
# Results for 10lb | 2435records | trend_ratio_slow+momentum_moderate+momentum_fast_EMA10 | Test: 2025-09-26-2025-01-23 | QQQ_15
# Best CV split: 4 (score=0.71)
#   Threshold 0.5: {'Len': 170, 'PC': 147, 'NC': 23, 'PP': 0.8, 'PR': 0.96, 'NP': 0.78, 'NR': 0.37, 'PosFb': 0.847, 'NegFb': 0.57}
#   Threshold 0.55: {'Len': 170, 'PC': 136, 'NC': 13, 'PP': 0.82, 'PR': 0.91, 'NP': 0.85, 'NR': 0.23, 'PosFb': 0.848, 'NegFb': 0.448}
# Best model: lb=10, score=0.708
# Models Saved for QQQ_trend_ratio_slow+momentum_moderate+momentum_fast_EMA10 15 Returns
# ---------------------------
# Results for 8lb | 1945records | trend_slow+trend_ratio_slow+trend_ratio_fast | Test: 2025-09-26-2025-01-23 | QQQ_15
# Best CV split: 5 (score=0.86)
#   Threshold 0.5: {'Len': 170, 'PC': 132, 'NC': 38, 'PP': 0.89, 'PR': 0.96, 'NP': 0.87, 'NR': 0.69, 'PosFb': 0.912, 'NegFb': 0.8}
#   Threshold 0.55: {'Len': 170, 'PC': 125, 'NC': 30, 'PP': 0.9, 'PR': 0.92, 'NP': 0.97, 'NR': 0.61, 'PosFb': 0.907, 'NegFb': 0.811}
# Results for 10lb | 2435records | trend_slow+trend_ratio_slow+trend_ratio_fast | Test: 2025-09-26-2025-01-23 | QQQ_15
# Best CV split: 5 (score=0.84)
#   Threshold 0.5: {'Len': 170, 'PC': 133, 'NC': 37, 'PP': 0.88, 'PR': 0.96, 'NP': 0.86, 'NR': 0.66, 'PosFb': 0.905, 'NegFb': 0.781}
#   Threshold 0.55: {'Len': 170, 'PC': 125, 'NC': 29, 'PP': 0.88, 'PR': 0.9, 'NP': 0.9, 'NR': 0.54, 'PosFb': 0.887, 'NegFb': 0.736}
# Best model: lb=8, score=0.856
# Models Saved for QQQ_trend_slow+trend_ratio_slow+trend_ratio_fast 15 Returns
# ---------------------------
# Results for 8lb | 1945records | duration_slow+duration_fast+trend_ratio_moderate | Test: 2025-09-26-2025-01-23 | QQQ_15
# Best CV split: 4 (score=0.84)
#   Threshold 0.5: {'Len': 170, 'PC': 125, 'NC': 45, 'PP': 0.9, 'PR': 0.92, 'NP': 0.8, 'NR': 0.75, 'PosFb': 0.907, 'NegFb': 0.783}
#   Threshold 0.55: {'Len': 170, 'PC': 121, 'NC': 38, 'PP': 0.91, 'PR': 0.9, 'NP': 0.79, 'NR': 0.63, 'PosFb': 0.907, 'NegFb': 0.728}
# Results for 10lb | 2435records | duration_slow+duration_fast+trend_ratio_moderate | Test: 2025-09-26-2025-01-23 | QQQ_15
# Best CV split: 4 (score=0.85)
#   Threshold 0.5: {'Len': 170, 'PC': 126, 'NC': 44, 'PP': 0.9, 'PR': 0.93, 'NP': 0.82, 'NR': 0.75, 'PosFb': 0.91, 'NegFb': 0.795}
#   Threshold 0.55: {'Len': 170, 'PC': 120, 'NC': 42, 'PP': 0.91, 'PR': 0.9, 'NP': 0.83, 'NR': 0.73, 'PosFb': 0.907, 'NegFb': 0.794}
# Best model: lb=10, score=0.852
# Models Saved for QQQ_duration_slow+duration_fast+trend_ratio_moderate 15 Returns
# ---------------------------
# Results for 8lb | 1945records | trend_fast+trend_ratio_moderate+volatility_fast | Test: 2025-09-26-2025-01-23 | QQQ_15
# Best CV split: 4 (score=0.56)
#   Threshold 0.5: {'Len': 170, 'PC': 152, 'NC': 18, 'PP': 0.74, 'PR': 0.92, 'NP': 0.5, 'NR': 0.19, 'PosFb': 0.792, 'NegFb': 0.324}
#   Threshold 0.55: {'Len': 170, 'PC': 135, 'NC': 13, 'PP': 0.76, 'PR': 0.84, 'NP': 0.62, 'NR': 0.17, 'PosFb': 0.785, 'NegFb': 0.329}
# Results for 10lb | 2435records | trend_fast+trend_ratio_moderate+volatility_fast | Test: 2025-09-26-2025-01-23 | QQQ_15
# Best CV split: 3 (score=0.6)
#   Threshold 0.5: {'Len': 170, 'PC': 139, 'NC': 31, 'PP': 0.76, 'PR': 0.87, 'NP': 0.48, 'NR': 0.31, 'PosFb': 0.793, 'NegFb': 0.406}
#   Threshold 0.55: {'Len': 170, 'PC': 125, 'NC': 18, 'PP': 0.8, 'PR': 0.82, 'NP': 0.44, 'NR': 0.16, 'PosFb': 0.807, 'NegFb': 0.278}
# Best model: lb=10, score=0.6
# Models Saved for QQQ_trend_fast+trend_ratio_moderate+volatility_fast 15 Returns
# ---------------------------
# Results for 8lb | 1940records | lag_fast+trend_slow+volatility_moderate | Test: 2025-09-19-2025-01-15 | QQQ_20
# Best CV split: 3 (score=0.83)
#   Threshold 0.5: {'Len': 170, 'PC': 133, 'NC': 37, 'PP': 0.89, 'PR': 0.95, 'NP': 0.81, 'NR': 0.67, 'PosFb': 0.909, 'NegFb': 0.757}
#   Threshold 0.55: {'Len': 170, 'PC': 125, 'NC': 33, 'PP': 0.9, 'PR': 0.9, 'NP': 0.88, 'NR': 0.65, 'PosFb': 0.9, 'NegFb': 0.787}
# Results for 10lb | 2430records | lag_fast+trend_slow+volatility_moderate | Test: 2025-09-19-2025-01-15 | QQQ_20
# Best CV split: 4 (score=0.69)
#   Threshold 0.5: {'Len': 170, 'PC': 158, 'NC': 12, 'PP': 0.79, 'PR': 1.0, 'NP': 1.0, 'NR': 0.27, 'PosFb': 0.849, 'NegFb': 0.526}
#   Threshold 0.55: {'Len': 170, 'PC': 149, 'NC': 6, 'PP': 0.79, 'PR': 0.94, 'NP': 1.0, 'NR': 0.13, 'PosFb': 0.834, 'NegFb': 0.31}
# Best model: lb=8, score=0.833
# Models Saved for QQQ_lag_fast+trend_slow+volatility_moderate 20 Returns
# ---------------------------
# Results for 8lb | 1940records | lag_fast+trend_slow+trend_moderate | Test: 2025-09-19-2025-01-15 | QQQ_20
# Best CV split: 5 (score=0.8)
#   Threshold 0.5: {'Len': 170, 'PC': 131, 'NC': 39, 'PP': 0.88, 'PR': 0.92, 'NP': 0.74, 'NR': 0.64, 'PosFb': 0.893, 'NegFb': 0.703}
#   Threshold 0.55: {'Len': 170, 'PC': 125, 'NC': 35, 'PP': 0.89, 'PR': 0.89, 'NP': 0.77, 'NR': 0.6, 'PosFb': 0.89, 'NegFb': 0.704}
# Results for 10lb | 2430records | lag_fast+trend_slow+trend_moderate | Test: 2025-09-19-2025-01-15 | QQQ_20
# Best CV split: 4 (score=0.83)
#   Threshold 0.5: {'Len': 170, 'PC': 133, 'NC': 37, 'PP': 0.89, 'PR': 0.95, 'NP': 0.81, 'NR': 0.67, 'PosFb': 0.909, 'NegFb': 0.757}
#   Threshold 0.55: {'Len': 170, 'PC': 125, 'NC': 32, 'PP': 0.9, 'PR': 0.9, 'NP': 0.78, 'NR': 0.55, 'PosFb': 0.9, 'NegFb': 0.685}
# Best model: lb=10, score=0.833
# Models Saved for QQQ_lag_fast+trend_slow+trend_moderate 20 Returns
# ---------------------------
# Results for 8lb | 1940records | duration_moderate+trend_ratio_slow+momentum_moderate | Test: 2025-09-19-2025-01-15 | QQQ_20
# Best CV split: 3 (score=0.8)
#   Threshold 0.5: {'Len': 170, 'PC': 123, 'NC': 47, 'PP': 0.9, 'PR': 0.89, 'NP': 0.7, 'NR': 0.73, 'PosFb': 0.897, 'NegFb': 0.71}
#   Threshold 0.55: {'Len': 170, 'PC': 110, 'NC': 41, 'PP': 0.91, 'PR': 0.8, 'NP': 0.76, 'NR': 0.69, 'PosFb': 0.87, 'NegFb': 0.735}
# Results for 10lb | 2430records | duration_moderate+trend_ratio_slow+momentum_moderate | Test: 2025-09-19-2025-01-15 | QQQ_20
# Best CV split: 3 (score=0.84)
#   Threshold 0.5: {'Len': 170, 'PC': 130, 'NC': 40, 'PP': 0.9, 'PR': 0.94, 'NP': 0.8, 'NR': 0.71, 'PosFb': 0.913, 'NegFb': 0.768}
#   Threshold 0.55: {'Len': 170, 'PC': 120, 'NC': 39, 'PP': 0.91, 'PR': 0.87, 'NP': 0.79, 'NR': 0.68, 'PosFb': 0.896, 'NegFb': 0.75}
# Best model: lb=10, score=0.84
# Models Saved for QQQ_duration_moderate+trend_ratio_slow+momentum_moderate 20 Returns
# ---------------------------
# Results for 8lb | 1940records | duration_slow+duration_moderate+trend_ratio_slow | Test: 2025-09-19-2025-01-15 | QQQ_20
# Best CV split: 4 (score=0.78)
#   Threshold 0.5: {'Len': 170, 'PC': 108, 'NC': 62, 'PP': 0.94, 'PR': 0.81, 'NP': 0.61, 'NR': 0.84, 'PosFb': 0.892, 'NegFb': 0.671}
#   Threshold 0.55: {'Len': 170, 'PC': 102, 'NC': 61, 'PP': 0.95, 'PR': 0.78, 'NP': 0.61, 'NR': 0.83, 'PosFb': 0.886, 'NegFb': 0.669}
# Results for 10lb | 2430records | duration_slow+duration_moderate+trend_ratio_slow | Test: 2025-09-19-2025-01-15 | QQQ_20
# Best CV split: 4 (score=0.84)
#   Threshold 0.5: {'Len': 170, 'PC': 122, 'NC': 48, 'PP': 0.93, 'PR': 0.91, 'NP': 0.75, 'NR': 0.8, 'PosFb': 0.923, 'NegFb': 0.766}
#   Threshold 0.55: {'Len': 170, 'PC': 107, 'NC': 37, 'PP': 0.93, 'PR': 0.8, 'NP': 0.84, 'NR': 0.69, 'PosFb': 0.882, 'NegFb': 0.783}
# Best model: lb=10, score=0.844
# Models Saved for QQQ_duration_slow+duration_moderate+trend_ratio_slow 20 Returns
# ---------------------------
# Results for 8lb | 1940records | duration_slow+trend_moderate+trend_ratio_moderate | Test: 2025-09-19-2025-01-15 | QQQ_20
# Best CV split: 5 (score=0.87)
#   Threshold 0.5: {'Len': 170, 'PC': 120, 'NC': 50, 'PP': 0.95, 'PR': 0.91, 'NP': 0.78, 'NR': 0.87, 'PosFb': 0.936, 'NegFb': 0.808}
#   Threshold 0.55: {'Len': 170, 'PC': 116, 'NC': 46, 'PP': 0.95, 'PR': 0.88, 'NP': 0.8, 'NR': 0.82, 'PosFb': 0.925, 'NegFb': 0.807}
# Results for 10lb | 2430records | duration_slow+trend_moderate+trend_ratio_moderate | Test: 2025-09-19-2025-01-15 | QQQ_20
# Best CV split: 3 (score=0.86)
#   Threshold 0.5: {'Len': 170, 'PC': 128, 'NC': 42, 'PP': 0.91, 'PR': 0.93, 'NP': 0.81, 'NR': 0.76, 'PosFb': 0.917, 'NegFb': 0.793}
#   Threshold 0.55: {'Len': 170, 'PC': 122, 'NC': 36, 'PP': 0.94, 'PR': 0.92, 'NP': 0.78, 'NR': 0.62, 'PosFb': 0.933, 'NegFb': 0.718}
# Best model: lb=8, score=0.872
# Models Saved for QQQ_duration_slow+trend_moderate+trend_ratio_moderate 20 Returns
# ---------------------------
# Results for 8lb | 1935records | lag_fast+duration_moderate+volatility_fast_EMA10 | Test: 2025-09-12-2025-01-07 | QQQ_25
# Best CV split: 4 (score=0.81)
#   Threshold 0.5: {'Len': 170, 'PC': 128, 'NC': 42, 'PP': 0.88, 'PR': 0.92, 'NP': 0.76, 'NR': 0.68, 'PosFb': 0.893, 'NegFb': 0.731}
# ...
# Results for 8lb | 1940records | duration_moderate+trend_ratio_slow+momentum_moderate | Test: 2025-09-19-2025-03-28 | QQQ_20
# Best CV split: 4 (score=0.73)
#   Threshold 0.5: {'Len': 120, 'PC': 101, 'NC': 19, 'PP': 0.99, 'PR': 0.9, 'NP': 0.42, 'NR': 0.89, 'PosFb': 0.958, 'NegFb': 0.51}
#   Threshold 0.55: {'Len': 120, 'PC': 98, 'NC': 17, 'PP': 1.0, 'PR': 0.88, 'NP': 0.47, 'NR': 0.89, 'PosFb': 0.957, 'NegFb': 0.558}
# Results for 10lb | 2430records | duration_moderate+trend_ratio_slow+momentum_moderate | Test: 2025-09-19-2025-03-28 | QQQ_20
# Best CV split: 3 (score=0.77)
#   Threshold 0.5: {'Len': 120, 'PC': 103, 'NC': 17, 'PP': 1.0, 'PR': 0.92, 'NP': 0.47, 'NR': 1.0, 'PosFb': 0.972, 'NegFb': 0.571}
#   Threshold 0.55: {'Len': 120, 'PC': 99, 'NC': 16, 'PP': 1.0, 'PR': 0.88, 'NP': 0.44, 'NR': 0.88, 'PosFb': 0.957, 'NegFb': 0.528}
# Best model: lb=10, score=0.772
# Models Saved for QQQ_duration_moderate+trend_ratio_slow+momentum_moderate 20 Returns
# ---------------------------
# Results for 8lb | 1940records | duration_slow+duration_moderate+trend_ratio_slow | Test: 2025-09-19-2025-03-28 | QQQ_20
# Best CV split: 5 (score=0.88)
#   Threshold 0.5: {'Len': 120, 'PC': 109, 'NC': 11, 'PP': 0.99, 'PR': 0.97, 'NP': 0.73, 'NR': 0.89, 'PosFb': 0.983, 'NegFb': 0.777}
#   Threshold 0.55: {'Len': 120, 'PC': 106, 'NC': 11, 'PP': 1.0, 'PR': 0.95, 'NP': 0.73, 'NR': 0.89, 'PosFb': 0.983, 'NegFb': 0.777}
# Results for 10lb | 2430records | duration_slow+duration_moderate+trend_ratio_slow | Test: 2025-09-19-2025-03-28 | QQQ_20
# Best CV split: 3 (score=0.84)
#   Threshold 0.5: {'Len': 120, 'PC': 109, 'NC': 11, 'PP': 0.99, 'PR': 0.96, 'NP': 0.64, 'NR': 0.88, 'PosFb': 0.98, 'NegFb': 0.704}
#   Threshold 0.55: {'Len': 120, 'PC': 109, 'NC': 11, 'PP': 0.99, 'PR': 0.96, 'NP': 0.64, 'NR': 0.88, 'PosFb': 0.98, 'NegFb': 0.704}
# Best model: lb=8, score=0.88
# Models Saved for QQQ_duration_slow+duration_moderate+trend_ratio_slow 20 Returns
# ---------------------------
# Results for 8lb | 1940records | duration_slow+trend_moderate+trend_ratio_moderate | Test: 2025-09-19-2025-03-28 | QQQ_20
# Best CV split: 5 (score=0.78)
#   Threshold 0.5: {'Len': 120, 'PC': 104, 'NC': 16, 'PP': 0.99, 'PR': 0.93, 'NP': 0.5, 'NR': 0.89, 'PosFb': 0.969, 'NegFb': 0.586}
#   Threshold 0.55: {'Len': 120, 'PC': 100, 'NC': 13, 'PP': 0.99, 'PR': 0.89, 'NP': 0.62, 'NR': 0.9, 'PosFb': 0.954, 'NegFb': 0.692}
# Results for 10lb | 2430records | duration_slow+trend_moderate+trend_ratio_moderate | Test: 2025-09-19-2025-03-28 | QQQ_20
# Best CV split: 5 (score=0.75)
#   Threshold 0.5: {'Len': 120, 'PC': 104, 'NC': 16, 'PP': 0.99, 'PR': 0.92, 'NP': 0.44, 'NR': 0.88, 'PosFb': 0.966, 'NegFb': 0.528}
#   Threshold 0.55: {'Len': 120, 'PC': 104, 'NC': 9, 'PP': 0.99, 'PR': 0.92, 'NP': 0.33, 'NR': 0.37, 'PosFb': 0.966, 'NegFb': 0.342}
# Best model: lb=8, score=0.778
# Models Saved for QQQ_duration_slow+trend_moderate+trend_ratio_moderate 20 Returns
# ---------------------------
# Results for 8lb | 1935records | lag_fast+duration_moderate+volatility_fast_EMA10 | Test: 2025-09-12-2025-03-21 | QQQ_25
# Best CV split: 3 (score=0.78)
#   Threshold 0.5: {'Len': 120, 'PC': 110, 'NC': 10, 'PP': 0.99, 'PR': 0.96, 'NP': 0.5, 'NR': 0.83, 'PosFb': 0.98, 'NegFb': 0.576}
#   Threshold 0.55: {'Len': 120, 'PC': 108, 'NC': 8, 'PP': 1.0, 'PR': 0.95, 'NP': 0.5, 'NR': 0.67, 'PosFb': 0.983, 'NegFb': 0.546}
# Results for 10lb | 2425records | lag_fast+duration_moderate+volatility_fast_EMA10 | Test: 2025-09-12-2025-03-21 | QQQ_25
# Best CV split: 5 (score=0.74)
#   Threshold 0.5: {'Len': 120, 'PC': 108, 'NC': 12, 'PP': 0.99, 'PR': 0.94, 'NP': 0.42, 'NR': 0.84, 'PosFb': 0.973, 'NegFb': 0.504}
#   Threshold 0.55: {'Len': 120, 'PC': 106, 'NC': 7, 'PP': 1.0, 'PR': 0.93, 'NP': 0.57, 'NR': 0.66, 'PosFb': 0.976, 'NegFb': 0.597}
# Best model: lb=8, score=0.778
# Models Saved for QQQ_lag_fast+duration_moderate+volatility_fast_EMA10 25 Returns
# ---------------------------
# Results for 8lb | 1935records | lag_fast+trend_slow+volatility_moderate | Test: 2025-09-12-2025-03-21 | QQQ_25
# Best CV split: 3 (score=0.86)
#   Threshold 0.5: {'Len': 120, 'PC': 117, 'NC': 3, 'PP': 0.97, 'PR': 1.0, 'NP': 1.0, 'NR': 0.5, 'PosFb': 0.98, 'NegFb': 0.75}
#   Threshold 0.55: {'Len': 120, 'PC': 98, 'NC': 0, 'PP': 1.0, 'PR': 0.86, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.949, 'NegFb': 0.0}
# Results for 10lb | 2425records | lag_fast+trend_slow+volatility_moderate | Test: 2025-09-12-2025-03-21 | QQQ_25
# Best CV split: 3 (score=0.48)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.95, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.966, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.95, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.966, 'NegFb': 0.0}
# Best model: lb=8, score=0.865
# Models Saved for QQQ_lag_fast+trend_slow+volatility_moderate 25 Returns
# ---------------------------
# Results for 8lb | 1935records | duration_slow+duration_moderate+trend_ratio_slow | Test: 2025-09-12-2025-03-21 | QQQ_25
# Best CV split: 3 (score=0.79)
#   Threshold 0.5: {'Len': 120, 'PC': 108, 'NC': 12, 'PP': 1.0, 'PR': 0.95, 'NP': 0.5, 'NR': 1.0, 'PosFb': 0.983, 'NegFb': 0.6}
#   Threshold 0.55: {'Len': 120, 'PC': 108, 'NC': 12, 'PP': 1.0, 'PR': 0.95, 'NP': 0.5, 'NR': 1.0, 'PosFb': 0.983, 'NegFb': 0.6}
# Results for 10lb | 2425records | duration_slow+duration_moderate+trend_ratio_slow | Test: 2025-09-12-2025-03-21 | QQQ_25
# Best CV split: 3 (score=0.79)
#   Threshold 0.5: {'Len': 120, 'PC': 108, 'NC': 12, 'PP': 1.0, 'PR': 0.95, 'NP': 0.5, 'NR': 1.0, 'PosFb': 0.983, 'NegFb': 0.6}
#   Threshold 0.55: {'Len': 120, 'PC': 108, 'NC': 11, 'PP': 1.0, 'PR': 0.95, 'NP': 0.55, 'NR': 1.01, 'PosFb': 0.983, 'NegFb': 0.648}
# Best model: lb=8, score=0.792
# Models Saved for QQQ_duration_slow+duration_moderate+trend_ratio_slow 25 Returns
# ---------------------------
# Results for 8lb | 1935records | duration_slow+trend_moderate+trend_ratio_moderate | Test: 2025-09-12-2025-03-21 | QQQ_25
# Best CV split: 3 (score=0.84)
#   Threshold 0.5: {'Len': 120, 'PC': 110, 'NC': 10, 'PP': 1.0, 'PR': 0.96, 'NP': 0.6, 'NR': 1.0, 'PosFb': 0.986, 'NegFb': 0.692}
#   Threshold 0.55: {'Len': 120, 'PC': 107, 'NC': 5, 'PP': 1.0, 'PR': 0.94, 'NP': 0.2, 'NR': 0.17, 'PosFb': 0.979, 'NegFb': 0.189}
# Results for 10lb | 2425records | duration_slow+trend_moderate+trend_ratio_moderate | Test: 2025-09-12-2025-03-21 | QQQ_25
# Best CV split: 3 (score=0.84)
#   Threshold 0.5: {'Len': 120, 'PC': 110, 'NC': 10, 'PP': 1.0, 'PR': 0.96, 'NP': 0.6, 'NR': 1.0, 'PosFb': 0.986, 'NegFb': 0.692}
#   Threshold 0.55: {'Len': 120, 'PC': 104, 'NC': 8, 'PP': 1.0, 'PR': 0.91, 'NP': 0.62, 'NR': 0.83, 'PosFb': 0.968, 'NegFb': 0.677}
# Best model: lb=8, score=0.839
# Models Saved for QQQ_duration_slow+trend_moderate+trend_ratio_moderate 25 Returns
# ---------------------------
# Results for 8lb | 1935records | duration_fast+trend_moderate+trend_ratio_slow | Test: 2025-09-12-2025-03-21 | QQQ_25
# Best CV split: 3 (score=0.82)
#   Threshold 0.5: {'Len': 120, 'PC': 109, 'NC': 11, 'PP': 1.0, 'PR': 0.96, 'NP': 0.55, 'NR': 1.01, 'PosFb': 0.986, 'NegFb': 0.648}
#   Threshold 0.55: {'Len': 120, 'PC': 103, 'NC': 11, 'PP': 1.0, 'PR': 0.9, 'NP': 0.55, 'NR': 1.01, 'PosFb': 0.964, 'NegFb': 0.648}
# Results for 10lb | 2425records | duration_fast+trend_moderate+trend_ratio_slow | Test: 2025-09-12-2025-03-21 | QQQ_25
# Best CV split: 4 (score=0.91)
#   Threshold 0.5: {'Len': 120, 'PC': 112, 'NC': 8, 'PP': 1.0, 'PR': 0.98, 'NP': 0.75, 'NR': 1.0, 'PosFb': 0.993, 'NegFb': 0.818}
#   Threshold 0.55: {'Len': 120, 'PC': 109, 'NC': 0, 'PP': 1.0, 'PR': 0.96, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.986, 'NegFb': 0.0}
# Best model: lb=10, score=0.906
# Models Saved for QQQ_duration_fast+trend_moderate+trend_ratio_slow 25 Returns
# ---------------------------
# Results for 8lb | 1925records | lag_fast+trend_fast+trend_ratio_moderate | Test: 2025-08-28-2025-03-07 | QQQ_35
# Best CV split: 3 (score=0.49)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
# Results for 10lb | 2415records | lag_fast+trend_fast+trend_ratio_moderate | Test: 2025-08-28-2025-03-07 | QQQ_35
# Best CV split: 3 (score=0.49)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
# Best model: lb=8, score=0.494
# Models Saved for QQQ_lag_fast+trend_fast+trend_ratio_moderate 35 Returns
# ---------------------------
# Results for 8lb | 1925records | lag_fast+volatility_fast+momentum_slow | Test: 2025-08-28-2025-03-07 | QQQ_35
# Best CV split: 3 (score=0.49)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
# Results for 10lb | 2415records | lag_fast+volatility_fast+momentum_slow | Test: 2025-08-28-2025-03-07 | QQQ_35
# Best CV split: 3 (score=0.49)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
# Best model: lb=8, score=0.494
# Models Saved for QQQ_lag_fast+volatility_fast+momentum_slow 35 Returns
# ---------------------------
# Results for 8lb | 1925records | lag_fast+trend_ratio_fast+momentum_slow | Test: 2025-08-28-2025-03-07 | QQQ_35
# Best CV split: 3 (score=0.49)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
# Results for 10lb | 2415records | lag_fast+trend_ratio_fast+momentum_slow | Test: 2025-08-28-2025-03-07 | QQQ_35
# Best CV split: 3 (score=0.49)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
# Best model: lb=8, score=0.494
# Models Saved for QQQ_lag_fast+trend_ratio_fast+momentum_slow 35 Returns
# ---------------------------
# Results for 8lb | 1925records | duration_slow+trend_slow+trend_ratio_slow | Test: 2025-08-28-2025-03-07 | QQQ_35
# Best CV split: 3 (score=0.49)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
# Results for 10lb | 2415records | duration_slow+trend_slow+trend_ratio_slow | Test: 2025-08-28-2025-03-07 | QQQ_35
# Best CV split: 3 (score=0.49)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.98, 'PR': 1.0, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.987, 'NegFb': 0.0}
# Best model: lb=8, score=0.494
# Models Saved for QQQ_duration_slow+trend_slow+trend_ratio_slow 35 Returns
# ---------------------------
# Results for 8lb | 1915records | lag_fast+trend_moderate+trend_ratio_slow | Test: 2025-08-14-2025-02-21 | QQQ_45
# Best CV split: 3 (score=0.47)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
# Results for 10lb | 2405records | lag_fast+trend_moderate+trend_ratio_slow | Test: 2025-08-14-2025-02-21 | QQQ_45
# Best CV split: 3 (score=0.47)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
# Best model: lb=8, score=0.471
# Models Saved for QQQ_lag_fast+trend_moderate+trend_ratio_slow 45 Returns
# ---------------------------
# Results for 8lb | 1915records | lag_fast+trend_ratio_slow+volatility_moderate | Test: 2025-08-14-2025-02-21 | QQQ_45
# Best CV split: 3 (score=0.47)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
# Results for 10lb | 2405records | lag_fast+trend_ratio_slow+volatility_moderate | Test: 2025-08-14-2025-02-21 | QQQ_45
# Best CV split: 3 (score=0.47)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
# Best model: lb=8, score=0.471
# Models Saved for QQQ_lag_fast+trend_ratio_slow+volatility_moderate 45 Returns
# ---------------------------
# Results for 8lb | 1915records | duration_slow+duration_moderate+trend_fast | Test: 2025-08-14-2025-02-21 | QQQ_45
# Best CV split: 3 (score=0.84)
#   Threshold 0.5: {'Len': 120, 'PC': 116, 'NC': 4, 'PP': 0.96, 'PR': 1.0, 'NP': 1.0, 'NR': 0.44, 'PosFb': 0.973, 'NegFb': 0.702}
#   Threshold 0.55: {'Len': 120, 'PC': 116, 'NC': 4, 'PP': 0.96, 'PR': 1.0, 'NP': 1.0, 'NR': 0.44, 'PosFb': 0.973, 'NegFb': 0.702}
# Results for 10lb | 2405records | duration_slow+duration_moderate+trend_fast | Test: 2025-08-14-2025-02-21 | QQQ_45
# Best CV split: 5 (score=0.74)
#   Threshold 0.5: {'Len': 120, 'PC': 113, 'NC': 7, 'PP': 0.96, 'PR': 0.98, 'NP': 0.57, 'NR': 0.44, 'PosFb': 0.967, 'NegFb': 0.519}
#   Threshold 0.55: {'Len': 120, 'PC': 111, 'NC': 4, 'PP': 0.95, 'PR': 0.95, 'NP': 1.0, 'NR': 0.44, 'PosFb': 0.95, 'NegFb': 0.702}
# Best model: lb=8, score=0.837
# Models Saved for QQQ_duration_slow+duration_moderate+trend_fast 45 Returns
# ---------------------------
# Results for 8lb | 1915records | duration_slow+duration_moderate+volatility_moderate | Test: 2025-08-14-2025-02-21 | QQQ_45
# Best CV split: 4 (score=0.84)
#   Threshold 0.5: {'Len': 120, 'PC': 116, 'NC': 4, 'PP': 0.96, 'PR': 1.0, 'NP': 1.0, 'NR': 0.44, 'PosFb': 0.973, 'NegFb': 0.702}
#   Threshold 0.55: {'Len': 120, 'PC': 116, 'NC': 4, 'PP': 0.96, 'PR': 1.0, 'NP': 1.0, 'NR': 0.44, 'PosFb': 0.973, 'NegFb': 0.702}
# Results for 10lb | 2405records | duration_slow+duration_moderate+volatility_moderate | Test: 2025-08-14-2025-02-21 | QQQ_45
# Best CV split: 4 (score=0.84)
#   Threshold 0.5: {'Len': 120, 'PC': 116, 'NC': 4, 'PP': 0.96, 'PR': 1.0, 'NP': 1.0, 'NR': 0.44, 'PosFb': 0.973, 'NegFb': 0.702}
#   Threshold 0.55: {'Len': 120, 'PC': 116, 'NC': 1, 'PP': 0.96, 'PR': 1.0, 'NP': 1.0, 'NR': 0.11, 'PosFb': 0.973, 'NegFb': 0.27}
# Best model: lb=8, score=0.837
# Models Saved for QQQ_duration_slow+duration_moderate+volatility_moderate 45 Returns
# ---------------------------
# Results for 8lb | 1915records | momentum_moderate+momentum_fast_EMA10+all_seasons | Test: 2025-08-14-2025-02-21 | QQQ_45
# Best CV split: 3 (score=0.47)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
# Results for 10lb | 2405records | momentum_moderate+momentum_fast_EMA10+all_seasons | Test: 2025-08-14-2025-02-21 | QQQ_45
# Best CV split: 3 (score=0.47)
#   Threshold 0.5: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
#   Threshold 0.55: {'Len': 120, 'PC': 120, 'NC': 0, 'PP': 0.92, 'PR': 0.99, 'NP': 0.0, 'NR': 0.0, 'PosFb': 0.942, 'NegFb': 0.0}
# Best model: lb=8, score=0.471
# Models Saved for QQQ_momentum_moderate+momentum_fast_EMA10+all_seasons 45 Returns
# ---------------------------

# %% [markdown]
# # Velocity x Category Combo Groupings

# %%
ticker = 'QQQ'
model_dir = f'../Models/Ensemble_{ticker}'
thresh = .5
arch_types = ['deep']
lb = 5
returns = [5, 10, 15, 20, 25, 35, 45]
combined_df = pd.DataFrame()
exts = [220, 170, 120, '10-08', 'new']

def extract(ticker, returns, cat_cols_all, windows=[10, 25]):

    import os
    from indicators_returns import final_df #Universal script for indicator set and actuals
    import importlib
    import indicators_returns
    importlib.reload(indicators_returns)
    from indicators_returns import final_df
    # point this at an existing directory in your project
    os.chdir('/Users/brettchase/Documents/Fracturion/Feature_Set_Construction_Testing')
    
    df = final_df(ticker, returns)
    df = df.iloc[:-101].replace([np.inf, -np.inf], 0)#

    df = df.sort_index(ascending=True)
    # Exponential Moving Average
    ema_cols = {
        f"{col}_EMA{w}": df[col].ewm(span=w, adjust=False).mean()
        for w in windows
        for col in cat_cols_all
    }
    # 3) merge them back into one dict
    new_cols = {**ema_cols}

    # 4) concatenate onto your original df
    df = pd.concat([df, pd.DataFrame(new_cols, index=df.index)], axis=1)    
    df = df.sort_index(ascending=False)
    
    return df

df = extract(ticker, returns, raw_all, windows=[10,25])

def submodel(thresh, ext, df):

        upper = thresh
        lower = 1 - upper

        # Placeholder for final predictions
        combined_predictions = {}
        record_length = lb * 245
        df = df.iloc[:record_length]
        df = add_cyclic_seasonality(df, 
                                    date_col='Date',
                                    add_weekly=True,
                                    add_month=True,
                                    add_quarter=True,
                                    add_year=True,
                                    add_day_of_year=False,
                                    mode='calendar',    # or 'trading' or 'both'
                                    prefix='cyc_')

        # Iterate through each return horizon
        for r in returns:
        
            df_ph = df.copy()

            # Create base prediction matrix with Date and Close
            pred_matrix = df_ph[['Date', 'Close']].copy()

            for arch in arch_types:
            
                selected_models = get_model_set(r)
                    
                # all index-combos of length r
                for name, original_cols in selected_models.items():

                    #cols = original_cols
                    cols = feature_map.get((name, arch, r), original_cols)
                    
                    df_features = df_ph[cols].copy()
                    df_features = df_features.replace([np.inf, -np.inf], 0)

                    # XGBoost prediction
                    xgb_path = os.path.join(model_dir, f"{name}_xgboost_{r}{arch}{ext}.pkl")
                    #print(xgb_path)
                    #xgb_path = os.path.join(model_dir, f"{name}_xgboost_{r}{arch}all.pkl")
                    if os.path.exists(xgb_path):
                        with open(xgb_path, 'rb') as f:
                            model_xgb = pickle.load(f)
                            #print(f"{xgb_path} | {model_xgb.get_booster().best_iteration}")
                        prob_xgb = model_xgb.predict_proba(df_features)[:, 1]
                        col_name_xgb = f"{name}_xgb_{r}{arch}"
                        pred_matrix[col_name_xgb] = np.where(
                            prob_xgb > upper, prob_xgb,
                            np.where(prob_xgb < lower, prob_xgb - 1, 0)
                        )

                        signed_pred = np.where(
                            prob_xgb > upper, prob_xgb,
                            np.where(prob_xgb < lower, prob_xgb - 1, 0)
                        )

                    # Final summed prediction across models
                    pred_cols = [col for col in pred_matrix.columns if col not in ['Date', 'Close'] and not col.startswith('sum_')
                                 and not col.startswith('w_sum_') and not col.startswith('weighted_')]
                    pred_matrix[f"sum_{r}"] = pred_matrix[pred_cols].sum(axis=1)

                    combined_predictions[r] = pred_matrix

        aggr_df = None

        for r, df_preds in combined_predictions.items():

            cols_to_merge = [col for col in df_preds.columns if col not in ['Date', 'Close']]
            df_preds_renamed = df_preds[['Date', 'Close'] + cols_to_merge].copy()

            if aggr_df is None:
                aggr_df = df_preds_renamed
            else:
                aggr_df = pd.merge(aggr_df, df_preds_renamed, on=['Date', 'Close'], how='outer')

        sub_model_df = aggr_df.copy()
        for r in returns:
            sub_model_df[f"sum_{r}_{ext}"] = sub_model_df[f"sum_{r}"]

        return sub_model_df, model_xgb, cols

for ext in exts:
    with open(f"curr_feature_map_v{ext}.pkl", "rb") as f:
            feature_map = pickle.load(f)

    """
    sub_model_df, model_xgb, cols = submodel(thresh, ext)
    sub_model_df[['Date', 'Close', f'sum_5_{ext}', f'sum_10_{ext}', f'sum_15_{ext}', f'sum_20_{ext}', 
                f'sum_25_{ext}', f'sum_35_{ext}', f'sum_45_{ext}']].sort_index(ascending=False).head(45).round(3).reset_index()
    """
    # Run submodel
    sub_model_df, model_xgb, cols = submodel(thresh, ext, df)

    # Select only needed columns
    cols_to_merge = ['Date', 'Close', 
                    f'sum_5_{ext}', f'sum_10_{ext}', f'sum_15_{ext}', 
                    f'sum_20_{ext}', f'sum_25_{ext}', f'sum_35_{ext}', f'sum_45_{ext}']
    sub_model_df = sub_model_df[cols_to_merge]

    if combined_df.empty:
        combined_df = sub_model_df.copy()
    else:
        combined_df = combined_df.merge(sub_model_df, on=['Date', 'Close'], how='outer')

#combined_df.sort_index(ascending=False).head(5).round(3).reset_index()
        
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

rs = [15]
for r in returns:
    final_df = combined_df.sort_index(ascending=False).head(r).round(3).reset_index().drop(columns='index', errors='ignore').copy()
    cols = [col for col in final_df.columns if col.startswith(f'sum_{r}')]
    print(final_df[['Date', 'Close'] + cols].head(3))
    
    plt.figure(figsize=(12,6))

    # line for Close
    plt.plot(final_df['Date'], final_df['Close'], color='black', linewidth=1, alpha=0.6, label='Close')

    # all sum_5_x columns
    sum_cols = [c for c in final_df.columns if c.startswith(f'sum_{r}_')]
    offsets = np.linspace(-0.3, 0.3, len(sum_cols))  # small horizontal offsets

    for i, col in enumerate(sum_cols):
        vals = final_df[col]
        colors = np.where(vals >= 0, 'blue', 'red')     # up = blue, down = red
        sizes = np.abs(vals) * 60                       # scale magnitude
        # apply slight horizontal offset to separate columns visually
        plt.scatter(final_df['Date'] + np.timedelta64(int(offsets[i]*24), 'h'),
                    final_df['Close'],
                    s=sizes, c=colors, alpha=0.55, edgecolor='k', linewidths=0.4, label=col)

    # custom legend
    legend_elements = [
        Patch(facecolor='blue', edgecolor='k', label='Positive (Up)'),
        Patch(facecolor='red', edgecolor='k', label='Negative (Down)'),
        Line2D([], [], color='black', linewidth=1.5, label='Close')
    ]
    plt.legend(handles=legend_elements + [Line2D([], [], color='none', label=col) for col in sum_cols],
            title='Legend', loc='best')

    plt.xlabel('Date')
    plt.xticks(final_df['Date'], rotation=45, ha='right')
    plt.ylabel('Close')
    plt.title('Close with Prediction Magnitude and Direction')
    plt.tight_layout()
    plt.show()
# Out:
#         Date   Close  sum_5_220  sum_5_170  sum_5_120  sum_5_10-08  sum_5_new
# 0 2025-10-20  611.54      1.136      0.121      0.026       -0.079      0.105
# 1 2025-10-17  603.93      1.239      1.366      0.095       -0.073      0.178
# 2 2025-10-16  599.99     -1.147     -1.201     -1.153       -2.344     -0.189
#         Date   Close  sum_10_220  sum_10_170  sum_10_120  sum_10_10-08  sum_10_new
# 0 2025-10-20  611.54      -1.309      -2.605      -2.500        -2.812      -1.807
# 1 2025-10-17  603.93      -1.285      -2.633      -2.574        -2.767      -1.767
# 2 2025-10-16  599.99      -1.206      -1.561      -2.589        -2.775      -1.700
#         Date   Close  sum_15_220  sum_15_170  sum_15_120  sum_15_10-08  sum_15_new
# 0 2025-10-20  611.54      -1.870       0.197       0.505        -1.995      -2.528
# 1 2025-10-17  603.93      -1.815       0.551       1.860        -1.526      -2.327
# 2 2025-10-16  599.99      -0.744      -0.702       0.810        -0.403      -1.305
#         Date   Close  sum_20_220  sum_20_170  sum_20_120  sum_20_10-08  sum_20_new
# 0 2025-10-20  611.54      -0.507      -0.814      -1.507        -0.602      -0.892
# 1 2025-10-17  603.93       0.775       0.692      -1.402        -0.439       0.428
# 2 2025-10-16  599.99       0.817      -0.326      -1.430        -0.472       0.439
#         Date   Close  sum_25_220  sum_25_170  sum_25_120  sum_25_10-08  sum_25_new
# 0 2025-10-20  611.54      -1.796       0.531       0.502        -1.909      -3.734
# 1 2025-10-17  603.93       1.460       0.691       0.539        -0.638      -2.556
# 2 2025-10-16  599.99       1.640       0.838       1.523        -0.655      -2.521
#         Date   Close  sum_35_220  sum_35_170  sum_35_120  sum_35_10-08  sum_35_new
# 0 2025-10-20  611.54      -0.930       1.085       2.673        -1.113      -0.403
# 1 2025-10-17  603.93       1.209       1.146       2.673        -0.018      -0.237
# 2 2025-10-16  599.99       0.242       1.223       2.678         0.058      -0.224
#         Date   Close  sum_45_220  sum_45_170  sum_45_120  sum_45_10-08  sum_45_new
# 0 2025-10-20  611.54       0.607      -0.494       3.275        -0.542       0.458
# 1 2025-10-17  603.93       0.607      -0.408       3.277        -0.517       0.672
# 2 2025-10-16  599.99       0.867      -0.332       3.254         0.671       2.099

# %%
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt
from sklearn.metrics import (
    roc_curve, auc,
    precision_recall_curve, average_precision_score,
    f1_score, accuracy_score
)

def performance_metrics(metrics_df, returns):

    metrics_df = metrics_df.sort_index(ascending=True)

    def add_column_based_on_future_value(df, days):

        future_return = (df['Close'].shift(-days) - df['Close']) / df['Close']

        df[f'Return_{days}'] = (future_return > 0).astype(int)

        return df

    # Apply return logic for each target horizon
    for r in returns: 
        new_df = add_column_based_on_future_value(metrics_df, r)

    return new_df

performance_df = performance_metrics(combined_df.round(3), returns)

horizons = returns
# Dictionary to store the filtered DataFrames
horizon_dfs = {}

# Loop through each horizon
for h in horizons:
    # Collect relevant columns
    cols = ['Date', 'Close'] + [
        col for col in performance_df.columns 
        if col.endswith(f'_xgb_{h}deep') or col.endswith(f'_xgb_{h}shallow') or f'sum_{h}_' in col or col == f'Return_{h}']
    
    # Create and store the filtered DataFrame
    horizon_dfs[h] = performance_df[cols].copy()

def convert_signed_to_prob(p):
    return p if p >= 0 else 1 + p

def convert_sum_to_prob(p):
    return p if p >= 0 else -1 * p

for h in horizons:

    df = horizon_dfs[h].sort_values('Date', ascending=False).iloc[h:h+150].copy()
    for col in df.columns:
        if f'sum_{h}' in col:
            #df[f'{col}_norm'] = df[col] / 5
            max_pos = df.loc[df[col] > 0, col].max()
            max_neg = df.loc[df[col] < 0, col].min()  # most negative (e.g., -12.5)
            
            df[f'{col}_norm'] = df[col].apply(
                lambda x: x / max_pos if x > 0 else (x / abs(max_neg) if x < 0 else 0)
            )

    bins = [5]
    for bin in bins:
        # --- Calibration Curve ---
        plt.figure(figsize=(10, 6))
        for col in df.columns:
            if f'_xgb_{h}' in col or 'norm' in col: #f'sum_{h}_norm' in col:
                filtered = df[df[col] != 0]
                if 'norm' in col: #== f'sum_{h}_norm':
                    probs = filtered[col].apply(convert_sum_to_prob)
                else:
                    probs = filtered[col].apply(convert_signed_to_prob)
                targets = filtered[f'Return_{h}']
                prob_true, prob_pred = calibration_curve(targets, probs, n_bins=bin, strategy='quantile')
                plt.plot(prob_pred, prob_true, marker='o', label=col)

        plt.plot([0, 1], [0, 1], 'k--')
        plt.title(f'Calibration Curve - Horizon {h}')
        plt.xlabel('Predicted Probability')
        plt.ylabel('Actual Frequency')
        plt.legend()
        plt.grid()
        plt.show()

# %%
pd.set_option("display.expand_frame_repr", False)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 10000)
pd.set_option("display.max_colwidth", None)
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt
from sklearn.metrics import (
    roc_curve, auc,
    precision_recall_curve, average_precision_score,
    f1_score, accuracy_score
)
threshs = [.55]
thresh = .5
length = 150
start = 0
accuracy_df, combined_df = pd.DataFrame(), pd.DataFrame()
df = extract(ticker, returns, raw_all, windows=[10,25])

def performance_metrics(metrics_df, returns):

    metrics_df = metrics_df.sort_index(ascending=True)

    def add_column_based_on_future_value(df, days):

        future_return = (df['Close'].shift(-days) - df['Close']) / df['Close']

        df[f'Return_{days}'] = (future_return > 0).astype(int)

        return df

    # Apply return logic for each target horizon
    for r in returns: 
        new_df = add_column_based_on_future_value(metrics_df, r)

    return new_df
    
for ext in exts:

    with open(f"curr_feature_map_v{ext}.pkl", "rb") as f:
            feature_map = pickle.load(f)

    # Run submodel
    sub_model_df, model_xgb, cols = submodel(thresh, ext, df)

    # Select only needed columns
    cols_to_merge = ['Date', 'Close', 
                    f'sum_5_{ext}', f'sum_10_{ext}', f'sum_15_{ext}', 
                    f'sum_20_{ext}', f'sum_25_{ext}', f'sum_35_{ext}', f'sum_45_{ext}']
    sub_model_df = sub_model_df[cols_to_merge]

    if combined_df.empty:
        combined_df = sub_model_df.copy()
    else:
        combined_df = combined_df.merge(sub_model_df, on=['Date', 'Close'], how='outer')

performance_df = performance_metrics(combined_df.round(3), returns)

horizons = returns
# Dictionary to store the filtered DataFrames
horizon_dfs = {}

# Loop through each horizon
for h in horizons:
    # Collect relevant columns
    cols = ['Date', 'Close'] + [
        col for col in performance_df.columns 
        if col.endswith(f'_xgb_{h}deep') or col.endswith(f'_xgb_{h}shallow') or f'sum_{h}' in col or col == f'Return_{h}'
    ]
    
    # Create and store the filtered DataFrame
    horizon_dfs[h] = performance_df[cols].copy()

for h in horizons:

    df = horizon_dfs[h].sort_values('Date', ascending=False).iloc[h+start:h+length+start].copy()
    
    for arch in ['deep']:
        records = []
        actual_pos = df[f'Return_{h}'].sum()
        actual_neg = len(df[f'Return_{h}']) - actual_pos
        for col in df.columns:
            if f'_xgb_{h}{arch}' in col or f'sum_{h}' in col:
                # only keep the rows that actually got a prediction
                filtered = df[df[col] != 0]
                # convert your raw score to a probability
                if f'sum_{h}' in col:
                    probs = filtered[col].apply(convert_sum_to_prob)
                else:
                    probs = filtered[col].apply(convert_signed_to_prob)
                # binarize at 0.5
                y_pred = (probs >= 0.5).astype(int)
                y_true = filtered[f'Return_{h}']
                
                # compute the matrix
                cm = confusion_matrix(y_true, y_pred,labels=[0,1])
                tn, fp, fn, tp = cm.ravel()
                records.append({
                    'horizon': h,
                    'model': col,
                    'act_pos': actual_pos,
                    'act_neg': actual_neg,
                    'pos_acc': f"{(tp/(tp + fp)):.1%}" if actual_pos>0 else "n/a",
                    'neg_acc': f"{(tn/(tn + fn)):.1%}" if actual_neg>0 else "n/a",
                    'tp': tp,
                    'fp': fp,
                    'tn': tn,
                    'fn': fn,
                })

        # make your summary table
        cm_df = pd.DataFrame(records)
        accuracy_df = pd.concat([accuracy_df, cm_df], ignore_index=True)

accuracy_df["pos_weight"] = (accuracy_df["pos_acc"].replace("n/a", "50%") .str.rstrip("%").astype(float).fillna(50).clip(lower=50) / 100)
accuracy_df["neg_weight"] = (accuracy_df["neg_acc"].replace("n/a", "50%") .str.rstrip("%").astype(float).fillna(50).clip(lower=50) / 100)
#accuracy_df[accuracy_df['horizon'] == 10]
pos_w_map = accuracy_df.groupby("model")["pos_weight"].mean().to_dict()
neg_w_map = accuracy_df.groupby("model")["neg_weight"].mean().to_dict()
accuracy_df
# Out:
#     horizon         model  act_pos  act_neg pos_acc neg_acc   tp  fp  tn  fn  pos_weight  neg_weight
# 0         5     sum_5_220      102       48   71.0%   66.7%   98  40   8   4       0.710       0.667
# 1         5     sum_5_170      102       48   71.9%   66.7%   97  38  10   5       0.719       0.667
# 2         5     sum_5_120      102       48   69.2%   57.1%   99  44   4   3       0.692       0.571
# 3         5   sum_5_10-08      102       48   69.9%   50.0%   95  41   7   7       0.699       0.500
# 4         5     sum_5_new      102       48   69.4%   66.7%  100  44   4   2       0.694       0.667
# 5        10    sum_10_220      114       36   77.1%   50.0%  111  33   3   3       0.771       0.500
# 6        10    sum_10_170      114       36   77.6%   57.1%  111  32   4   3       0.776       0.571
# 7        10    sum_10_120      114       36   77.2%   60.0%  112  33   3   2       0.772       0.600
# 8        10  sum_10_10-08      114       36   77.6%  100.0%  114  33   3   0       0.776       1.000
# 9        10    sum_10_new      114       36   80.2%   52.6%  105  26  10   9       0.802       0.526
# 10       15    sum_15_220      113       37   75.7%   50.0%  112  36   1   1       0.757       0.500
# 11       15    sum_15_170      113       37   75.8%  100.0%  113  36   1   0       0.758       1.000
# 12       15    sum_15_120      113       37   76.4%  100.0%  113  35   2   0       0.764       1.000
# 13       15  sum_15_10-08      113       37   75.2%    0.0%  112  37   0   1       0.752       0.500
# 14       15    sum_15_new      113       37   75.8%  100.0%  113  36   1   0       0.758       1.000
# 15       20    sum_20_220      120       30   80.8%   50.0%  118  28   2   2       0.808       0.500
# 16       20    sum_20_170      120       30   80.0%    nan%  120  30   0   0       0.800       0.500
# 17       20    sum_20_120      120       30   80.0%    nan%  120  30   0   0       0.800       0.500
# 18       20  sum_20_10-08      120       30   80.5%  100.0%  120  29   1   0       0.805       1.000
# 19       20    sum_20_new      120       30   80.5%  100.0%  120  29   1   0       0.805       1.000
# 20       25    sum_25_220      117       33   77.9%    0.0%  116  33   0   1       0.779       0.500
# 21       25    sum_25_170      117       33   78.0%    nan%  117  33   0   0       0.780       0.500
# 22       25    sum_25_120      117       33   83.2%   76.9%  114  23  10   3       0.832       0.769
# 23       25  sum_25_10-08      117       33   82.3%   88.9%  116  25   8   1       0.823       0.889
# 24       25    sum_25_new      117       33   81.0%   75.0%  115  27   6   2       0.810       0.750
# 25       35    sum_35_220      120       30   83.9%   38.5%  104  20  10  16       0.839       0.500
# 26       35    sum_35_170      120       30   87.7%   70.0%  114  16  14   6       0.877       0.700
# 27       35    sum_35_120      120       30   80.0%    nan%  120  30   0   0       0.800       0.500
# 28       35  sum_35_10-08      120       30   80.5%  100.0%  120  29   1   0       0.805       1.000
# 29       35    sum_35_new      120       30   81.8%   33.3%  108  24   6  12       0.818       0.500
# 30       45    sum_45_220      113       37   82.5%  100.0%  113  24  13   0       0.825       1.000
# 31       45    sum_45_170      113       37   79.6%   69.2%  109  28   9   4       0.796       0.692
# 32       45    sum_45_120      113       37   75.3%    nan%  113  37   0   0       0.753       0.500
# 33       45  sum_45_10-08      113       37   77.8%   83.3%  112  32   5   1       0.778       0.833
# 34       45    sum_45_new      113       37   76.4%   50.0%  110  34   3   3       0.764       0.500

# %%
horizons = returns
# Dictionary to store the filtered DataFrames
horizon_dfs = {}

# Loop through each horizon
for h in horizons:
    # Collect relevant columns
    cols = ['Date', 'Close'] + [
        col for col in performance_df.columns 
        if col.endswith(f'_xgb_{h}deep') or col.endswith(f'_xgb_{h}shallow') or f'sum_{h}' in col or col == f'Return_{h}'
    ]
    
    # Create and store the filtered DataFrame
    horizon_dfs[h] = performance_df[cols].copy()
